# %%
import pandas as pd

# 데이터 불러오기
df = pd.read_csv("/Users/hyunwoo/Desktop/PADA/PADA_LAB/raw/audible_reviews.csv")

# 1000개 랜덤 샘플링
sampled_df = df.sample(n=1000, random_state=42)  # random_state를 고정하면 동일한 결과가 재현됨

# 샘플링 결과 확인
print(sampled_df)

# 샘플링 데이터를 새로운 CSV 파일로 저장
sampled_df.to_csv("/Users/hyunwoo/Desktop/PADA/PADA_LAB/audible_sampled.csv", index=False)
# Out:
#                                              Review_Text Posted_Date  Rating  \
# 98710  youve really gotta know where your towel is, a...    02-21-22       5
# 92506  Theres a reason why Violas brilliance has been...    06-23-22       5
# 36795  Over hipped I was excited to start reading it ...    05-27-20       2
# 12951  Joe Morton is the best reader Ive had the plea...    03-19-17       4
# 74224  This book details the history of human evoluti...    02-10-24       5
# ...                                                  ...         ...     ...
# 90966  I knew that this book would be good because it...    01-27-17       5
# 92575  One of the best Ive read since Will Viola is a...    07-10-22       5
# 6234   The narration was great, and the plot was ente...    03-21-24       2
# 1761   I dont enjoy scifi but so hears so many great ...    05-13-23       5
# 5757   Listened to this book on a long drive  very en...    01-22-23       5
#
#        Average_Rating  Num_of_Ratings  Helpfulness  \
# 98710             4.6           55145            0
# 92506             4.9           40545            0
# 36795             4.7           13092            0
# 12951             4.2            8957            0
# 74224             4.7           56033            0
# ...               ...             ...          ...
# 90966             4.9          215239            0
# 92575             4.9           40545            0
# 6234              4.6            8066            0
# 1761              4.9          182379            0
# 5757              4.6            8066            0
#
#                                   Reviewer  \
# 98710                          Wolfman Dan
# 92506                         Maisa Morrar
# 36795                              BookTea
# 12951                              William
# 74224                       Watsh Rajneesh
# ...                                    ...
# 90966                              Rishbha
# 92575                      Amazon Customer
# 6234   sjwthompson | Buttercup's Book Blog
# 1761                       Bethany Dempsey
# 5757                 Christine A. McCorvie
#
#                                            Review Title  \
# 98710  one of the all time classics of human literature
# 92506                              Chillingly Beautiful
# 36795                               A waste of a credit
# 12951          Joe Morton is definitely the best reader
# 74224                        History of human evolution
# ...                                                 ...
# 90966                                           Amazing
# 92575                                Absolutely amazing
# 6234                           Fun take on the classics
# 1761                                     Good,good,good
# 5757                                  A fun distraction
#
#                                                     Link  \
# 98710  https://www.audible.com/pd/The-Hitchhikers-Gui...
# 92506  https://www.audible.com/pd/Finding-Me-Audioboo...
# 36795  https://www.audible.com/pd/Red-White-Royal-Blu...
# 12951  https://www.audible.com/pd/Invisible-Man-Audio...
# 74224  https://www.audible.com/pd/Sapiens-Audiobook/B...
# ...                                                  ...
# 90966  https://www.audible.com/pd/Born-a-Crime-Audiob...
# 92575  https://www.audible.com/pd/Finding-Me-Audioboo...
# 6234   https://www.audible.com/pd/Mrs-Wickham-Audiobo...
# 1761   https://www.audible.com/pd/Project-Hail-Mary-A...
# 5757   https://www.audible.com/pd/Mrs-Wickham-Audiobo...
#
#              Rating_Distribution     Rating_of_Performance  \
# 98710    40868,9576,3215,929,557   40758,5054,1135,232,192
# 92506       38678,1544,224,54,45        36158,822,83,28,34
# 36795     10200,1881,667,204,140      9107,1754,533,133,86
# 12951      5402,1766,795,393,601      6244,830,404,186,320
# 74224    45042,7848,1980,631,532   39888,6212,1299,264,226
# ...                          ...                       ...
# 90966  195059,17004,2395,407,374   185807,7574,951,178,210
# 92575       38678,1544,224,54,45        36158,822,83,28,34
# 6234        5753,1525,537,162,89        6154,846,254,65,52
# 1761   162833,15895,2619,672,360  156733,7989,1298,287,227
# 5757        5753,1525,537,162,89        6154,846,254,65,52
#
#                  Rating_of_Story
# 98710    34621,7996,3097,994,594
# 92506       34980,1634,227,59,38
# 36795      9075,1589,591,204,137
# 12951      4564,1669,809,375,562
# 74224    37827,6836,1827,538,540
# ...                          ...
# 90966  174092,16520,2484,374,281
# 92575       34980,1634,227,59,38
# 6234       5111,1411,516,171,111
# 1761   145112,16872,2818,763,416
# 5757       5111,1411,516,171,111
#
# [1000 rows x 12 columns]
