# %%
import pandas as pd

# %%
df = pd.read_csv("preprocessed_amazon.csv")
df
# Out:
#                                             product_name  Num_of_Rating  \
# 0      Panasonic Portable AM / FM Radio, Battery Oper...          27618
# 1      Panasonic Portable AM / FM Radio, Battery Oper...          27618
# 2      Panasonic Portable AM / FM Radio, Battery Oper...          27618
# 3      Panasonic Portable AM / FM Radio, Battery Oper...          27618
# 4      Panasonic Portable AM / FM Radio, Battery Oper...          27618
# ...                                                  ...            ...
# 89923  Fintie Case for iPad 9.7 2018 2017 / iPad Air ...          43430
# 89924  Fintie Case for iPad 9.7 2018 2017 / iPad Air ...          43430
# 89925  Fintie Case for iPad 9.7 2018 2017 / iPad Air ...          43430
# 89926  Fintie Case for iPad 9.7 2018 2017 / iPad Air ...          43430
# 89927  Fintie Case for iPad 9.7 2018 2017 / iPad Air ...          43430
#
#        Rating                              review_title  \
# ...

# %%
df['time_lapsed'] = df['Day_elapsed']

# %%
df
# Out:
#                                             product_name  Num_of_Rating  \
# 0      Panasonic Portable AM / FM Radio, Battery Oper...          27618
# 1      Panasonic Portable AM / FM Radio, Battery Oper...          27618
# 2      Panasonic Portable AM / FM Radio, Battery Oper...          27618
# 3      Panasonic Portable AM / FM Radio, Battery Oper...          27618
# 4      Panasonic Portable AM / FM Radio, Battery Oper...          27618
# ...                                                  ...            ...
# 89923  Fintie Case for iPad 9.7 2018 2017 / iPad Air ...          43430
# 89924  Fintie Case for iPad 9.7 2018 2017 / iPad Air ...          43430
# 89925  Fintie Case for iPad 9.7 2018 2017 / iPad Air ...          43430
# 89926  Fintie Case for iPad 9.7 2018 2017 / iPad Air ...          43430
# 89927  Fintie Case for iPad 9.7 2018 2017 / iPad Air ...          43430
#
#        Rating                              review_title  \
# ...
