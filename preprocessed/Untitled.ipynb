# %%
import pandas as pd

# %%
df = pd.read_csv("preprocessed_hotel.csv")
df
# Out:
#          Hotel_Name                                        Review_Text  \
# 0       studios2let  Perfect location with good connections and sho...
# 1       studios2let  The room had everything you needed. Near to am...
# 2       studios2let  Conveniently nearby St. Pancras, very small bu...
# 3       studios2let         Reception staffed 24 hours a day.All good.
# 4       studios2let  Very convenient to Kings Cross and the cityA l...
# ...             ...                                                ...
# 89500  montanahotel  Convenient and classy.    The staff are excell...
# 89501  montanahotel  lovely atmosphere, extremely friendly and help...
# 89502  montanahotel  It was a single room, a little small but it wa...
# 89503  montanahotel  Very clean and well maintained.The rooms are v...
# 89504  montanahotel  The staff were very friendly and helpful! Espe...
#
#        Posted_Date  Rating  Average_Rating  Num_of_Ratings  Helpfulness  \
# ...
