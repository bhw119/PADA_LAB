# %%
import torch
from transformers import BertTokenizer, BertModel
import numpy as np
import csv

class LexiconProcessor:
    def __init__(self, model_name: str = 'bert-base-uncased'):
        # BERT 모델 초기화
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.tokenizer = BertTokenizer.from_pretrained(model_name)
        self.model = BertModel.from_pretrained(model_name).to(self.device)
        self.model.eval()
        
    def get_embedding(self, word: str) -> np.ndarray:
        """단어의 BERT 임베딩을 계산"""
        inputs = self.tokenizer(
            word,
            return_tensors='pt',
            padding=True,
            truncation=True,
            max_length=512
        ).to(self.device)
        
        with torch.no_grad():
            outputs = self.model(**inputs)
            embedding = outputs.last_hidden_state[:, 0, :]
        
        return embedding.cpu().numpy()[0]

    def process_lexicon(self, vad_lexicon_path: str, output_file: str):
        """VAD 렉시콘의 단어들을 처리하여 임베딩과 VA 값을 저장"""
        # VAD 렉시콘 읽기
        word_data = {}
        with open(vad_lexicon_path, 'r', encoding='utf-8') as file:
            for line in file:
                parts = line.strip().split()
                if len(parts) == 4:
                    word = parts[0].lower()
                    valence, arousal = float(parts[1]), float(parts[2])
                    word_data[word] = (valence, arousal)
        
        # 각 단어에 대한 임베딩 계산 및 저장
        with open(output_file, 'w', newline='', encoding='utf-8') as f:
            writer = csv.writer(f)
            writer.writerow(['word', 'valence', 'arousal', 'embedding'])
            
            for word, (valence, arousal) in word_data.items():
                try:
                    embedding = self.get_embedding(word)
                    writer.writerow([
                        word,
                        valence,
                        arousal,
                        embedding.tolist()
                    ])
                    print(f"Processed: {word}")
                except Exception as e:
                    print(f"Error processing word '{word}': {e}")

def main():
    # 설정
    vad_lexicon_path = "Bipolar_Lexicon.txt"
    output_file = "lexicon_embeddings.csv"
    
    # 렉시콘 처리
    processor = LexiconProcessor()
    processor.process_lexicon(vad_lexicon_path, output_file)
    print("Processing completed!")

if __name__ == "__main__":
    main()
# Out:
# Processed: aaaaaaah
# Processed: aaaah
# Processed: aardvark
# Processed: aback
# Processed: abacus
# Processed: abalone
# Processed: abandon
# Processed: abandoned
# Processed: abandonment
# Processed: abashed
# Processed: abate
# Processed: abatement
# Processed: abba
# Processed: abbey
# Processed: abbot
# Processed: abbreviate
# Processed: abbreviation
# Processed: abdomen
# Processed: abdominal
# Processed: abduct
# Processed: abduction
# Processed: aberrant
# Processed: aberration
# Processed: abeyance
# Processed: abhor
# Processed: abhorrence
# Processed: abhorrent
# Processed: abide
# Processed: abiding
# Processed: ability
# Processed: abject
# Processed: ablation
# Processed: ablaze
# Processed: able
# Processed: abnormal
# Processed: abnormality
# Processed: aboard
# Processed: abode
# Processed: abolish
# Processed: abolition
# Processed: abominable
# Processed: abominate
# Processed: abomination
# Processed: aboriginal
# Processed: abort
# Processed: abortion
# Processed: abortive
# Processed: abound
# Processed: abovementioned
# Processed: abracadabra
# Processed: abrasion
# Processed: abrasive
# Processed: abreast
# Processed: abroad
# Processed: abrogate
# Processed: abrupt
# Processed: abruptly
# Processed: abscess
# Processed: absence
# Processed: absent
# Processed: absentee
# Processed: absenteeism
# Processed: absinthe
# Processed: absolute
# Processed: absolution
# Processed: absolve
# Processed: absorb
# Processed: absorbed
# Processed: absorbent
# Processed: absorbing
# Processed: absorption
# Processed: abstain
# Processed: abstention
# Processed: abstinence
# Processed: abstract
# Processed: abstraction
# Processed: absurd
# Processed: absurdity
# Processed: abundance
# Processed: abundant
# Processed: abuse
# Processed: abused
# Processed: abusive
# Processed: abutment
# Processed: aby
# Processed: abysmal
# Processed: abyss
# Processed: academic
# Processed: academy
# Processed: accede
# Processed: accelerant
# Processed: accelerate
# Processed: accelerated
# Processed: acceleration
# Processed: accelerator
# Processed: accent
# Processed: accentuate
# Processed: accept
# Processed: acceptable
# Processed: acceptance
# Processed: acceptances
# Processed: access
# Processed: accessible
# Processed: accession
# Processed: accessory
# Processed: accident
# Processed: accidental
# Processed: accidentally
# Processed: acclaim
# Processed: accolade
# Processed: accommodate
# Processed: accommodation
# Processed: accompaniment
# Processed: accompany
# Processed: accompanying
# Processed: accomplice
# Processed: accomplish
# Processed: accomplished
# Processed: accomplishment
# Processed: accord
# Processed: accordance
# Processed: accordion
# Processed: account
# Processed: accountability
# Processed: accountable
# Processed: accountant
# Processed: accounting
# Processed: accounts
# Processed: accredited
# Processed: accretion
# Processed: accrue
# Processed: accueil
# Processed: accumulate
# Processed: accumulation
# Processed: accuracy
# Processed: accurate
# Processed: accursed
# Processed: accusation
# Processed: accusative
# Processed: accuse
# Processed: accused
# Processed: accuser
# Processed: accusing
# Processed: accustomed
# Processed: ace
# Processed: acetic
# Processed: acetylene
# Processed: ache
# Processed: achieve
# Processed: achieved
# Processed: achievement
# Processed: aching
# Processed: achy
# Processed: acid
# Processed: acidity
# Processed: acknowledge
# Processed: acknowledged
# Processed: acknowledgement
# Processed: acknowledgment
# Processed: acme
# Processed: acne
# Processed: acorn
# Processed: acoustic
# Processed: acoustics
# Processed: acquaint
# Processed: acquaintance
# Processed: acquainted
# Processed: acquiescence
# Processed: acquire
# Processed: acquiring
# Processed: acquisition
# Processed: acquisitions
# Processed: acquit
# Processed: acquittal
# Processed: acre
# Processed: acreage
# Processed: acres
# Processed: acrobat
# Processed: acrylic
# Processed: act
# Processed: acting
# Processed: action
# Processed: actionable
# Processed: activate
# Processed: activation
# Processed: active
# Processed: activist
# Processed: activity
# Processed: actor
# Processed: actress
# Processed: actual
# Processed: actuality
# Processed: actuary
# Processed: acuity
# Processed: acumen
# Processed: acupuncture
# Processed: acute
# Processed: acutely
# Processed: ad
# Processed: adage
# Processed: adamant
# Processed: adapt
# Processed: adaptable
# Processed: adaptation
# Processed: add
# Processed: added
# Processed: addendum
# Processed: adder
# Processed: addict
# Processed: addicted
# Processed: addiction
# Processed: addictive
# Processed: addition
# Processed: additional
# Processed: additive
# Processed: address
# Processed: addressee
# Processed: addresses
# Processed: adept
# Processed: adequacy
# Processed: adequate
# Processed: adhere
# Processed: adherence
# Processed: adherent
# Processed: adhering
# Processed: adhesion
# Processed: adhesive
# Processed: adieu
# Processed: adipose
# Processed: adjacency
# Processed: adjacent
# Processed: adjective
# Processed: adjoining
# Processed: adjourn
# Processed: adjournment
# Processed: adjudicate
# Processed: adjudication
# Processed: adjunct
# Processed: adjust
# Processed: adjuster
# Processed: adjustment
# Processed: adjuvant
# Processed: admin
# Processed: administer
# Processed: administration
# Processed: administrative
# Processed: administrator
# Processed: admirable
# Processed: admiral
# Processed: admiralty
# Processed: admiration
# Processed: admire
# Processed: admired
# Processed: admirer
# Processed: admiring
# Processed: admissibility
# Processed: admissible
# Processed: admission
# Processed: admit
# Processed: admittance
# Processed: admitted
# Processed: admitting
# Processed: admixture
# Processed: admonition
# Processed: ado
# Processed: adobe
# Processed: adolescence
# Processed: adolescent
# Processed: adopt
# Processed: adoption
# Processed: adoptive
# Processed: adorable
# Processed: adoration
# Processed: adore
# Processed: adoring
# Processed: adorn
# Processed: adornment
# Processed: adrenalin
# Processed: adrenaline
# Processed: adrift
# Processed: adult
# Processed: adulterated
# Processed: adulterer
# Processed: adultery
# Processed: adulthood
# Processed: advance
# Processed: advanced
# Processed: advancement
# Processed: advancing
# Processed: advantage
# Processed: advantageous
# Processed: advent
# Processed: adventure
# Processed: adventurer
# Processed: adventures
# Processed: adventurous
# Processed: adversary
# Processed: adverse
# Processed: adversity
# Processed: advertise
# Processed: advertisement
# Processed: advertising
# Processed: adverts
# Processed: advice
# Processed: advisable
# Processed: advise
# Processed: advised
# Processed: advisement
# Processed: adviser
# Processed: advisor
# Processed: advisory
# Processed: advocacy
# Processed: advocate
# Processed: aegis
# Processed: aeration
# Processed: aerial
# Processed: aerobics
# Processed: aerodrome
# Processed: aerodynamic
# Processed: aerodynamics
# Processed: aeronautics
# Processed: aeroplane
# Processed: aerospace
# Processed: aesthetic
# Processed: aesthetics
# Processed: aetiology
# Processed: afar
# Processed: affable
# Processed: affair
# Processed: affect
# Processed: affecting
# Processed: affection
# Processed: affectionate
# Processed: affections
# Processed: affiche
# Processed: affidavit
# Processed: affiliated
# Processed: affiliation
# Processed: affinity
# Processed: affirm
# Processed: affirmation
# Processed: affirmative
# Processed: affirmatively
# Processed: affix
# Processed: afflict
# Processed: afflicted
# Processed: affliction
# Processed: affluence
# Processed: affluent
# Processed: afford
# Processed: affordable
# Processed: affront
# Processed: affronted
# Processed: afield
# Processed: afire
# Processed: afloat
# Processed: afore
# Processed: aforementioned
# Processed: aforesaid
# Processed: afraid
# Processed: afresh
# Processed: aft
# Processed: afterlife
# Processed: aftermath
# Processed: afternoon
# Processed: aftershave
# Processed: aftertaste
# Processed: afterthought
# Processed: aga
# Processed: agape
# Processed: agate
# Processed: age
# Processed: aged
# Processed: agency
# Processed: agenda
# Processed: agent
# Processed: agglomeration
# Processed: aggravate
# Processed: aggravated
# Processed: aggravates
# Processed: aggravating
# Processed: aggravation
# Processed: aggregate
# Processed: aggregation
# Processed: aggresive
# Processed: aggression
# Processed: aggressive
# Processed: aggressively
# Processed: aggressiveness
# Processed: aggressor
# Processed: agh
# Processed: aghast
# Processed: aghhh
# Processed: agile
# Processed: agility
# Processed: aging
# Processed: agitate
# Processed: agitated
# Processed: agitation
# Processed: aglow
# Processed: agnostic
# Processed: ago
# Processed: agonizing
# Processed: agony
# Processed: agoraphobia
# Processed: agree
# Processed: agreeable
# Processed: agreed
# Processed: agreeing
# Processed: agreement
# Processed: agressive
# Processed: agricultural
# Processed: agriculture
# Processed: aground
# Processed: agua
# Processed: ahead
# Processed: ahhh
# Processed: ahhhhhhhh
# Processed: ahoy
# Processed: aid
# Processed: aide
# Processed: aiding
# Processed: aids
# Processed: ail
# Processed: ailing
# Processed: ailment
# Processed: aim
# Processed: aimless
# Processed: air
# Processed: airbag
# Processed: airborne
# Processed: aircraft
# Processed: airfield
# Processed: airhead
# Processed: airlift
# Processed: airline
# Processed: airliner
# Processed: airlock
# Processed: airman
# Processed: airplane
# Processed: airport
# Processed: airs
# Processed: airship
# Processed: airspace
# Processed: airspeed
# Processed: airstrip
# Processed: airtight
# Processed: airway
# Processed: aisle
# Processed: ait
# Processed: ajar
# Processed: aka
# Processed: akin
# Processed: alabaster
# Processed: alarm
# Processed: alarmed
# Processed: alarming
# Processed: alas
# Processed: alb
# Processed: albatross
# Processed: albino
# Processed: album
# Processed: alchemy
# Processed: alcohol
# Processed: alcoholic
# Processed: alcoholism
# Processed: alcove
# Processed: alderman
# Processed: ale
# Processed: alert
# Processed: alertness
# Processed: alerts
# Processed: alfalfa
# Processed: algebra
# Processed: algebraic
# Processed: algorithm
# Processed: alias
# Processed: alibi
# Processed: alien
# Processed: alienate
# Processed: alienated
# Processed: alienation
# Processed: alight
# Processed: align
# Processed: aligned
# Processed: alignment
# Processed: alike
# Processed: alimentation
# Processed: alimony
# Processed: aliquot
# Processed: alive
# Processed: alkali
# Processed: alkaloids
# Processed: allay
# Processed: allegation
# Processed: allege
# Processed: alleged
# Processed: allegiance
# Processed: allegorical
# Processed: allegory
# Processed: allegro
# Processed: allergic
# Processed: allergy
# Processed: alleviate
# Processed: alleviation
# Processed: alley
# Processed: alleyway
# Processed: alliance
# Processed: allied
# Processed: alligator
# Processed: allocate
# Processed: allocation
# Processed: allot
# Processed: allotment
# Processed: allow
# Processed: allowable
# Processed: allowance
# Processed: allowed
# Processed: alloy
# Processed: allsmiles
# Processed: allure
# Processed: alluring
# Processed: allusion
# Processed: alluvial
# Processed: ally
# Processed: almanac
# Processed: almighty
# Processed: almond
# Processed: aloft
# Processed: aloha
# Processed: alone
# Processed: alongside
# Processed: aloof
# Processed: aloud
# Processed: alpha
# Processed: alphabet
# Processed: alphabetical
# Processed: alpine
# Processed: alreadyyyyy
# Processed: altar
# Processed: alter
# Processed: alteration
# Processed: altercation
# Processed: altered
# Processed: alternate
# Processed: alternating
# Processed: alternative
# Processed: altimeter
# Processed: altitude
# Processed: alto
# Processed: altogether
# Processed: aluminum
# Processed: alumnus
# Processed: alveolar
# Processed: alzheimers
# Processed: amalgam
# Processed: amalgamation
# Processed: amaretto
# Processed: amass
# Processed: amateur
# Processed: amaze
# Processed: amazed
# Processed: amazedness
# Processed: amazement
# Processed: amazing
# Processed: amazingly
# Processed: ambassador
# Processed: amber
# Processed: ambience
# Processed: ambient
# Processed: ambiguity
# Processed: ambiguous
# Processed: ambit
# Processed: ambition
# Processed: ambitious
# Processed: ambivalent
# Processed: ambrosia
# Processed: ambulance
# Processed: ambush
# Processed: ameliorate
# Processed: amen
# Processed: amenable
# Processed: amend
# Processed: amendment
# Processed: amends
# Processed: amenity
# Processed: amethyst
# Processed: amiable
# Processed: amicable
# Processed: amid
# Processed: amidst
# Processed: amino
# Processed: ammo
# Processed: ammonia
# Processed: ammonium
# Processed: ammunition
# Processed: amnesia
# Processed: amnesty
# Processed: amorous
# Processed: amorphous
# Processed: amortization
# Processed: amount
# Processed: amour
# Processed: amp
# Processed: ampersand
# Processed: amphetamines
# Processed: amphibian
# Processed: amphibious
# Processed: amphitheater
# Processed: ample
# Processed: amplification
# Processed: amplify
# Processed: amplitude
# Processed: amply
# Processed: amputate
# Processed: amputation
# Processed: amuck
# Processed: amulet
# Processed: amuse
# Processed: amused
# Processed: amusement
# Processed: amusing
# Processed: ana
# Processed: anaconda
# Processed: anaesthesia
# Processed: anaesthetic
# Processed: anagram
# Processed: anal
# Processed: analgesic
# Processed: analogous
# Processed: analogue
# Processed: analogy
# Processed: analysis
# Processed: analyst
# Processed: analytic
# Processed: analytical
# Processed: analyze
# Processed: analyzer
# Processed: anaphylactic
# Processed: anarchism
# Processed: anarchist
# Processed: anarchy
# Processed: anastomosis
# Processed: anathema
# Processed: anatomic
# Processed: anatomy
# Processed: ancestor
# Processed: ancestral
# Processed: ancestry
# Processed: anchor
# Processed: anchorage
# Processed: ancient
# Processed: ancillary
# Processed: androgen
# Processed: android
# Processed: anecdote
# Processed: anemia
# Processed: anemic
# Processed: anemone
# Processed: anesthesia
# Processed: anesthesiologist
# Processed: anesthetic
# Processed: aneurysm
# Processed: anew
# Processed: angel
# Processed: angelic
# Processed: anger
# Processed: angered
# Processed: angermanagement
# Processed: angina
# Processed: angiogram
# Processed: angiography
# Processed: angle
# Processed: angling
# Processed: angora
# Processed: angriest
# Processed: angry
# Processed: angrytweet
# Processed: angst
# Processed: anguish
# Processed: anguished
# Processed: angular
# Processed: anhydrous
# Processed: animal
# Processed: animate
# Processed: animated
# Processed: animation
# Processed: animosity
# Processed: animus
# Processed: ankle
# Processed: anklet
# Processed: annals
# Processed: annex
# Processed: annexation
# Processed: annexe
# Processed: annihilate
# Processed: annihilated
# Processed: annihilation
# Processed: anniversary
# Processed: annotate
# Processed: annotation
# Processed: announce
# Processed: announcement
# Processed: announcer
# Processed: annoy
# Processed: annoyance
# Processed: annoyed
# Processed: annoyin
# Processed: annoying
# Processed: annoys
# Processed: annual
# Processed: annuity
# Processed: annul
# Processed: annular
# Processed: annulment
# Processed: annulus
# Processed: anointed
# Processed: anointing
# Processed: anomalous
# Processed: anomaly
# Processed: anon
# Processed: anonymity
# Processed: anonymous
# Processed: anorexic
# Processed: answer
# Processed: answerable
# Processed: answering
# Processed: ant
# Processed: antagonism
# Processed: antagonist
# Processed: antagonistic
# Processed: antagonize
# Processed: ante
# Processed: antecedent
# Processed: antelope
# Processed: antenna
# Processed: anterior
# Processed: anthem
# Processed: anthill
# Processed: anthology
# Processed: anthrax
# Processed: anthropological
# Processed: anthropologist
# Processed: anthropology
# Processed: anti
# Processed: antiaircraft
# Processed: antibiotic
# Processed: antibiotics
# Processed: antichrist
# Processed: anticipate
# Processed: anticipation
# Processed: anticipatory
# Processed: antics
# Processed: antidote
# Processed: antifungal
# Processed: antigravity
# Processed: antimony
# Processed: antipathy
# Processed: antiquarian
# Processed: antiquated
# Processed: antique
# Processed: antiques
# Processed: antiquity
# Processed: antiseptic
# Processed: antisocial
# Processed: antithesis
# Processed: antithetical
# Processed: antiviral
# Processed: antler
# Processed: antsy
# Processed: anus
# Processed: anvil
# Processed: anxiety
# Processed: anxietyattack
# Processed: anxious
# Processed: anxiousness
# Processed: anytime
# Processed: aorta
# Processed: aortic
# Processed: apace
# Processed: apache
# Processed: apartment
# Processed: apartments
# Processed: apathetic
# Processed: apathy
# Processed: ape
# Processed: aperture
# Processed: apex
# Processed: aphid
# Processed: aphrodisiac
# Processed: apiece
# Processed: aplomb
# Processed: apocalypse
# Processed: apocalyptic
# Processed: apologetic
# Processed: apologist
# Processed: apologize
# Processed: apology
# Processed: apostasy
# Processed: apostate
# Processed: apostle
# Processed: apostolic
# Processed: apostrophe
# Processed: apothecary
# Processed: appalled
# Processed: appalling
# Processed: apparatus
# Processed: apparel
# Processed: apparent
# Processed: apparently
# Processed: apparition
# Processed: appeal
# Processed: appear
# Processed: appearance
# Processed: appease
# Processed: appellant
# Processed: append
# Processed: appendage
# Processed: appendectomy
# Processed: appendicitis
# Processed: appendix
# Processed: appetite
# Processed: appetizer
# Processed: appetizing
# Processed: applaud
# Processed: applause
# Processed: apple
# Processed: applejack
# Processed: applesauce
# Processed: appliance
# Processed: appliances
# Processed: applicability
# Processed: applicable
# Processed: applicant
# Processed: application
# Processed: apply
# Processed: appoint
# Processed: appointment
# Processed: appointments
# Processed: apportion
# Processed: apportionment
# Processed: appraisal
# Processed: appraise
# Processed: appreciable
# Processed: appreciate
# Processed: appreciated
# Processed: appreciates
# Processed: appreciation
# Processed: appreciative
# Processed: apprehend
# Processed: apprehension
# Processed: apprehensive
# Processed: apprentice
# Processed: apprenticeship
# Processed: approach
# Processed: approaching
# Processed: approbate
# Processed: approbation
# Processed: appropriate
# Processed: appropriation
# Processed: approval
# Processed: approve
# Processed: approved
# Processed: approvement
# Processed: approving
# Processed: approximate
# Processed: approximately
# Processed: approximating
# Processed: approximation
# Processed: appurtenances
# Processed: apricot
# Processed: apron
# Processed: apt
# Processed: aptitude
# Processed: aqua
# Processed: aquamarine
# Processed: aquarium
# Processed: aquatic
# Processed: aqueduct
# Processed: aqueous
# Processed: arable
# Processed: arbiter
# Processed: arbitrary
# Processed: arbitrate
# Processed: arbitration
# Processed: arbitrator
# Processed: arbor
# Processed: arc
# Processed: arcade
# Processed: arcane
# Processed: arch
# Processed: archaeological
# Processed: archaeologist
# Processed: archaeology
# Processed: archaic
# Processed: archangel
# Processed: archbishop
# Processed: archdiocese
# Processed: archduke
# Processed: arched
# Processed: archer
# Processed: archery
# Processed: archetype
# Processed: archipelago
# Processed: architect
# Processed: architectural
# Processed: architecture
# Processed: archive
# Processed: arctic
# Processed: ardent
# Processed: ardor
# Processed: arduous
# Processed: area
# Processed: arena
# Processed: areola
# Processed: areyoukidding
# Processed: areyoukiddingme
# Processed: argent
# Processed: argh
# Processed: arghh
# Processed: arghhhh
# Processed: argue
# Processed: argument
# Processed: argumentation
# Processed: argumentative
# Processed: arguments
# Processed: arid
# Processed: arise
# Processed: aristocracy
# Processed: aristocrat
# Processed: aristocratic
# Processed: arithmetic
# Processed: ark
# Processed: arm
# Processed: armada
# Processed: armament
# Processed: armaments
# Processed: armature
# Processed: armchair
# Processed: armed
# Processed: armor
# Processed: armored
# Processed: armory
# Processed: armpit
# Processed: arms
# Processed: army
# Processed: aroma
# Processed: aromatherapy
# Processed: arousal
# Processed: arouse
# Processed: aroused
# Processed: arraignment
# Processed: arrange
# Processed: arranged
# Processed: arrangement
# Processed: array
# Processed: arrears
# Processed: arrest
# Processed: arrhythmia
# Processed: arrival
# Processed: arrive
# Processed: arrogance
# Processed: arrogant
# Processed: arrow
# Processed: arsehole
# Processed: arseholes
# Processed: arsenal
# Processed: arsenic
# Processed: arson
# Processed: arsonist
# Processed: art
# Processed: arterial
# Processed: artery
# Processed: artful
# Processed: arthritis
# Processed: arthropod
# Processed: artichoke
# Processed: article
# Processed: articles
# Processed: articulate
# Processed: articulation
# Processed: artifact
# Processed: artifice
# Processed: artificial
# Processed: artillery
# Processed: artisan
# Processed: artist
# Processed: artiste
# Processed: artistic
# Processed: artistry
# Processed: artists
# Processed: artwork
# Processed: arty
# Processed: asap
# Processed: asbestos
# Processed: ascend
# Processed: ascendancy
# Processed: ascendant
# Processed: ascending
# Processed: ascension
# Processed: ascent
# Processed: ascertain
# Processed: ascertained
# Processed: ascetic
# Processed: ash
# Processed: ashamed
# Processed: ashes
# Processed: ashtray
# Processed: asinine
# Processed: ask
# Processed: asleeep
# Processed: asleep
# Processed: asp
# Processed: asparagus
# Processed: aspartame
# Processed: aspect
# Processed: aspects
# Processed: aspen
# Processed: asphalt
# Processed: asphyxia
# Processed: asphyxiation
# Processed: aspiration
# Processed: aspire
# Processed: aspirin
# Processed: aspiring
# Processed: ass
# Processed: assail
# Processed: assailant
# Processed: assassin
# Processed: assassinate
# Processed: assassination
# Processed: assault
# Processed: assay
# Processed: assemblage
# Processed: assemble
# Processed: assembled
# Processed: assembly
# Processed: assemblyman
# Processed: assent
# Processed: assert
# Processed: asserting
# Processed: assertion
# Processed: assertive
# Processed: assess
# Processed: assessment
# Processed: assessor
# Processed: asset
# Processed: assets
# Processed: asshole
# Processed: assign
# Processed: assignee
# Processed: assignment
# Processed: assimilate
# Processed: assimilation
# Processed: assist
# Processed: assistance
# Processed: assistant
# Processed: associate
# Processed: association
# Processed: assorted
# Processed: assortment
# Processed: assuage
# Processed: assume
# Processed: assumed
# Processed: assuming
# Processed: assumption
# Processed: assurance
# Processed: assure
# Processed: assured
# Processed: assuredly
# Processed: asterisk
# Processed: asteroid
# Processed: asteroids
# Processed: asthma
# Processed: asthmatic
# Processed: astigmatism
# Processed: astonish
# Processed: astonished
# Processed: astonishing
# Processed: astonishingly
# Processed: astonishment
# Processed: astound
# Processed: astral
# Processed: astray
# Processed: astringent
# Processed: astrologer
# Processed: astrology
# Processed: astronaut
# Processed: astronomer
# Processed: astronomical
# Processed: astronomy
# Processed: astute
# Processed: asunder
# Processed: asylum
# Processed: asymmetric
# Processed: asymmetry
# Processed: asymptotic
# Processed: atelier
# Processed: atheism
# Processed: atheistic
# Processed: atherosclerosis
# Processed: athlete
# Processed: athletic
# Processed: athleticism
# Processed: athletics
# Processed: atlas
# Processed: atmosphere
# Processed: atmospheric
# Processed: atoll
# Processed: atom
# Processed: atomic
# Processed: atone
# Processed: atonement
# Processed: atpeace
# Processed: atrium
# Processed: atrocious
# Processed: atrocity
# Processed: atrophy
# Processed: attach
# Processed: attached
# Processed: attachment
# Processed: attack
# Processed: attacker
# Processed: attacking
# Processed: attain
# Processed: attainable
# Processed: attainment
# Processed: attempt
# Processed: attempted
# Processed: attend
# Processed: attendance
# Processed: attendant
# Processed: attention
# Processed: attentionseeker
# Processed: attentionseekers
# Processed: attentive
# Processed: attenuate
# Processed: attenuated
# Processed: attenuation
# Processed: attest
# Processed: attestation
# Processed: attic
# Processed: attire
# Processed: attitude
# Processed: attorney
# Processed: attract
# Processed: attraction
# Processed: attractive
# Processed: attractiveness
# Processed: attributable
# Processed: attribute
# Processed: attribution
# Processed: attrition
# Processed: auburn
# Processed: auction
# Processed: auctioneer
# Processed: audacious
# Processed: audacity
# Processed: audible
# Processed: audience
# Processed: audio
# Processed: audit
# Processed: audition
# Processed: auditions
# Processed: auditor
# Processed: auditorium
# Processed: auditory
# Processed: aught
# Processed: augment
# Processed: augmentation
# Processed: august
# Processed: aunt
# Processed: auntie
# Processed: aura
# Processed: aurora
# Processed: auspices
# Processed: auspicious
# Processed: austere
# Processed: austerity
# Processed: authentic
# Processed: authenticate
# Processed: authentication
# Processed: authenticity
# Processed: author
# Processed: authoritative
# Processed: authority
# Processed: authorization
# Processed: authorize
# Processed: authorized
# Processed: authorship
# Processed: autism
# Processed: autistic
# Processed: auto
# Processed: autobiographical
# Processed: autobiography
# Processed: autocorrect
# Processed: autocratic
# Processed: autograph
# Processed: autographed
# Processed: automated
# Processed: automatic
# Processed: automobile
# Processed: automotive
# Processed: autonomy
# Processed: autopilot
# Processed: autopsy
# Processed: autumn
# Processed: auxiliary
# Processed: avail
# Processed: availability
# Processed: available
# Processed: avalanche
# Processed: avarice
# Processed: avatar
# Processed: avenge
# Processed: avenger
# Processed: avenging
# Processed: avenue
# Processed: aver
# Processed: average
# Processed: aversation
# Processed: averse
# Processed: averseness
# Processed: aversion
# Processed: avert
# Processed: aviary
# Processed: aviation
# Processed: aviator
# Processed: avid
# Processed: avocado
# Processed: avoid
# Processed: avoidance
# Processed: avoiding
# Processed: await
# Processed: awake
# Processed: awaken
# Processed: awakening
# Processed: award
# Processed: awards
# Processed: aware
# Processed: awareness
# Processed: awe
# Processed: awed
# Processed: awesome
# Processed: awesomeness
# Processed: awestruck
# Processed: awful
# Processed: awkward
# Processed: awkwardness
# Processed: awning
# Processed: awry
# Processed: axe
# Processed: axial
# Processed: axiom
# Processed: axiomatic
# Processed: axis
# Processed: axle
# Processed: ay
# Processed: aye
# Processed: azimuth
# Processed: azure
# Processed: babble
# Processed: babbling
# Processed: babe
# Processed: baboon
# Processed: baby
# Processed: babysit
# Processed: babysitter
# Processed: baccalaureate
# Processed: baccarat
# Processed: bachelor
# Processed: bachelorette
# Processed: back
# Processed: backboard
# Processed: backbone
# Processed: backdoor
# Processed: backdrop
# Processed: backer
# Processed: backfire
# Processed: backgammon
# Processed: background
# Processed: backhand
# Processed: backhoe
# Processed: backoff
# Processed: backpack
# Processed: backpacker
# Processed: backroom
# Processed: backseat
# Processed: backside
# Processed: backtrack
# Processed: backup
# Processed: backward
# Processed: backwardness
# Processed: backwards
# Processed: backwater
# Processed: backwoods
# Processed: backyard
# Processed: bacon
# Processed: bacteria
# Processed: bacterial
# Processed: bacterium
# Processed: bad
# Processed: badass
# Processed: badday
# Processed: badfeeling
# Processed: badge
# Processed: badger
# Processed: badhabit
# Processed: badly
# Processed: badness
# Processed: baffle
# Processed: baffled
# Processed: bag
# Processed: bagel
# Processed: baggage
# Processed: baggie
# Processed: baggy
# Processed: bagman
# Processed: bagpipes
# Processed: bail
# Processed: bailiff
# Processed: bait
# Processed: bake
# Processed: bakery
# Processed: baking
# Processed: bal
# Processed: balance
# Processed: balanced
# Processed: balcony
# Processed: bald
# Processed: balding
# Processed: baldy
# Processed: bale
# Processed: balk
# Processed: ball
# Processed: ballad
# Processed: ballast
# Processed: ballerina
# Processed: ballet
# Processed: ballgame
# Processed: ballistic
# Processed: ballistics
# Processed: balloon
# Processed: ballot
# Processed: ballpark
# Processed: ballplayer
# Processed: ballpoint
# Processed: ballroom
# Processed: ballsy
# Processed: balm
# Processed: balmy
# Processed: balsam
# Processed: balsamic
# Processed: bam
# Processed: bamboo
# Processed: ban
# Processed: banana
# Processed: band
# Processed: bandage
# Processed: bandanna
# Processed: bandit
# Processed: bandstand
# Processed: bandwagon
# Processed: bandwidth
# Processed: bane
# Processed: bang
# Processed: banger
# Processed: banish
# Processed: banished
# Processed: banishment
# Processed: banister
# Processed: banjo
# Processed: bank
# Processed: banker
# Processed: banking
# Processed: bankroll
# Processed: bankrupt
# Processed: bankruptcy
# Processed: banner
# Processed: banquet
# Processed: banshee
# Processed: banter
# Processed: banzai
# Processed: baptism
# Processed: baptismal
# Processed: baptize
# Processed: bar
# Processed: barb
# Processed: barbarian
# Processed: barbaric
# Processed: barbarism
# Processed: barbecue
# Processed: barbed
# Processed: barber
# Processed: barbershop
# Processed: bard
# Processed: bare
# Processed: bareback
# Processed: barefoot
# Processed: barely
# Processed: barf
# Processed: bargain
# Processed: bargaining
# Processed: barge
# Processed: baritone
# Processed: barium
# Processed: bark
# Processed: barkeep
# Processed: barks
# Processed: barley
# Processed: barmaid
# Processed: barman
# Processed: barn
# Processed: barnacle
# Processed: barney
# Processed: barnyard
# Processed: barometer
# Processed: baron
# Processed: baroness
# Processed: baroque
# Processed: barrack
# Processed: barracuda
# Processed: barrage
# Processed: barred
# Processed: barrel
# Processed: barren
# Processed: barricade
# Processed: barrier
# Processed: barring
# Processed: barrister
# Processed: barroom
# Processed: barrow
# Processed: bartender
# Processed: barter
# Processed: base
# Processed: baseball
# Processed: baseboard
# Processed: baseless
# Processed: baseline
# Processed: baseman
# Processed: basement
# Processed: bases
# Processed: bash
# Processed: bashful
# Processed: basic
# Processed: basics
# Processed: basil
# Processed: basilica
# Processed: basin
# Processed: basis
# Processed: bask
# Processed: basket
# Processed: basketball
# Processed: bass
# Processed: basso
# Processed: bassoon
# Processed: bastard
# Processed: bastarding
# Processed: bastards
# Processed: bastion
# Processed: bat
# Processed: batch
# Processed: batching
# Processed: bate
# Processed: bath
# Processed: bathe
# Processed: bathhouse
# Processed: bathing
# Processed: bathrobe
# Processed: bathroom
# Processed: bathtub
# Processed: bathymetry
# Processed: baton
# Processed: battalion
# Processed: batter
# Processed: battered
# Processed: battering
# Processed: battery
# Processed: battle
# Processed: battled
# Processed: battlefield
# Processed: battleground
# Processed: battlements
# Processed: battleship
# Processed: batty
# Processed: bauble
# Processed: bawdy
# Processed: bawl
# Processed: bay
# Processed: bayonet
# Processed: bayou
# Processed: bazaar
# Processed: bazooka
# Processed: bday
# Processed: be
# Processed: beach
# Processed: beaches
# Processed: beacon
# Processed: bead
# Processed: beading
# Processed: beads
# Processed: beady
# Processed: beagle
# Processed: beak
# Processed: beaker
# Processed: beam
# Processed: beaming
# Processed: bean
# Processed: beanbag
# Processed: beanie
# Processed: bear
# Processed: bearable
# Processed: beard
# Processed: bearded
# Processed: bearer
# Processed: bearing
# Processed: bearings
# Processed: bearish
# Processed: bearskin
# Processed: beast
# Processed: beastly
# Processed: beat
# Processed: beaten
# Processed: beater
# Processed: beating
# Processed: beatnik
# Processed: beau
# Processed: beautification
# Processed: beautiful
# Processed: beautify
# Processed: beauty
# Processed: beaver
# Processed: bebop
# Processed: beck
# Processed: beckon
# Processed: become
# Processed: bed
# Processed: bedding
# Processed: bedpan
# Processed: bedrock
# Processed: bedroom
# Processed: bedside
# Processed: bedspread
# Processed: bedtime
# Processed: bee
# Processed: beef
# Processed: beefsteak
# Processed: beehive
# Processed: beep
# Processed: beeper
# Processed: beer
# Processed: bees
# Processed: beeswax
# Processed: beetle
# Processed: befall
# Processed: befitting
# Processed: befriend
# Processed: befuddled
# Processed: beg
# Processed: beggar
# Processed: begging
# Processed: begin
# Processed: beginner
# Processed: beginning
# Processed: beginnings
# Processed: begrudge
# Processed: begun
# Processed: behappy
# Processed: behave
# Processed: behavior
# Processed: behavioral
# Processed: behemoth
# Processed: behest
# Processed: behold
# Processed: beholden
# Processed: beholder
# Processed: beige
# Processed: belated
# Processed: belay
# Processed: belch
# Processed: belief
# Processed: believable
# Processed: believe
# Processed: believed
# Processed: believer
# Processed: believing
# Processed: belittle
# Processed: belittled
# Processed: bell
# Processed: bellboy
# Processed: bellhop
# Processed: belligerent
# Processed: bellman
# Processed: bellow
# Processed: bellows
# Processed: belly
# Processed: bellybutton
# Processed: bellyful
# Processed: belong
# Processed: belongings
# Processed: beloved
# Processed: belt
# Processed: beluga
# Processed: bemused
# Processed: bench
# Processed: bend
# Processed: bender
# Processed: bending
# Processed: beneath
# Processed: benedictory
# Processed: benefactor
# Processed: beneficial
# Processed: beneficiary
# Processed: benefit
# Processed: benevolence
# Processed: benevolent
# Processed: benign
# Processed: bent
# Processed: benzene
# Processed: bequeath
# Processed: bequest
# Processed: bereaved
# Processed: bereavement
# Processed: bereft
# Processed: beret
# Processed: bergamot
# Processed: berlin
# Processed: berserk
# Processed: berth
# Processed: beryllium
# Processed: beseech
# Processed: beset
# Processed: bestdayever
# Processed: bestfeeling
# Processed: bestfriends
# Processed: bestial
# Processed: besties
# Processed: bestow
# Processed: bestseller
# Processed: bet
# Processed: beta
# Processed: betray
# Processed: betrayal
# Processed: betrayed
# Processed: betrothed
# Processed: betterment
# Processed: betting
# Processed: betty
# Processed: bevel
# Processed: beverage
# Processed: bevy
# Processed: beware
# Processed: bewilder
# Processed: bewildered
# Processed: bewilderment
# Processed: bias
# Processed: biased
# Processed: bib
# Processed: bible
# Processed: biblical
# Processed: bibliography
# Processed: bicarbonate
# Processed: bicentennial
# Processed: biceps
# Processed: bicker
# Processed: bickering
# Processed: bicolor
# Processed: bicycle
# Processed: bid
# Processed: bidder
# Processed: bidding
# Processed: bide
# Processed: biennial
# Processed: bier
# Processed: bifurcation
# Processed: big
# Processed: bigamy
# Processed: bigday
# Processed: biggestfear
# Processed: biggie
# Processed: bighorn
# Processed: bigmouth
# Processed: bigot
# Processed: bigoted
# Processed: bigotry
# Processed: bike
# Processed: biker
# Processed: bikini
# Processed: bilateral
# Processed: bilayer
# Processed: bile
# Processed: bilge
# Processed: bilingual
# Processed: bill
# Processed: billboard
# Processed: billet
# Processed: billiard
# Processed: billiards
# Processed: billing
# Processed: billion
# Processed: billionaire
# Processed: billy
# Processed: bimbo
# Processed: bimonthly
# Processed: bin
# Processed: binary
# Processed: bind
# Processed: binder
# Processed: bindery
# Processed: binding
# Processed: bing
# Processed: binge
# Processed: bingo
# Processed: binocular
# Processed: binoculars
# Processed: binomial
# Processed: bio
# Processed: biochemical
# Processed: biochemist
# Processed: biochemistry
# Processed: biogenesis
# Processed: biographer
# Processed: biography
# Processed: biological
# Processed: biologist
# Processed: biology
# Processed: bionic
# Processed: biopsy
# Processed: biosphere
# Processed: bipartite
# Processed: bipolar
# Processed: birch
# Processed: bird
# Processed: birdcage
# Processed: birdie
# Processed: birdman
# Processed: birth
# Processed: birthday
# Processed: birthing
# Processed: birthmark
# Processed: birthplace
# Processed: birthright
# Processed: bis
# Processed: biscuit
# Processed: bishop
# Processed: bison
# Processed: bisque
# Processed: bistro
# Processed: bit
# Processed: bitch
# Processed: bitchy
# Processed: bite
# Processed: biter
# Processed: bitsy
# Processed: bitter
# Processed: bitterly
# Processed: bitterness
# Processed: bittersweet
# Processed: bitty
# Processed: bitumen
# Processed: biweekly
# Processed: biz
# Processed: bizarre
# Processed: blab
# Processed: blabbermouth
# Processed: blackberry
# Processed: blackbird
# Processed: blackboard
# Processed: blacken
# Processed: blackface
# Processed: blackjack
# Processed: blacklist
# Processed: blackmail
# Processed: blackmailer
# Processed: blackness
# Processed: blackout
# Processed: blacksmith
# Processed: bladder
# Processed: blade
# Processed: blame
# Processed: blameless
# Processed: bland
# Processed: blank
# Processed: blanket
# Processed: blare
# Processed: blase
# Processed: blasphemous
# Processed: blasphemy
# Processed: blast
# Processed: blaster
# Processed: blastoff
# Processed: blatant
# Processed: blather
# Processed: blaze
# Processed: blazer
# Processed: blazing
# Processed: bleach
# Processed: bleak
# Processed: bleed
# Processed: bleeder
# Processed: bleeding
# Processed: bleep
# Processed: blemish
# Processed: blemished
# Processed: blend
# Processed: blender
# Processed: blending
# Processed: bless
# Processed: blessed
# Processed: blessing
# Processed: blessings
# Processed: bleu
# Processed: blight
# Processed: blighted
# Processed: blimp
# Processed: blinded
# Processed: blindfold
# Processed: blindfolded
# Processed: blinding
# Processed: blindly
# Processed: blindness
# Processed: blink
# Processed: blip
# Processed: bliss
# Processed: blissful
# Processed: blister
# Processed: blistering
# Processed: blitz
# Processed: blizzard
# Processed: bloat
# Processed: bloated
# Processed: blob
# Processed: block
# Processed: blockade
# Processed: blockage
# Processed: blockbuster
# Processed: blockhead
# Processed: blog
# Processed: bloke
# Processed: blond
# Processed: blonde
# Processed: blood
# Processed: bloodbath
# Processed: bloodhound
# Processed: bloodless
# Processed: bloodline
# Processed: bloodshed
# Processed: bloodshot
# Processed: bloodstream
# Processed: bloodthirsty
# Processed: bloody
# Processed: bloom
# Processed: bloomers
# Processed: blooming
# Processed: blossom
# Processed: blot
# Processed: blotched
# Processed: blotter
# Processed: blouse
# Processed: blow
# Processed: blower
# Processed: blowfish
# Processed: blowing
# Processed: blowjob
# Processed: blown
# Processed: blowout
# Processed: blowtorch
# Processed: blubber
# Processed: bluddy
# Processed: blue
# Processed: blueberry
# Processed: bluebird
# Processed: bluegrass
# Processed: bluejay
# Processed: blueprint
# Processed: blues
# Processed: bluff
# Processed: bluish
# Processed: blunder
# Processed: blunt
# Processed: blur
# Processed: blurred
# Processed: blurry
# Processed: blurt
# Processed: blush
# Processed: blushing
# Processed: boa
# Processed: boar
# Processed: board
# Processed: boarder
# Processed: boarding
# Processed: boardroom
# Processed: boards
# Processed: boardwalk
# Processed: boast
# Processed: boastful
# Processed: boasting
# Processed: boat
# Processed: boathouse
# Processed: boating
# Processed: boatload
# Processed: boatman
# Processed: bobbin
# Processed: bobcat
# Processed: bobsled
# Processed: bode
# Processed: bodega
# Processed: bodice
# Processed: bodily
# Processed: body
# Processed: bodyguard
# Processed: bog
# Processed: bogey
# Processed: bogeyman
# Processed: bogus
# Processed: bohemian
# Processed: boil
# Processed: boiler
# Processed: boilerplate
# Processed: boiling
# Processed: boisterous
# Processed: bold
# Processed: boldness
# Processed: bollocks
# Processed: bolster
# Processed: bolt
# Processed: bolus
# Processed: bomb
# Processed: bombard
# Processed: bombardier
# Processed: bombardment
# Processed: bombed
# Processed: bomber
# Processed: bombers
# Processed: bombing
# Processed: bombshell
# Processed: bonanza
# Processed: bonbon
# Processed: bond
# Processed: bondage
# Processed: bonding
# Processed: bonds
# Processed: bondsman
# Processed: bone
# Processed: bonehead
# Processed: boner
# Processed: bones
# Processed: bonfire
# Processed: bong
# Processed: bonkers
# Processed: bonne
# Processed: bonnet
# Processed: bonny
# Processed: bonsai
# Processed: bonus
# Processed: bony
# Processed: boo
# Processed: boob
# Processed: booby
# Processed: booger
# Processed: boogeyman
# Processed: boogie
# Processed: book
# Processed: bookcase
# Processed: bookie
# Processed: booking
# Processed: bookish
# Processed: bookkeeper
# Processed: bookkeeping
# Processed: booklet
# Processed: bookmaker
# Processed: bookmark
# Processed: books
# Processed: bookseller
# Processed: bookshop
# Processed: bookstore
# Processed: bookworm
# Processed: boom
# Processed: boomer
# Processed: boomerang
# Processed: booming
# Processed: boon
# Processed: boooo
# Processed: boost
# Processed: booster
# Processed: boot
# Processed: booth
# Processed: bootleg
# Processed: bootlegger
# Processed: boots
# Processed: booty
# Processed: booze
# Processed: bop
# Processed: bopper
# Processed: border
# Processed: bordering
# Processed: borderline
# Processed: bore
# Processed: boreal
# Processed: bored
# Processed: boredom
# Processed: borer
# Processed: boring
# Processed: born
# Processed: boron
# Processed: borough
# Processed: borrow
# Processed: borrower
# Processed: bosom
# Processed: boss
# Processed: bossy
# Processed: boston
# Processed: botanical
# Processed: botanist
# Processed: botany
# Processed: bother
# Processed: bothering
# Processed: bottle
# Processed: bottleneck
# Processed: bottling
# Processed: bottom
# Processed: bottomless
# Processed: botulism
# Processed: boulder
# Processed: bounce
# Processed: bouncer
# Processed: bouncy
# Processed: bound
# Processed: boundary
# Processed: boundless
# Processed: bounds
# Processed: bountiful
# Processed: bounty
# Processed: bouquet
# Processed: bourbon
# Processed: bourgeois
# Processed: bourgeoisie
# Processed: bourse
# Processed: bout
# Processed: boutique
# Processed: bouttime
# Processed: bovine
# Processed: bow
# Processed: bowed
# Processed: bowel
# Processed: bowels
# Processed: bowl
# Processed: bowler
# Processed: bowling
# Processed: bowls
# Processed: box
# Processed: boxcar
# Processed: boxer
# Processed: boxers
# Processed: boxing
# Processed: boycott
# Processed: boyfriend
# Processed: boyhood
# Processed: boyish
# Processed: boysenberry
# Processed: bozo
# Processed: bra
# Processed: brace
# Processed: bracelet
# Processed: braces
# Processed: brachial
# Processed: bracket
# Processed: brackets
# Processed: brackish
# Processed: brad
# Processed: brag
# Processed: braid
# Processed: brain
# Processed: brainless
# Processed: brains
# Processed: brainstorm
# Processed: brainwash
# Processed: brainy
# Processed: brake
# Processed: bran
# Processed: branch
# Processed: branching
# Processed: brand
# Processed: brandy
# Processed: brash
# Processed: brass
# Processed: brassiere
# Processed: brat
# Processed: bratwurst
# Processed: bravado
# Processed: brave
# Processed: bravery
# Processed: brawl
# Processed: brawn
# Processed: brazen
# Processed: breach
# Processed: bread
# Processed: breadth
# Processed: break
# Processed: breakable
# Processed: breakaway
# Processed: breakdown
# Processed: breaker
# Processed: breakers
# Processed: breakfast
# Processed: breakingnews
# Processed: breakneck
# Processed: breakthrough
# Processed: breakup
# Processed: breast
# Processed: breath
# Processed: breathe
# Processed: breather
# Processed: breathless
# Processed: breathtaking
# Processed: breech
# Processed: breeches
# Processed: breed
# Processed: breeder
# Processed: breeding
# Processed: breeze
# Processed: breezy
# Processed: brethren
# Processed: breve
# Processed: brevity
# Processed: brew
# Processed: brewery
# Processed: brewing
# Processed: briar
# Processed: bribe
# Processed: bribery
# Processed: brick
# Processed: bridal
# Processed: bride
# Processed: bridegroom
# Processed: bridesmaid
# Processed: bridge
# Processed: bridle
# Processed: brief
# Processed: briefcase
# Processed: briefing
# Processed: briefly
# Processed: brig
# Processed: brigade
# Processed: bright
# Processed: brighten
# Processed: brightens
# Processed: brighter
# Processed: brightness
# Processed: brilliance
# Processed: brilliant
# Processed: brim
# Processed: brimming
# Processed: brimstone
# Processed: brine
# Processed: bring
# Processed: brink
# Processed: brisk
# Processed: brisket
# Processed: bristle
# Processed: brittle
# Processed: bro
# Processed: broach
# Processed: broad
# Processed: broadcast
# Processed: broadcasting
# Processed: broaden
# Processed: broadside
# Processed: broadsword
# Processed: brocade
# Processed: broccoli
# Processed: brochure
# Processed: broil
# Processed: broke
# Processed: broken
# Processed: brokenheart
# Processed: brokenhearted
# Processed: broker
# Processed: brokerage
# Processed: bromide
# Processed: bronco
# Processed: bronze
# Processed: brooch
# Processed: brood
# Processed: brooding
# Processed: brook
# Processed: broom
# Processed: broomstick
# Processed: broth
# Processed: brothel
# Processed: brother
# Processed: brotherhood
# Processed: brotherly
# Processed: brow
# Processed: brown
# Processed: brownstone
# Processed: browse
# Processed: brrr
# Processed: bruise
# Processed: bruising
# Processed: brunch
# Processed: brunette
# Processed: brunt
# Processed: brush
# Processed: brutal
# Processed: brutality
# Processed: brute
# Processed: brutish
# Processed: bubble
# Processed: bubbling
# Processed: bubbly
# Processed: bubonic
# Processed: buck
# Processed: buckaroo
# Processed: bucket
# Processed: buckle
# Processed: buckled
# Processed: bucko
# Processed: buckshot
# Processed: buckwheat
# Processed: bud
# Processed: buddha
# Processed: buddhism
# Processed: budding
# Processed: buddy
# Processed: budge
# Processed: budget
# Processed: buff
# Processed: buffalo
# Processed: buffer
# Processed: buffering
# Processed: buffet
# Processed: buffoon
# Processed: bug
# Processed: bugaboo
# Processed: bugged
# Processed: bugger
# Processed: buggy
# Processed: bugle
# Processed: bugler
# Processed: build
# Processed: builder
# Processed: building
# Processed: buildings
# Processed: buildup
# Processed: bulb
# Processed: bulbous
# Processed: bulge
# Processed: bulimic
# Processed: bulk
# Processed: bulkhead
# Processed: bulky
# Processed: bull
# Processed: bulldog
# Processed: bulldozer
# Processed: bullet
# Processed: bulletin
# Processed: bulletproof
# Processed: bullfighter
# Processed: bullfrog
# Processed: bullheaded
# Processed: bullhorn
# Processed: bullion
# Processed: bullock
# Processed: bullpen
# Processed: bullshit
# Processed: bully
# Processed: bulwark
# Processed: bum
# Processed: bumblebee
# Processed: bummed
# Processed: bummer
# Processed: bump
# Processed: bumper
# Processed: bumpy
# Processed: bun
# Processed: bunch
# Processed: bundle
# Processed: bungalow
# Processed: bungee
# Processed: bunghole
# Processed: bunion
# Processed: bunk
# Processed: bunker
# Processed: bunkhouse
# Processed: bunny
# Processed: bunt
# Processed: buoy
# Processed: buoyancy
# Processed: buoyant
# Processed: bur
# Processed: burden
# Processed: burdened
# Processed: burdensome
# Processed: bureau
# Processed: bureaucracy
# Processed: bureaucrat
# Processed: bureaucratic
# Processed: burger
# Processed: burglar
# Processed: burglary
# Processed: burial
# Processed: buried
# Processed: burke
# Processed: burlap
# Processed: burlesque
# Processed: burly
# Processed: burn
# Processed: burned
# Processed: burner
# Processed: burning
# Processed: burnished
# Processed: burnout
# Processed: burnt
# Processed: burp
# Processed: burr
# Processed: burrito
# Processed: burro
# Processed: burrow
# Processed: bursary
# Processed: burst
# Processed: bury
# Processed: bus
# Processed: busboy
# Processed: bush
# Processed: bushel
# Processed: bushy
# Processed: business
# Processed: businessman
# Processed: businesswoman
# Processed: busload
# Processed: buss
# Processed: bust
# Processed: busted
# Processed: buster
# Processed: bustle
# Processed: bustling
# Processed: busy
# Processed: busybody
# Processed: butane
# Processed: butcher
# Processed: butler
# Processed: butt
# Processed: butter
# Processed: buttercup
# Processed: butterfly
# Processed: buttermilk
# Processed: butterscotch
# Processed: buttery
# Processed: buttock
# Processed: buttocks
# Processed: button
# Processed: buttress
# Processed: buxom
# Processed: buy
# Processed: buyer
# Processed: buying
# Processed: buzz
# Processed: buzzard
# Processed: buzzed
# Processed: buzzer
# Processed: buzzing
# Processed: bye
# Processed: bygone
# Processed: bylaw
# Processed: byline
# Processed: bypass
# Processed: bystander
# Processed: byte
# Processed: byzantine
# Processed: cab
# Processed: cabal
# Processed: cabana
# Processed: cabaret
# Processed: cabbage
# Processed: cabbie
# Processed: cabernet
# Processed: cabin
# Processed: cabinet
# Processed: cable
# Processed: caboodle
# Processed: caboose
# Processed: cabriolet
# Processed: cache
# Processed: cacophony
# Processed: cactus
# Processed: cad
# Processed: cadaver
# Processed: caddie
# Processed: caddy
# Processed: cadence
# Processed: cadet
# Processed: cafe
# Processed: cafeteria
# Processed: caffeine
# Processed: cage
# Processed: cagey
# Processed: cahoots
# Processed: cairn
# Processed: cake
# Processed: cakewalk
# Processed: calamari
# Processed: calamitous
# Processed: calamity
# Processed: calcareous
# Processed: calcium
# Processed: calculate
# Processed: calculated
# Processed: calculating
# Processed: calculation
# Processed: calculator
# Processed: calculus
# Processed: calendar
# Processed: calender
# Processed: calf
# Processed: caliber
# Processed: calibrate
# Processed: calico
# Processed: calipers
# Processed: calisthenics
# Processed: call
# Processed: callback
# Processed: caller
# Processed: calligraphy
# Processed: calling
# Processed: callous
# Processed: calls
# Processed: calm
# Processed: calming
# Processed: calmness
# Processed: caloric
# Processed: calorie
# Processed: calorimeter
# Processed: cam
# Processed: camaraderie
# Processed: camber
# Processed: camcorder
# Processed: camel
# Processed: cameo
# Processed: camera
# Processed: cameraman
# Processed: camisole
# Processed: camouflage
# Processed: camouflaged
# Processed: camp
# Processed: campaign
# Processed: campaigner
# Processed: campaigning
# Processed: camper
# Processed: campfire
# Processed: camping
# Processed: campsite
# Processed: campus
# Processed: can
# Processed: canal
# Processed: canary
# Processed: cancel
# Processed: canceling
# Processed: cancellation
# Processed: cancer
# Processed: candid
# Processed: candidacy
# Processed: candidate
# Processed: candied
# Processed: candle
# Processed: candlelight
# Processed: candles
# Processed: candlestick
# Processed: candor
# Processed: candy
# Processed: cane
# Processed: canine
# Processed: canister
# Processed: canker
# ...
# Processed: variegated
# Processed: variety
# Processed: various
# Processed: varmint
# Processed: varnish
# Processed: varsity
# Processed: vary
# Processed: varying
# Processed: vascular
# Processed: vase
# Processed: vasectomy
# Processed: vassal
# Processed: vast
# Processed: vat
# Processed: vaudeville
# Processed: vault
# Processed: vaulted
# Processed: vaulting
# Processed: veal
# Processed: vector
# Processed: veer
# Processed: vega
# Processed: vegan
# Processed: vegetable
# Processed: vegetarian
# Processed: vegetarianism
# Processed: vegetation
# Processed: vegetative
# Processed: veggie
# Processed: vehement
# Processed: vehicle
# Processed: veil
# Processed: veiled
# Processed: vein
# Processed: veined
# Processed: vellum
# Processed: velocity
# Processed: velour
# Processed: velvet
# Processed: velvety
# Processed: vena
# Processed: vendetta
# Processed: vending
# Processed: vendor
# Processed: veneer
# Processed: venerable
# Processed: veneration
# Processed: venereal
# Processed: venetian
# Processed: vengeance
# Processed: vengeful
# Processed: venison
# Processed: venom
# Processed: venomous
# Processed: venous
# Processed: vent
# Processed: ventilation
# Processed: ventilator
# Processed: venting
# Processed: ventricle
# Processed: ventricular
# Processed: ventriloquist
# Processed: venture
# Processed: venue
# Processed: veracity
# Processed: veranda
# Processed: verb
# Processed: verbal
# Processed: verbatim
# Processed: verbiage
# Processed: verbose
# Processed: verbosity
# Processed: verdant
# Processed: verdict
# Processed: verge
# Processed: verification
# Processed: verified
# Processed: verify
# Processed: verily
# Processed: veritable
# Processed: vermin
# Processed: vermouth
# Processed: vernacular
# Processed: vernal
# Processed: veronica
# Processed: versatile
# Processed: versatility
# Processed: verse
# Processed: version
# Processed: versus
# Processed: vert
# Processed: vertebra
# Processed: vertebral
# Processed: vertex
# Processed: vertical
# Processed: vertically
# Processed: vertigo
# Processed: verve
# Processed: veryangry
# Processed: vesicle
# Processed: vesicular
# Processed: vessel
# Processed: vest
# Processed: vested
# Processed: vestibule
# Processed: vestige
# Processed: vet
# Processed: veteran
# Processed: veterinarian
# Processed: veterinary
# Processed: veto
# Processed: vexed
# Processed: viability
# Processed: viable
# Processed: viaduct
# Processed: vial
# Processed: vibe
# Processed: vibes
# Processed: vibrant
# Processed: vibrate
# Processed: vibration
# Processed: vibrator
# Processed: vibratory
# Processed: vicar
# Processed: vicarious
# Processed: vice
# Processed: viceroy
# Processed: vicinity
# Processed: vicious
# Processed: victim
# Processed: victimized
# Processed: victor
# Processed: victoria
# Processed: victorious
# Processed: victory
# Processed: video
# Processed: videotape
# Processed: vie
# Processed: view
# Processed: viewer
# Processed: viewing
# Processed: viewpoint
# Processed: vigil
# Processed: vigilance
# Processed: vigilant
# Processed: vigilante
# Processed: vignette
# Processed: vigor
# Processed: vigorous
# Processed: viking
# Processed: vile
# Processed: villa
# Processed: village
# Processed: villager
# Processed: villain
# Processed: villainous
# Processed: vinaigrette
# Processed: vindicate
# Processed: vindicated
# Processed: vindication
# Processed: vindictive
# Processed: vine
# Processed: vinegar
# Processed: vineyard
# Processed: vintage
# Processed: vinyl
# Processed: viola
# Processed: violate
# Processed: violation
# Processed: violence
# Processed: violent
# Processed: violently
# Processed: violet
# Processed: violin
# Processed: violinist
# Processed: viper
# Processed: viral
# Processed: virgin
# Processed: virginal
# Processed: virginity
# Processed: virility
# Processed: virology
# Processed: virtual
# Processed: virtually
# Processed: virtue
# Processed: virtuoso
# Processed: virtuous
# Processed: virulence
# Processed: virus
# Processed: visa
# Processed: visage
# Processed: viscosity
# Processed: viscous
# Processed: vise
# Processed: visibility
# Processed: visible
# Processed: visibly
# Processed: vision
# Processed: visionary
# Processed: visit
# Processed: visitation
# Processed: visiting
# Processed: visitor
# Processed: visor
# Processed: vista
# Processed: visual
# Processed: visualize
# Processed: vital
# Processed: vitality
# Processed: vitals
# Processed: vitamin
# Processed: vitreous
# Processed: viva
# Processed: vivacious
# Processed: vivid
# Processed: vixen
# Processed: vocabulary
# Processed: vocal
# Processed: vocalist
# Processed: vocation
# Processed: vodka
# Processed: vogue
# Processed: voice
# Processed: voiceless
# Processed: voicemail
# Processed: void
# Processed: volatile
# Processed: volatility
# Processed: volcanic
# Processed: volcano
# Processed: volition
# Processed: volley
# Processed: volleyball
# Processed: voltage
# Processed: voltmeter
# Processed: volume
# Processed: volumes
# Processed: voluminous
# Processed: voluntarily
# Processed: voluntary
# Processed: volunteer
# Processed: volunteering
# Processed: volunteers
# Processed: voluptuous
# Processed: vomit
# Processed: vomiting
# Processed: voodoo
# Processed: voracious
# Processed: vortex
# Processed: vote
# Processed: voter
# Processed: voting
# Processed: votive
# Processed: vouch
# Processed: voucher
# Processed: vow
# Processed: vowel
# Processed: voyage
# Processed: voyager
# Processed: voyeur
# Processed: vulgar
# Processed: vulgarity
# Processed: vulnerability
# Processed: vulnerable
# Processed: vulture
# Processed: wacko
# Processed: wacky
# Processed: wad
# Processed: waddle
# Processed: wade
# Processed: wafer
# Processed: waffle
# Processed: wag
# Processed: wage
# Processed: wager
# Processed: wages
# Processed: wagon
# Processed: wail
# Processed: waist
# Processed: waistcoat
# Processed: waistline
# Processed: wait
# Processed: waiter
# Processed: waiting
# Processed: waitinggame
# Processed: waitress
# Processed: waive
# Processed: waiver
# Processed: wake
# Processed: walk
# Processed: walker
# Processed: walking
# Processed: walkout
# Processed: wall
# Processed: wallaby
# Processed: wallet
# Processed: wallflower
# Processed: wallop
# Processed: wallow
# Processed: wallpaper
# Processed: walnut
# Processed: walrus
# Processed: waltz
# Processed: wan
# Processed: wand
# Processed: wander
# Processed: wanderer
# Processed: wandering
# Processed: wane
# Processed: waning
# Processed: wanker
# Processed: wannabe
# Processed: wannasleep
# Processed: want
# Processed: wanting
# Processed: wanton
# Processed: war
# Processed: warbler
# Processed: warcrimes
# Processed: ward
# Processed: warden
# Processed: wardrobe
# Processed: ware
# Processed: warehouse
# Processed: warfare
# Processed: warhead
# Processed: warlike
# Processed: warlock
# Processed: warlord
# Processed: warm
# Processed: warming
# Processed: warms
# Processed: warmth
# Processed: warn
# Processed: warned
# Processed: warning
# Processed: warp
# Processed: warpath
# Processed: warped
# Processed: warrant
# Processed: warranted
# Processed: warrants
# Processed: warranty
# Processed: warren
# Processed: warrior
# Processed: warship
# Processed: wart
# Processed: wartime
# Processed: wary
# Processed: wash
# Processed: washed
# Processed: washer
# Processed: washing
# Processed: washout
# Processed: washroom
# Processed: wasp
# Processed: waste
# Processed: wastebasket
# Processed: wasted
# Processed: wasteful
# Processed: wasteland
# Processed: wasting
# Processed: watch
# Processed: watchdog
# Processed: watcher
# Processed: watchful
# Processed: watchman
# Processed: watchout
# Processed: watchtower
# Processed: water
# Processed: waterbed
# Processed: watercourse
# Processed: watered
# Processed: waterfall
# Processed: waterfront
# Processed: watermelon
# Processed: waterproof
# Processed: waterworks
# Processed: watery
# Processed: wave
# Processed: wavelength
# Processed: waver
# Processed: wavering
# Processed: waves
# Processed: wavy
# Processed: wax
# Processed: waxed
# Processed: waxy
# Processed: way
# Processed: ways
# Processed: wayward
# Processed: weak
# Processed: weaken
# Processed: weakened
# Processed: weakling
# Processed: weakly
# Processed: weakness
# Processed: wealth
# Processed: wealthy
# Processed: weapon
# Processed: weaponry
# Processed: wear
# Processed: wearer
# Processed: wearily
# Processed: weariness
# Processed: wearing
# Processed: weary
# Processed: weasel
# Processed: weather
# Processed: weathered
# Processed: weatherman
# Processed: weatherproof
# Processed: weave
# Processed: web
# Processed: website
# Processed: wed
# Processed: wedded
# Processed: wedding
# Processed: wedge
# Processed: wedlock
# Processed: wee
# Processed: weed
# Processed: weeding
# Processed: weeds
# Processed: weedy
# Processed: weeeee
# Processed: week
# Processed: weekday
# Processed: weekend
# Processed: weekly
# Processed: weenie
# Processed: weep
# Processed: weeping
# Processed: weepy
# Processed: weigh
# Processed: weighing
# Processed: weight
# Processed: weightless
# Processed: weightloss
# Processed: weights
# Processed: weighty
# Processed: weir
# Processed: weird
# Processed: weirdness
# Processed: weirdo
# Processed: welcome
# Processed: welcomed
# Processed: welcoming
# Processed: weld
# Processed: welder
# Processed: welding
# Processed: welfare
# Processed: wellhead
# Processed: wellness
# Processed: welsh
# Processed: welt
# Processed: wen
# Processed: wench
# Processed: werewolf
# Processed: west
# Processed: westbound
# Processed: western
# Processed: wet
# Processed: wetback
# Processed: whack
# Processed: whale
# Processed: whaling
# Processed: wham
# Processed: whammy
# Processed: wharf
# Processed: whatdoido
# Processed: whatif
# Processed: whatmakesmesmile
# Processed: whatnot
# Processed: whatsoever
# Processed: whatsthepoint
# Processed: wheat
# Processed: wheel
# Processed: wheelbarrow
# Processed: wheelchair
# Processed: wheels
# Processed: wheeze
# Processed: whelp
# Processed: whereabouts
# Processed: wherefore
# Processed: wherewith
# Processed: wherewithal
# Processed: whet
# Processed: whiff
# Processed: whilst
# Processed: whim
# Processed: whimper
# Processed: whimsical
# Processed: whimsy
# Processed: whine
# Processed: whiny
# Processed: whip
# Processed: whiplash
# Processed: whipped
# Processed: whirl
# Processed: whirlpool
# Processed: whirlwind
# Processed: whisk
# Processed: whisker
# Processed: whiskers
# Processed: whiskey
# Processed: whisky
# Processed: whisper
# Processed: whispered
# Processed: whistle
# Processed: whit
# Processed: whitefish
# Processed: whiteness
# Processed: whitewash
# Processed: whitish
# Processed: whittle
# Processed: whiz
# Processed: whole
# Processed: wholesale
# Processed: wholesome
# Processed: wholly
# Processed: whoo
# Processed: whoop
# Processed: whopper
# Processed: whopping
# Processed: whore
# Processed: whorehouse
# Processed: wick
# Processed: wicked
# Processed: wickedness
# Processed: wicker
# Processed: wicket
# Processed: wide
# Processed: widely
# Processed: widen
# Processed: widespread
# Processed: widow
# Processed: widowed
# Processed: widower
# Processed: width
# Processed: wield
# Processed: wiener
# Processed: wienie
# Processed: wife
# Processed: wig
# Processed: wiggle
# Processed: wight
# Processed: wiki
# Processed: wild
# Processed: wildcat
# Processed: wildebeest
# Processed: wilderness
# Processed: wildfire
# Processed: wildlife
# Processed: will
# Processed: willful
# Processed: willies
# Processed: willing
# Processed: willingly
# Processed: willingness
# Processed: willow
# Processed: willpower
# Processed: wilt
# Processed: wilted
# Processed: wily
# Processed: wimp
# Processed: wimpy
# Processed: win
# Processed: wince
# Processed: winch
# Processed: wind
# Processed: windbag
# Processed: windfall
# Processed: winding
# Processed: windmill
# Processed: window
# Processed: windowsill
# Processed: windpipe
# Processed: windshield
# Processed: windy
# Processed: wine
# Processed: wing
# Processed: winged
# Processed: winger
# Processed: wingman
# Processed: wink
# Processed: winner
# Processed: winning
# Processed: winnings
# Processed: wino
# Processed: winter
# Processed: winterbreak
# Processed: wintertime
# Processed: wintery
# Processed: wintry
# Processed: wipe
# Processed: wiper
# Processed: wire
# Processed: wired
# Processed: wireless
# Processed: wiretap
# Processed: wiring
# Processed: wis
# Processed: wisdom
# Processed: wise
# Processed: wish
# Processed: wishbone
# Processed: wishful
# Processed: wishing
# Processed: wishmeluck
# Processed: wisp
# Processed: wistful
# Processed: wit
# Processed: witch
# Processed: witchcraft
# Processed: withal
# Processed: withdraw
# Processed: withdrawal
# Processed: withdrawals
# Processed: withdrawn
# Processed: wither
# Processed: withered
# Processed: withering
# Processed: withhold
# Processed: withholding
# Processed: withstand
# Processed: witless
# Processed: witness
# Processed: wits
# Processed: witty
# Processed: wiz
# Processed: wizard
# Processed: wobble
# Processed: wobbly
# Processed: woe
# Processed: woeful
# Processed: woefully
# Processed: wok
# Processed: wokemeup
# Processed: wolf
# Processed: wolverine
# Processed: womanhood
# Processed: womanizer
# Processed: womanly
# Processed: womb
# Processed: wonder
# Processed: wonderful
# Processed: wonderfully
# Processed: wonderment
# Processed: wondrous
# Processed: wont
# Processed: woo
# Processed: wood
# Processed: woodcut
# Processed: wooden
# Processed: woodland
# Processed: woodlands
# Processed: woodpecker
# Processed: woods
# Processed: woodshed
# Processed: woodsman
# Processed: woodwork
# Processed: woody
# Processed: woof
# Processed: woohoo
# Processed: wooing
# Processed: wool
# Processed: woolen
# Processed: woolly
# Processed: woot
# Processed: woozy
# Processed: wop
# Processed: word
# Processed: wording
# Processed: words
# Processed: wordy
# Processed: work
# Processed: workaholic
# Processed: workbook
# Processed: worker
# Processed: working
# Processed: workings
# Processed: workload
# Processed: workman
# Processed: workmanship
# Processed: workout
# Processed: workplace
# Processed: works
# Processed: workshop
# Processed: workup
# Processed: world
# Processed: worldly
# Processed: worldwide
# Processed: worm
# Processed: wormhole
# Processed: wormwood
# Processed: worn
# Processed: worried
# Processed: worries
# Processed: worry
# Processed: worrying
# Processed: worse
# Processed: worsening
# Processed: worship
# Processed: worshipful
# Processed: worstfeeling
# Processed: worth
# Processed: worthless
# Processed: worthwhile
# Processed: worthy
# Processed: wot
# Processed: would
# Processed: wound
# Processed: wounded
# Processed: wounding
# Processed: wounds
# Processed: wracking
# Processed: wrangler
# Processed: wrangling
# Processed: wrap
# Processed: wrapper
# Processed: wrapping
# Processed: wrath
# Processed: wrathful
# Processed: wreak
# Processed: wreath
# Processed: wreck
# Processed: wreckage
# Processed: wrecked
# Processed: wrecker
# Processed: wrench
# Processed: wrenching
# Processed: wrest
# Processed: wrestle
# Processed: wrestler
# Processed: wrestling
# Processed: wretch
# Processed: wretched
# Processed: wriggle
# Processed: wright
# Processed: wring
# Processed: wringer
# Processed: wrinkle
# Processed: wrinkled
# Processed: wrist
# Processed: wristband
# Processed: wristwatch
# Processed: writ
# Processed: write
# Processed: writer
# Processed: writing
# Processed: written
# Processed: wrong
# Processed: wrongdoing
# Processed: wrongful
# Processed: wrongly
# Processed: wrought
# Processed: wry
# Processed: xanax
# Processed: xenophobia
# Processed: xerox
# Processed: xmas
# Processed: xoxo
# Processed: yaaaay
# Processed: yaaay
# Processed: yaay
# Processed: yacht
# Processed: yachting
# Processed: yahoo
# Processed: yak
# Processed: yam
# Processed: yank
# Processed: yap
# Processed: yard
# Processed: yarn
# Processed: yaw
# Processed: yawn
# Processed: yawning
# Processed: yay
# Processed: yayy
# Processed: yayyy
# Processed: yayyyy
# Processed: yea
# Processed: yeahhh
# Processed: yeahhhh
# Processed: year
# Processed: yearbook
# Processed: yearling
# Processed: yearly
# Processed: yearn
# Processed: yearning
# Processed: years
# Processed: yeast
# Processed: yehey
# Processed: yell
# Processed: yeller
# Processed: yelling
# Processed: yellow
# Processed: yellows
# Processed: yelp
# Processed: yen
# Processed: yeoman
# Processed: yesss
# Processed: yessss
# Processed: yesterday
# Processed: yesteryear
# Processed: yew
# Processed: yey
# Processed: yield
# Processed: yielding
# Processed: yo-yo
# Processed: yodel
# Processed: yoga
# Processed: yogi
# Processed: yogurt
# Processed: yoke
# Processed: yolk
# Processed: yon
# Processed: yonder
# Processed: youngster
# Processed: yousuck
# Processed: youth
# Processed: youthful
# Processed: yucky
# Processed: yuletide
# Processed: yummy
# Processed: yuppie
# Processed: zany
# Processed: zap
# Processed: zeal
# Processed: zealot
# Processed: zealous
# Processed: zebra
# Processed: zen
# Processed: zenith
# Processed: zephyr
# Processed: zeppelin
# Processed: zest
# Processed: zesty
# Processed: zeta
# Processed: zigzag
# Processed: zilch
# Processed: zillion
# Processed: zinc
# Processed: zing
# Processed: zip
# Processed: zipper
# Processed: zippy
# Processed: zit
# Processed: zodiac
# Processed: zombie
# Processed: zone
# Processed: zoning
# Processed: zoo
# Processed: zoological
# Processed: zoology
# Processed: zoom
# Processed: zucchini
# Processing completed!

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
import string
import pandas as pd

class va_scorer:
    def __init__(self, vad_lexicon_path):
        self.vad_dict = {}
        self._load_lexicon(vad_lexicon_path)

    def _load_lexicon(self, file_path):
        with open(file_path, 'r', encoding='utf-8') as file:
            for line in file:
                parts = line.strip().split()
                if len(parts) == 4:
                    word = parts[0]
                    scores = [float(score) for score in parts[1:]]
                    self.vad_dict[word] = {
                        'valence': scores[0],
                        'arousal': scores[1],
                        'dominance': scores[2]
                    }

    def get_vad_scores(self, word):
        return self.vad_dict.get(word.lower())

def analyze_emotion_labels():
    # 감정 라벨 리스트
    emotion_labels = [
        'disappointment', 'annoyance', 'sadness', 'disapproval', 'love',
        'anger', 'realization', 'neutral', 'approval', 'disgust',
        'joy', 'admiration', 'embarrassment', 'amusement', 'confusion',
        'nervousness', 'remorse', 'optimism', 'desire', 'relief',
        'caring', 'excitement', 'grief', 'surprise', 'curiosity',
        'pride', 'fear', 'gratitude'
    ]

    # VA Scorer 초기화
    scorer = va_scorer('Bipolar_Lexicon.txt')

    # 결과를 저장할 리스트
    results = []

    # 각 라벨에 대한 VA 값 찾기
    for label in emotion_labels:
        scores = scorer.get_vad_scores(label)
        if scores:
            results.append({
                'emotion': label,
                'valence': scores['valence'],
                'arousal': scores['arousal']
            })
        else:
            # 레이블이 사전에 없는 경우 NaN으로 처리
            results.append({
                'emotion': label,
                'valence': float('nan'),
                'arousal': float('nan')
            })

    # DataFrame 생성
    df = pd.DataFrame(results)
    
    # NaN 값이 있는 행 확인
    missing_labels = df[df.isna().any(axis=1)]['emotion'].tolist()
    if missing_labels:
        print("Following labels were not found in the lexicon:", missing_labels)

    # 결과 저장
    df.to_csv('emotion_va_scores.csv', index=False)
    
    return df

# 실행
df = analyze_emotion_labels()
print("\nEmotion VA Scores DataFrame:")
df.to_csv('emotion_va_scores.csv', index=False)
# Out:
# Emotion VA Scores DataFrame:

# %%
import pandas as pd

def calculate_weighted_va(emotion_scores_list, va_scores_file):
    """
    감정 점수와 VA 점수를 이용하여 가중 평균 VA 값을 계산합니다.
    
    Args:
        emotion_scores_list (list): 감정 분석 결과 리스트
        va_scores_file (str): VA 점수가 저장된 CSV 파일 경로
    
    Returns:
        tuple: (최종 valence 값, 최종 arousal 값)
    """
    # VA 점수 읽기
    va_df = pd.read_csv(va_scores_file)
    
    # 가중 평균 계산을 위한 변수 초기화
    weighted_valence = 0
    weighted_arousal = 0
    total_weight = 0
    
    # 각 감정에 대해 가중 평균 계산
    for emotion in emotion_scores_list:
        label = emotion['label']
        score = emotion['score']
        
        va_row = va_df[va_df['emotion'] == label]
        if not va_row.empty and not va_row['valence'].isna().any() and not va_row['arousal'].isna().any():
            valence = va_row['valence'].iloc[0]
            arousal = va_row['arousal'].iloc[0]
            
            weighted_valence += valence * score
            weighted_arousal += arousal * score
            total_weight += score
    
    # 최종 VA 값 계산
    if total_weight > 0:
        final_valence = weighted_valence / total_weight
        final_arousal = weighted_arousal / total_weight
        return final_valence, final_arousal
    else:
        return None, None

# 감정 점수 데이터
emotion_scores = [
    {'label': 'disappointment', 'score': 0.6073453426361084},
    {'label': 'annoyance', 'score': 0.29090917110443115},
    {'label': 'sadness', 'score': 0.11545353382825851},
    {'label': 'disapproval', 'score': 0.09492042660713196},
    {'label': 'love', 'score': 0.0554782971739769},
    {'label': 'anger', 'score': 0.032416511327028275},
    {'label': 'realization', 'score': 0.026335157454013824},
    {'label': 'neutral', 'score': 0.026163052767515182},
    {'label': 'approval', 'score': 0.025927066802978516},
    {'label': 'disgust', 'score': 0.01680212840437889},
    {'label': 'joy', 'score': 0.014748722314834595},
    {'label': 'admiration', 'score': 0.01159504521638155}
]

# 계산 실행
valence, arousal = calculate_weighted_va(emotion_scores, 'emotion_va_scores.csv')
print(f"Weighted VA scores for the sentence:")
print(f"Valence: {valence:.3f}")
print(f"Arousal: {arousal:.3f}")
# Out:
# Weighted VA scores for the sentence:
# Valence: -0.592
# Arousal: 0.079

# %%
from sentence_transformers import SentenceTransformer
import numpy as np
import csv

class LexiconProcessor:
    def __init__(self, model_name: str = 'all-MiniLM-L6-v2'):
        # Sentence Transformer 모델 초기화
        self.model = SentenceTransformer(model_name)
    
    def get_embedding(self, word: str) -> np.ndarray:
        """단어의 Sentence Transformer 임베딩을 계산"""
        embedding = self.model.encode(word)
        return embedding
    
    def process_lexicon(self, vad_lexicon_path: str, output_file: str):
        """VAD 렉시콘의 단어들을 처리하여 임베딩과 VA 값을 저장"""
        # VAD 렉시콘 읽기
        word_data = {}
        with open(vad_lexicon_path, 'r', encoding='utf-8') as file:
            for line in file:
                parts = line.strip().split()
                if len(parts) == 4:  # word, valence, arousal, dominance
                    word = parts[0].lower()
                    valence, arousal = float(parts[1]), float(parts[2])
                    word_data[word] = (valence, arousal)
        
        # 각 단어에 대한 임베딩 계산 및 저장
        with open(output_file, 'w', newline='', encoding='utf-8') as f:
            writer = csv.writer(f)
            writer.writerow(['word', 'valence', 'arousal', 'embedding'])
            
            # 배치 처리를 위한 준비
            batch_size = 32
            words = list(word_data.keys())
            
            for i in range(0, len(words), batch_size):
                batch_words = words[i:i + batch_size]
                try:
                    # 배치 단위로 임베딩 계산
                    embeddings = self.model.encode(batch_words)
                    
                    # 각 단어와 임베딩 저장
                    for word, embedding in zip(batch_words, embeddings):
                        valence, arousal = word_data[word]
                        writer.writerow([
                            word,
                            valence,
                            arousal,
                            embedding.tolist()
                        ])
                        print(f"Processed: {word}")
                except Exception as e:
                    print(f"Error processing batch starting with word '{batch_words[0]}': {e}")

def main():
    # 설정
    vad_lexicon_path = "Bipolar_Lexicon.txt"
    output_file = r"C:\Users\Administrator\Desktop\lexicon_embeddings_ver2.csv"
    
    # 렉시콘 처리
    processor = LexiconProcessor()
    processor.process_lexicon(vad_lexicon_path, output_file)
    print("Processing completed!")

if __name__ == "__main__":
    main()
# Out:
# Processed: aaaaaaah
# Processed: aaaah
# Processed: aardvark
# Processed: aback
# Processed: abacus
# Processed: abalone
# Processed: abandon
# Processed: abandoned
# Processed: abandonment
# Processed: abashed
# Processed: abate
# Processed: abatement
# Processed: abba
# Processed: abbey
# Processed: abbot
# Processed: abbreviate
# Processed: abbreviation
# Processed: abdomen
# Processed: abdominal
# Processed: abduct
# Processed: abduction
# Processed: aberrant
# Processed: aberration
# Processed: abeyance
# Processed: abhor
# Processed: abhorrence
# Processed: abhorrent
# Processed: abide
# Processed: abiding
# Processed: ability
# Processed: abject
# Processed: ablation
# Processed: ablaze
# Processed: able
# Processed: abnormal
# Processed: abnormality
# Processed: aboard
# Processed: abode
# Processed: abolish
# Processed: abolition
# Processed: abominable
# Processed: abominate
# Processed: abomination
# Processed: aboriginal
# Processed: abort
# Processed: abortion
# Processed: abortive
# Processed: abound
# Processed: abovementioned
# Processed: abracadabra
# Processed: abrasion
# Processed: abrasive
# Processed: abreast
# Processed: abroad
# Processed: abrogate
# Processed: abrupt
# Processed: abruptly
# Processed: abscess
# Processed: absence
# Processed: absent
# Processed: absentee
# Processed: absenteeism
# Processed: absinthe
# Processed: absolute
# Processed: absolution
# Processed: absolve
# Processed: absorb
# Processed: absorbed
# Processed: absorbent
# Processed: absorbing
# Processed: absorption
# Processed: abstain
# Processed: abstention
# Processed: abstinence
# Processed: abstract
# Processed: abstraction
# Processed: absurd
# Processed: absurdity
# Processed: abundance
# Processed: abundant
# Processed: abuse
# Processed: abused
# Processed: abusive
# Processed: abutment
# Processed: aby
# Processed: abysmal
# Processed: abyss
# Processed: academic
# Processed: academy
# Processed: accede
# Processed: accelerant
# Processed: accelerate
# Processed: accelerated
# Processed: acceleration
# Processed: accelerator
# Processed: accent
# Processed: accentuate
# Processed: accept
# Processed: acceptable
# Processed: acceptance
# Processed: acceptances
# Processed: access
# Processed: accessible
# Processed: accession
# Processed: accessory
# Processed: accident
# Processed: accidental
# Processed: accidentally
# Processed: acclaim
# Processed: accolade
# Processed: accommodate
# Processed: accommodation
# Processed: accompaniment
# Processed: accompany
# Processed: accompanying
# Processed: accomplice
# Processed: accomplish
# Processed: accomplished
# Processed: accomplishment
# Processed: accord
# Processed: accordance
# Processed: accordion
# Processed: account
# Processed: accountability
# Processed: accountable
# Processed: accountant
# Processed: accounting
# Processed: accounts
# Processed: accredited
# Processed: accretion
# Processed: accrue
# Processed: accueil
# Processed: accumulate
# Processed: accumulation
# Processed: accuracy
# Processed: accurate
# Processed: accursed
# Processed: accusation
# Processed: accusative
# Processed: accuse
# Processed: accused
# Processed: accuser
# Processed: accusing
# Processed: accustomed
# Processed: ace
# Processed: acetic
# Processed: acetylene
# Processed: ache
# Processed: achieve
# Processed: achieved
# Processed: achievement
# Processed: aching
# Processed: achy
# Processed: acid
# Processed: acidity
# Processed: acknowledge
# Processed: acknowledged
# Processed: acknowledgement
# Processed: acknowledgment
# Processed: acme
# Processed: acne
# Processed: acorn
# Processed: acoustic
# Processed: acoustics
# Processed: acquaint
# Processed: acquaintance
# Processed: acquainted
# Processed: acquiescence
# Processed: acquire
# Processed: acquiring
# Processed: acquisition
# Processed: acquisitions
# Processed: acquit
# Processed: acquittal
# Processed: acre
# Processed: acreage
# Processed: acres
# Processed: acrobat
# Processed: acrylic
# Processed: act
# Processed: acting
# Processed: action
# Processed: actionable
# Processed: activate
# Processed: activation
# Processed: active
# Processed: activist
# Processed: activity
# Processed: actor
# Processed: actress
# Processed: actual
# Processed: actuality
# Processed: actuary
# Processed: acuity
# Processed: acumen
# Processed: acupuncture
# Processed: acute
# Processed: acutely
# Processed: ad
# Processed: adage
# Processed: adamant
# Processed: adapt
# Processed: adaptable
# Processed: adaptation
# Processed: add
# Processed: added
# Processed: addendum
# Processed: adder
# Processed: addict
# Processed: addicted
# Processed: addiction
# Processed: addictive
# Processed: addition
# Processed: additional
# Processed: additive
# Processed: address
# Processed: addressee
# Processed: addresses
# Processed: adept
# Processed: adequacy
# Processed: adequate
# Processed: adhere
# Processed: adherence
# Processed: adherent
# Processed: adhering
# Processed: adhesion
# Processed: adhesive
# Processed: adieu
# Processed: adipose
# Processed: adjacency
# Processed: adjacent
# Processed: adjective
# Processed: adjoining
# Processed: adjourn
# Processed: adjournment
# Processed: adjudicate
# Processed: adjudication
# Processed: adjunct
# Processed: adjust
# Processed: adjuster
# Processed: adjustment
# Processed: adjuvant
# Processed: admin
# Processed: administer
# Processed: administration
# Processed: administrative
# Processed: administrator
# Processed: admirable
# Processed: admiral
# Processed: admiralty
# Processed: admiration
# Processed: admire
# Processed: admired
# Processed: admirer
# Processed: admiring
# Processed: admissibility
# Processed: admissible
# Processed: admission
# Processed: admit
# Processed: admittance
# Processed: admitted
# Processed: admitting
# Processed: admixture
# Processed: admonition
# Processed: ado
# Processed: adobe
# Processed: adolescence
# Processed: adolescent
# Processed: adopt
# Processed: adoption
# Processed: adoptive
# Processed: adorable
# Processed: adoration
# Processed: adore
# Processed: adoring
# Processed: adorn
# Processed: adornment
# Processed: adrenalin
# Processed: adrenaline
# Processed: adrift
# Processed: adult
# Processed: adulterated
# Processed: adulterer
# Processed: adultery
# Processed: adulthood
# Processed: advance
# Processed: advanced
# Processed: advancement
# Processed: advancing
# Processed: advantage
# Processed: advantageous
# Processed: advent
# Processed: adventure
# Processed: adventurer
# Processed: adventures
# Processed: adventurous
# Processed: adversary
# Processed: adverse
# Processed: adversity
# Processed: advertise
# Processed: advertisement
# Processed: advertising
# Processed: adverts
# Processed: advice
# Processed: advisable
# Processed: advise
# Processed: advised
# Processed: advisement
# Processed: adviser
# Processed: advisor
# Processed: advisory
# Processed: advocacy
# Processed: advocate
# Processed: aegis
# Processed: aeration
# Processed: aerial
# Processed: aerobics
# Processed: aerodrome
# Processed: aerodynamic
# Processed: aerodynamics
# Processed: aeronautics
# Processed: aeroplane
# Processed: aerospace
# Processed: aesthetic
# Processed: aesthetics
# Processed: aetiology
# Processed: afar
# Processed: affable
# Processed: affair
# Processed: affect
# Processed: affecting
# Processed: affection
# Processed: affectionate
# Processed: affections
# Processed: affiche
# Processed: affidavit
# Processed: affiliated
# Processed: affiliation
# Processed: affinity
# Processed: affirm
# Processed: affirmation
# Processed: affirmative
# Processed: affirmatively
# Processed: affix
# Processed: afflict
# Processed: afflicted
# Processed: affliction
# Processed: affluence
# Processed: affluent
# Processed: afford
# Processed: affordable
# Processed: affront
# Processed: affronted
# Processed: afield
# Processed: afire
# Processed: afloat
# Processed: afore
# Processed: aforementioned
# Processed: aforesaid
# Processed: afraid
# Processed: afresh
# Processed: aft
# Processed: afterlife
# Processed: aftermath
# Processed: afternoon
# Processed: aftershave
# Processed: aftertaste
# Processed: afterthought
# Processed: aga
# Processed: agape
# Processed: agate
# Processed: age
# Processed: aged
# Processed: agency
# Processed: agenda
# Processed: agent
# Processed: agglomeration
# Processed: aggravate
# Processed: aggravated
# Processed: aggravates
# Processed: aggravating
# Processed: aggravation
# Processed: aggregate
# Processed: aggregation
# Processed: aggresive
# Processed: aggression
# Processed: aggressive
# Processed: aggressively
# Processed: aggressiveness
# Processed: aggressor
# Processed: agh
# Processed: aghast
# Processed: aghhh
# Processed: agile
# Processed: agility
# Processed: aging
# Processed: agitate
# Processed: agitated
# Processed: agitation
# Processed: aglow
# Processed: agnostic
# Processed: ago
# Processed: agonizing
# Processed: agony
# Processed: agoraphobia
# Processed: agree
# Processed: agreeable
# Processed: agreed
# Processed: agreeing
# Processed: agreement
# Processed: agressive
# Processed: agricultural
# Processed: agriculture
# Processed: aground
# Processed: agua
# Processed: ahead
# Processed: ahhh
# Processed: ahhhhhhhh
# Processed: ahoy
# Processed: aid
# Processed: aide
# Processed: aiding
# Processed: aids
# Processed: ail
# Processed: ailing
# Processed: ailment
# Processed: aim
# Processed: aimless
# Processed: air
# Processed: airbag
# Processed: airborne
# Processed: aircraft
# Processed: airfield
# Processed: airhead
# Processed: airlift
# Processed: airline
# Processed: airliner
# Processed: airlock
# Processed: airman
# Processed: airplane
# Processed: airport
# Processed: airs
# Processed: airship
# Processed: airspace
# Processed: airspeed
# Processed: airstrip
# Processed: airtight
# Processed: airway
# Processed: aisle
# Processed: ait
# Processed: ajar
# Processed: aka
# Processed: akin
# Processed: alabaster
# Processed: alarm
# Processed: alarmed
# Processed: alarming
# Processed: alas
# Processed: alb
# Processed: albatross
# Processed: albino
# Processed: album
# Processed: alchemy
# Processed: alcohol
# Processed: alcoholic
# Processed: alcoholism
# Processed: alcove
# Processed: alderman
# Processed: ale
# Processed: alert
# Processed: alertness
# Processed: alerts
# Processed: alfalfa
# Processed: algebra
# Processed: algebraic
# Processed: algorithm
# Processed: alias
# Processed: alibi
# Processed: alien
# Processed: alienate
# Processed: alienated
# Processed: alienation
# Processed: alight
# Processed: align
# Processed: aligned
# Processed: alignment
# Processed: alike
# Processed: alimentation
# Processed: alimony
# Processed: aliquot
# Processed: alive
# Processed: alkali
# Processed: alkaloids
# Processed: allay
# Processed: allegation
# Processed: allege
# Processed: alleged
# Processed: allegiance
# Processed: allegorical
# Processed: allegory
# Processed: allegro
# Processed: allergic
# Processed: allergy
# Processed: alleviate
# Processed: alleviation
# Processed: alley
# Processed: alleyway
# Processed: alliance
# Processed: allied
# Processed: alligator
# Processed: allocate
# Processed: allocation
# Processed: allot
# Processed: allotment
# Processed: allow
# Processed: allowable
# Processed: allowance
# Processed: allowed
# Processed: alloy
# Processed: allsmiles
# Processed: allure
# Processed: alluring
# Processed: allusion
# Processed: alluvial
# Processed: ally
# Processed: almanac
# Processed: almighty
# Processed: almond
# Processed: aloft
# Processed: aloha
# Processed: alone
# Processed: alongside
# Processed: aloof
# Processed: aloud
# Processed: alpha
# Processed: alphabet
# Processed: alphabetical
# Processed: alpine
# Processed: alreadyyyyy
# Processed: altar
# Processed: alter
# Processed: alteration
# Processed: altercation
# Processed: altered
# Processed: alternate
# Processed: alternating
# Processed: alternative
# Processed: altimeter
# Processed: altitude
# Processed: alto
# Processed: altogether
# Processed: aluminum
# Processed: alumnus
# Processed: alveolar
# Processed: alzheimers
# Processed: amalgam
# Processed: amalgamation
# Processed: amaretto
# Processed: amass
# Processed: amateur
# Processed: amaze
# Processed: amazed
# Processed: amazedness
# Processed: amazement
# Processed: amazing
# Processed: amazingly
# Processed: ambassador
# Processed: amber
# Processed: ambience
# Processed: ambient
# Processed: ambiguity
# Processed: ambiguous
# Processed: ambit
# Processed: ambition
# Processed: ambitious
# Processed: ambivalent
# Processed: ambrosia
# Processed: ambulance
# Processed: ambush
# Processed: ameliorate
# Processed: amen
# Processed: amenable
# Processed: amend
# Processed: amendment
# Processed: amends
# Processed: amenity
# Processed: amethyst
# Processed: amiable
# Processed: amicable
# Processed: amid
# Processed: amidst
# Processed: amino
# Processed: ammo
# Processed: ammonia
# Processed: ammonium
# Processed: ammunition
# Processed: amnesia
# Processed: amnesty
# Processed: amorous
# Processed: amorphous
# Processed: amortization
# Processed: amount
# Processed: amour
# Processed: amp
# Processed: ampersand
# Processed: amphetamines
# Processed: amphibian
# Processed: amphibious
# Processed: amphitheater
# Processed: ample
# Processed: amplification
# Processed: amplify
# Processed: amplitude
# Processed: amply
# Processed: amputate
# Processed: amputation
# Processed: amuck
# Processed: amulet
# Processed: amuse
# Processed: amused
# Processed: amusement
# Processed: amusing
# Processed: ana
# Processed: anaconda
# Processed: anaesthesia
# Processed: anaesthetic
# Processed: anagram
# Processed: anal
# Processed: analgesic
# Processed: analogous
# Processed: analogue
# Processed: analogy
# Processed: analysis
# Processed: analyst
# Processed: analytic
# Processed: analytical
# Processed: analyze
# Processed: analyzer
# Processed: anaphylactic
# Processed: anarchism
# Processed: anarchist
# Processed: anarchy
# Processed: anastomosis
# Processed: anathema
# Processed: anatomic
# Processed: anatomy
# Processed: ancestor
# Processed: ancestral
# Processed: ancestry
# Processed: anchor
# Processed: anchorage
# Processed: ancient
# Processed: ancillary
# Processed: androgen
# Processed: android
# Processed: anecdote
# Processed: anemia
# Processed: anemic
# Processed: anemone
# Processed: anesthesia
# Processed: anesthesiologist
# Processed: anesthetic
# Processed: aneurysm
# Processed: anew
# Processed: angel
# Processed: angelic
# Processed: anger
# Processed: angered
# Processed: angermanagement
# Processed: angina
# Processed: angiogram
# Processed: angiography
# Processed: angle
# Processed: angling
# Processed: angora
# Processed: angriest
# Processed: angry
# Processed: angrytweet
# Processed: angst
# Processed: anguish
# Processed: anguished
# Processed: angular
# Processed: anhydrous
# Processed: animal
# Processed: animate
# Processed: animated
# Processed: animation
# Processed: animosity
# Processed: animus
# Processed: ankle
# Processed: anklet
# Processed: annals
# Processed: annex
# Processed: annexation
# Processed: annexe
# Processed: annihilate
# Processed: annihilated
# Processed: annihilation
# Processed: anniversary
# Processed: annotate
# Processed: annotation
# Processed: announce
# Processed: announcement
# Processed: announcer
# Processed: annoy
# Processed: annoyance
# Processed: annoyed
# Processed: annoyin
# Processed: annoying
# Processed: annoys
# Processed: annual
# Processed: annuity
# Processed: annul
# Processed: annular
# Processed: annulment
# Processed: annulus
# Processed: anointed
# Processed: anointing
# Processed: anomalous
# Processed: anomaly
# Processed: anon
# Processed: anonymity
# Processed: anonymous
# Processed: anorexic
# Processed: answer
# Processed: answerable
# Processed: answering
# Processed: ant
# Processed: antagonism
# Processed: antagonist
# Processed: antagonistic
# Processed: antagonize
# Processed: ante
# Processed: antecedent
# Processed: antelope
# Processed: antenna
# Processed: anterior
# Processed: anthem
# Processed: anthill
# Processed: anthology
# Processed: anthrax
# Processed: anthropological
# Processed: anthropologist
# Processed: anthropology
# Processed: anti
# Processed: antiaircraft
# Processed: antibiotic
# Processed: antibiotics
# Processed: antichrist
# Processed: anticipate
# Processed: anticipation
# Processed: anticipatory
# Processed: antics
# Processed: antidote
# Processed: antifungal
# Processed: antigravity
# Processed: antimony
# Processed: antipathy
# Processed: antiquarian
# Processed: antiquated
# Processed: antique
# Processed: antiques
# Processed: antiquity
# Processed: antiseptic
# Processed: antisocial
# Processed: antithesis
# Processed: antithetical
# Processed: antiviral
# Processed: antler
# Processed: antsy
# Processed: anus
# Processed: anvil
# Processed: anxiety
# Processed: anxietyattack
# Processed: anxious
# Processed: anxiousness
# Processed: anytime
# Processed: aorta
# Processed: aortic
# Processed: apace
# Processed: apache
# Processed: apartment
# Processed: apartments
# Processed: apathetic
# Processed: apathy
# Processed: ape
# Processed: aperture
# Processed: apex
# Processed: aphid
# Processed: aphrodisiac
# Processed: apiece
# Processed: aplomb
# Processed: apocalypse
# Processed: apocalyptic
# Processed: apologetic
# Processed: apologist
# Processed: apologize
# Processed: apology
# Processed: apostasy
# Processed: apostate
# Processed: apostle
# Processed: apostolic
# Processed: apostrophe
# Processed: apothecary
# Processed: appalled
# Processed: appalling
# Processed: apparatus
# Processed: apparel
# Processed: apparent
# Processed: apparently
# Processed: apparition
# Processed: appeal
# Processed: appear
# Processed: appearance
# Processed: appease
# Processed: appellant
# Processed: append
# Processed: appendage
# Processed: appendectomy
# Processed: appendicitis
# Processed: appendix
# Processed: appetite
# Processed: appetizer
# Processed: appetizing
# Processed: applaud
# Processed: applause
# Processed: apple
# Processed: applejack
# Processed: applesauce
# Processed: appliance
# Processed: appliances
# Processed: applicability
# Processed: applicable
# Processed: applicant
# Processed: application
# Processed: apply
# Processed: appoint
# Processed: appointment
# Processed: appointments
# Processed: apportion
# Processed: apportionment
# Processed: appraisal
# Processed: appraise
# Processed: appreciable
# Processed: appreciate
# Processed: appreciated
# Processed: appreciates
# Processed: appreciation
# Processed: appreciative
# Processed: apprehend
# Processed: apprehension
# Processed: apprehensive
# Processed: apprentice
# Processed: apprenticeship
# Processed: approach
# Processed: approaching
# Processed: approbate
# Processed: approbation
# Processed: appropriate
# Processed: appropriation
# Processed: approval
# Processed: approve
# Processed: approved
# Processed: approvement
# Processed: approving
# Processed: approximate
# Processed: approximately
# Processed: approximating
# Processed: approximation
# Processed: appurtenances
# Processed: apricot
# Processed: apron
# Processed: apt
# Processed: aptitude
# Processed: aqua
# Processed: aquamarine
# Processed: aquarium
# Processed: aquatic
# Processed: aqueduct
# Processed: aqueous
# Processed: arable
# Processed: arbiter
# Processed: arbitrary
# Processed: arbitrate
# Processed: arbitration
# Processed: arbitrator
# Processed: arbor
# Processed: arc
# Processed: arcade
# Processed: arcane
# Processed: arch
# Processed: archaeological
# Processed: archaeologist
# Processed: archaeology
# Processed: archaic
# Processed: archangel
# Processed: archbishop
# Processed: archdiocese
# Processed: archduke
# Processed: arched
# Processed: archer
# Processed: archery
# Processed: archetype
# Processed: archipelago
# Processed: architect
# Processed: architectural
# Processed: architecture
# Processed: archive
# Processed: arctic
# Processed: ardent
# Processed: ardor
# Processed: arduous
# Processed: area
# Processed: arena
# Processed: areola
# Processed: areyoukidding
# Processed: areyoukiddingme
# Processed: argent
# Processed: argh
# Processed: arghh
# Processed: arghhhh
# Processed: argue
# Processed: argument
# Processed: argumentation
# Processed: argumentative
# Processed: arguments
# Processed: arid
# Processed: arise
# Processed: aristocracy
# Processed: aristocrat
# Processed: aristocratic
# Processed: arithmetic
# Processed: ark
# Processed: arm
# Processed: armada
# Processed: armament
# Processed: armaments
# Processed: armature
# Processed: armchair
# Processed: armed
# Processed: armor
# Processed: armored
# Processed: armory
# Processed: armpit
# Processed: arms
# Processed: army
# Processed: aroma
# Processed: aromatherapy
# Processed: arousal
# Processed: arouse
# Processed: aroused
# Processed: arraignment
# Processed: arrange
# Processed: arranged
# Processed: arrangement
# Processed: array
# Processed: arrears
# Processed: arrest
# Processed: arrhythmia
# Processed: arrival
# Processed: arrive
# Processed: arrogance
# Processed: arrogant
# Processed: arrow
# Processed: arsehole
# Processed: arseholes
# Processed: arsenal
# Processed: arsenic
# Processed: arson
# Processed: arsonist
# Processed: art
# Processed: arterial
# Processed: artery
# Processed: artful
# Processed: arthritis
# Processed: arthropod
# Processed: artichoke
# Processed: article
# Processed: articles
# Processed: articulate
# Processed: articulation
# Processed: artifact
# Processed: artifice
# Processed: artificial
# Processed: artillery
# Processed: artisan
# Processed: artist
# Processed: artiste
# Processed: artistic
# Processed: artistry
# Processed: artists
# Processed: artwork
# Processed: arty
# Processed: asap
# Processed: asbestos
# Processed: ascend
# Processed: ascendancy
# Processed: ascendant
# Processed: ascending
# Processed: ascension
# Processed: ascent
# Processed: ascertain
# Processed: ascertained
# Processed: ascetic
# Processed: ash
# Processed: ashamed
# Processed: ashes
# Processed: ashtray
# Processed: asinine
# Processed: ask
# Processed: asleeep
# Processed: asleep
# Processed: asp
# Processed: asparagus
# Processed: aspartame
# Processed: aspect
# Processed: aspects
# Processed: aspen
# Processed: asphalt
# Processed: asphyxia
# Processed: asphyxiation
# Processed: aspiration
# Processed: aspire
# Processed: aspirin
# Processed: aspiring
# Processed: ass
# Processed: assail
# Processed: assailant
# Processed: assassin
# Processed: assassinate
# Processed: assassination
# Processed: assault
# Processed: assay
# Processed: assemblage
# Processed: assemble
# Processed: assembled
# Processed: assembly
# Processed: assemblyman
# Processed: assent
# Processed: assert
# Processed: asserting
# Processed: assertion
# Processed: assertive
# Processed: assess
# Processed: assessment
# Processed: assessor
# Processed: asset
# Processed: assets
# Processed: asshole
# Processed: assign
# Processed: assignee
# Processed: assignment
# Processed: assimilate
# Processed: assimilation
# Processed: assist
# Processed: assistance
# Processed: assistant
# Processed: associate
# Processed: association
# Processed: assorted
# Processed: assortment
# Processed: assuage
# Processed: assume
# Processed: assumed
# Processed: assuming
# Processed: assumption
# Processed: assurance
# Processed: assure
# Processed: assured
# Processed: assuredly
# Processed: asterisk
# Processed: asteroid
# Processed: asteroids
# Processed: asthma
# Processed: asthmatic
# Processed: astigmatism
# Processed: astonish
# Processed: astonished
# Processed: astonishing
# Processed: astonishingly
# Processed: astonishment
# Processed: astound
# Processed: astral
# Processed: astray
# Processed: astringent
# Processed: astrologer
# Processed: astrology
# Processed: astronaut
# Processed: astronomer
# Processed: astronomical
# Processed: astronomy
# Processed: astute
# Processed: asunder
# Processed: asylum
# Processed: asymmetric
# Processed: asymmetry
# Processed: asymptotic
# Processed: atelier
# Processed: atheism
# Processed: atheistic
# Processed: atherosclerosis
# Processed: athlete
# Processed: athletic
# Processed: athleticism
# Processed: athletics
# Processed: atlas
# Processed: atmosphere
# Processed: atmospheric
# Processed: atoll
# Processed: atom
# Processed: atomic
# Processed: atone
# Processed: atonement
# Processed: atpeace
# Processed: atrium
# Processed: atrocious
# Processed: atrocity
# Processed: atrophy
# Processed: attach
# Processed: attached
# Processed: attachment
# Processed: attack
# Processed: attacker
# Processed: attacking
# Processed: attain
# Processed: attainable
# Processed: attainment
# Processed: attempt
# Processed: attempted
# Processed: attend
# Processed: attendance
# Processed: attendant
# Processed: attention
# Processed: attentionseeker
# Processed: attentionseekers
# Processed: attentive
# Processed: attenuate
# Processed: attenuated
# Processed: attenuation
# Processed: attest
# Processed: attestation
# Processed: attic
# Processed: attire
# Processed: attitude
# Processed: attorney
# Processed: attract
# Processed: attraction
# Processed: attractive
# Processed: attractiveness
# Processed: attributable
# Processed: attribute
# Processed: attribution
# Processed: attrition
# Processed: auburn
# Processed: auction
# Processed: auctioneer
# Processed: audacious
# Processed: audacity
# Processed: audible
# Processed: audience
# Processed: audio
# Processed: audit
# Processed: audition
# Processed: auditions
# Processed: auditor
# Processed: auditorium
# Processed: auditory
# Processed: aught
# Processed: augment
# Processed: augmentation
# Processed: august
# Processed: aunt
# Processed: auntie
# Processed: aura
# Processed: aurora
# Processed: auspices
# Processed: auspicious
# Processed: austere
# Processed: austerity
# Processed: authentic
# Processed: authenticate
# Processed: authentication
# Processed: authenticity
# Processed: author
# Processed: authoritative
# Processed: authority
# Processed: authorization
# Processed: authorize
# Processed: authorized
# Processed: authorship
# Processed: autism
# Processed: autistic
# Processed: auto
# Processed: autobiographical
# Processed: autobiography
# Processed: autocorrect
# Processed: autocratic
# Processed: autograph
# Processed: autographed
# Processed: automated
# Processed: automatic
# Processed: automobile
# Processed: automotive
# Processed: autonomy
# Processed: autopilot
# Processed: autopsy
# Processed: autumn
# Processed: auxiliary
# Processed: avail
# Processed: availability
# Processed: available
# Processed: avalanche
# Processed: avarice
# Processed: avatar
# Processed: avenge
# Processed: avenger
# Processed: avenging
# Processed: avenue
# Processed: aver
# Processed: average
# Processed: aversation
# Processed: averse
# Processed: averseness
# Processed: aversion
# Processed: avert
# Processed: aviary
# Processed: aviation
# Processed: aviator
# Processed: avid
# Processed: avocado
# Processed: avoid
# Processed: avoidance
# Processed: avoiding
# Processed: await
# Processed: awake
# Processed: awaken
# Processed: awakening
# Processed: award
# Processed: awards
# Processed: aware
# Processed: awareness
# Processed: awe
# Processed: awed
# Processed: awesome
# Processed: awesomeness
# Processed: awestruck
# Processed: awful
# Processed: awkward
# Processed: awkwardness
# Processed: awning
# Processed: awry
# Processed: axe
# Processed: axial
# Processed: axiom
# Processed: axiomatic
# Processed: axis
# Processed: axle
# Processed: ay
# Processed: aye
# Processed: azimuth
# Processed: azure
# Processed: babble
# Processed: babbling
# Processed: babe
# Processed: baboon
# Processed: baby
# Processed: babysit
# Processed: babysitter
# Processed: baccalaureate
# Processed: baccarat
# Processed: bachelor
# Processed: bachelorette
# Processed: back
# Processed: backboard
# Processed: backbone
# Processed: backdoor
# Processed: backdrop
# Processed: backer
# Processed: backfire
# Processed: backgammon
# Processed: background
# Processed: backhand
# Processed: backhoe
# Processed: backoff
# Processed: backpack
# Processed: backpacker
# Processed: backroom
# Processed: backseat
# Processed: backside
# Processed: backtrack
# Processed: backup
# Processed: backward
# Processed: backwardness
# Processed: backwards
# Processed: backwater
# Processed: backwoods
# Processed: backyard
# Processed: bacon
# Processed: bacteria
# Processed: bacterial
# Processed: bacterium
# Processed: bad
# Processed: badass
# Processed: badday
# Processed: badfeeling
# Processed: badge
# Processed: badger
# Processed: badhabit
# Processed: badly
# Processed: badness
# Processed: baffle
# Processed: baffled
# Processed: bag
# Processed: bagel
# Processed: baggage
# Processed: baggie
# Processed: baggy
# Processed: bagman
# Processed: bagpipes
# Processed: bail
# Processed: bailiff
# Processed: bait
# Processed: bake
# Processed: bakery
# Processed: baking
# Processed: bal
# Processed: balance
# Processed: balanced
# Processed: balcony
# Processed: bald
# Processed: balding
# Processed: baldy
# Processed: bale
# Processed: balk
# Processed: ball
# Processed: ballad
# Processed: ballast
# Processed: ballerina
# Processed: ballet
# Processed: ballgame
# Processed: ballistic
# Processed: ballistics
# Processed: balloon
# Processed: ballot
# Processed: ballpark
# Processed: ballplayer
# Processed: ballpoint
# Processed: ballroom
# Processed: ballsy
# Processed: balm
# Processed: balmy
# Processed: balsam
# Processed: balsamic
# Processed: bam
# Processed: bamboo
# Processed: ban
# Processed: banana
# Processed: band
# Processed: bandage
# Processed: bandanna
# Processed: bandit
# Processed: bandstand
# Processed: bandwagon
# Processed: bandwidth
# Processed: bane
# Processed: bang
# Processed: banger
# Processed: banish
# Processed: banished
# Processed: banishment
# Processed: banister
# Processed: banjo
# Processed: bank
# Processed: banker
# Processed: banking
# Processed: bankroll
# Processed: bankrupt
# Processed: bankruptcy
# Processed: banner
# Processed: banquet
# Processed: banshee
# Processed: banter
# Processed: banzai
# Processed: baptism
# Processed: baptismal
# Processed: baptize
# Processed: bar
# Processed: barb
# Processed: barbarian
# Processed: barbaric
# Processed: barbarism
# Processed: barbecue
# Processed: barbed
# Processed: barber
# Processed: barbershop
# Processed: bard
# Processed: bare
# Processed: bareback
# Processed: barefoot
# Processed: barely
# Processed: barf
# Processed: bargain
# Processed: bargaining
# Processed: barge
# Processed: baritone
# Processed: barium
# Processed: bark
# Processed: barkeep
# Processed: barks
# Processed: barley
# Processed: barmaid
# Processed: barman
# Processed: barn
# Processed: barnacle
# Processed: barney
# Processed: barnyard
# Processed: barometer
# Processed: baron
# Processed: baroness
# Processed: baroque
# Processed: barrack
# Processed: barracuda
# Processed: barrage
# Processed: barred
# Processed: barrel
# Processed: barren
# Processed: barricade
# Processed: barrier
# Processed: barring
# Processed: barrister
# Processed: barroom
# Processed: barrow
# Processed: bartender
# Processed: barter
# Processed: base
# Processed: baseball
# Processed: baseboard
# Processed: baseless
# Processed: baseline
# Processed: baseman
# Processed: basement
# Processed: bases
# Processed: bash
# Processed: bashful
# Processed: basic
# Processed: basics
# Processed: basil
# Processed: basilica
# Processed: basin
# Processed: basis
# Processed: bask
# Processed: basket
# Processed: basketball
# Processed: bass
# Processed: basso
# Processed: bassoon
# Processed: bastard
# Processed: bastarding
# Processed: bastards
# Processed: bastion
# Processed: bat
# Processed: batch
# Processed: batching
# Processed: bate
# Processed: bath
# Processed: bathe
# Processed: bathhouse
# Processed: bathing
# Processed: bathrobe
# Processed: bathroom
# Processed: bathtub
# Processed: bathymetry
# Processed: baton
# Processed: battalion
# Processed: batter
# Processed: battered
# Processed: battering
# Processed: battery
# Processed: battle
# Processed: battled
# Processed: battlefield
# Processed: battleground
# Processed: battlements
# Processed: battleship
# Processed: batty
# Processed: bauble
# Processed: bawdy
# Processed: bawl
# Processed: bay
# Processed: bayonet
# Processed: bayou
# Processed: bazaar
# Processed: bazooka
# Processed: bday
# Processed: be
# Processed: beach
# Processed: beaches
# Processed: beacon
# Processed: bead
# Processed: beading
# Processed: beads
# Processed: beady
# Processed: beagle
# Processed: beak
# Processed: beaker
# Processed: beam
# Processed: beaming
# Processed: bean
# Processed: beanbag
# Processed: beanie
# Processed: bear
# Processed: bearable
# Processed: beard
# Processed: bearded
# Processed: bearer
# Processed: bearing
# Processed: bearings
# Processed: bearish
# Processed: bearskin
# Processed: beast
# Processed: beastly
# Processed: beat
# Processed: beaten
# Processed: beater
# Processed: beating
# Processed: beatnik
# Processed: beau
# Processed: beautification
# Processed: beautiful
# Processed: beautify
# Processed: beauty
# Processed: beaver
# Processed: bebop
# Processed: beck
# Processed: beckon
# Processed: become
# Processed: bed
# Processed: bedding
# Processed: bedpan
# Processed: bedrock
# Processed: bedroom
# Processed: bedside
# Processed: bedspread
# Processed: bedtime
# Processed: bee
# Processed: beef
# Processed: beefsteak
# Processed: beehive
# Processed: beep
# Processed: beeper
# Processed: beer
# Processed: bees
# Processed: beeswax
# Processed: beetle
# Processed: befall
# Processed: befitting
# Processed: befriend
# Processed: befuddled
# Processed: beg
# Processed: beggar
# Processed: begging
# Processed: begin
# Processed: beginner
# Processed: beginning
# Processed: beginnings
# Processed: begrudge
# Processed: begun
# Processed: behappy
# Processed: behave
# Processed: behavior
# Processed: behavioral
# Processed: behemoth
# Processed: behest
# Processed: behold
# Processed: beholden
# Processed: beholder
# Processed: beige
# Processed: belated
# Processed: belay
# Processed: belch
# Processed: belief
# Processed: believable
# Processed: believe
# Processed: believed
# Processed: believer
# Processed: believing
# Processed: belittle
# Processed: belittled
# Processed: bell
# Processed: bellboy
# Processed: bellhop
# Processed: belligerent
# Processed: bellman
# Processed: bellow
# Processed: bellows
# Processed: belly
# Processed: bellybutton
# Processed: bellyful
# Processed: belong
# Processed: belongings
# Processed: beloved
# Processed: belt
# Processed: beluga
# Processed: bemused
# Processed: bench
# Processed: bend
# Processed: bender
# Processed: bending
# Processed: beneath
# Processed: benedictory
# Processed: benefactor
# Processed: beneficial
# Processed: beneficiary
# Processed: benefit
# Processed: benevolence
# Processed: benevolent
# Processed: benign
# Processed: bent
# Processed: benzene
# Processed: bequeath
# Processed: bequest
# Processed: bereaved
# Processed: bereavement
# Processed: bereft
# Processed: beret
# Processed: bergamot
# Processed: berlin
# Processed: berserk
# Processed: berth
# Processed: beryllium
# Processed: beseech
# Processed: beset
# Processed: bestdayever
# Processed: bestfeeling
# Processed: bestfriends
# Processed: bestial
# Processed: besties
# Processed: bestow
# Processed: bestseller
# Processed: bet
# Processed: beta
# Processed: betray
# Processed: betrayal
# Processed: betrayed
# Processed: betrothed
# Processed: betterment
# Processed: betting
# Processed: betty
# Processed: bevel
# Processed: beverage
# Processed: bevy
# Processed: beware
# Processed: bewilder
# Processed: bewildered
# Processed: bewilderment
# Processed: bias
# Processed: biased
# Processed: bib
# Processed: bible
# Processed: biblical
# Processed: bibliography
# Processed: bicarbonate
# Processed: bicentennial
# Processed: biceps
# Processed: bicker
# Processed: bickering
# Processed: bicolor
# Processed: bicycle
# Processed: bid
# Processed: bidder
# Processed: bidding
# Processed: bide
# Processed: biennial
# Processed: bier
# Processed: bifurcation
# Processed: big
# Processed: bigamy
# Processed: bigday
# Processed: biggestfear
# Processed: biggie
# Processed: bighorn
# Processed: bigmouth
# Processed: bigot
# Processed: bigoted
# Processed: bigotry
# Processed: bike
# Processed: biker
# Processed: bikini
# Processed: bilateral
# Processed: bilayer
# Processed: bile
# Processed: bilge
# Processed: bilingual
# Processed: bill
# Processed: billboard
# Processed: billet
# Processed: billiard
# Processed: billiards
# Processed: billing
# Processed: billion
# Processed: billionaire
# Processed: billy
# Processed: bimbo
# Processed: bimonthly
# Processed: bin
# Processed: binary
# Processed: bind
# Processed: binder
# Processed: bindery
# Processed: binding
# Processed: bing
# Processed: binge
# Processed: bingo
# Processed: binocular
# Processed: binoculars
# Processed: binomial
# Processed: bio
# Processed: biochemical
# Processed: biochemist
# Processed: biochemistry
# Processed: biogenesis
# Processed: biographer
# Processed: biography
# Processed: biological
# Processed: biologist
# Processed: biology
# Processed: bionic
# Processed: biopsy
# Processed: biosphere
# Processed: bipartite
# Processed: bipolar
# Processed: birch
# Processed: bird
# Processed: birdcage
# Processed: birdie
# Processed: birdman
# Processed: birth
# Processed: birthday
# Processed: birthing
# Processed: birthmark
# Processed: birthplace
# Processed: birthright
# Processed: bis
# Processed: biscuit
# Processed: bishop
# Processed: bison
# Processed: bisque
# Processed: bistro
# Processed: bit
# Processed: bitch
# Processed: bitchy
# Processed: bite
# Processed: biter
# Processed: bitsy
# Processed: bitter
# Processed: bitterly
# Processed: bitterness
# Processed: bittersweet
# Processed: bitty
# Processed: bitumen
# Processed: biweekly
# Processed: biz
# Processed: bizarre
# Processed: blab
# Processed: blabbermouth
# Processed: blackberry
# Processed: blackbird
# Processed: blackboard
# Processed: blacken
# Processed: blackface
# Processed: blackjack
# Processed: blacklist
# Processed: blackmail
# Processed: blackmailer
# Processed: blackness
# Processed: blackout
# Processed: blacksmith
# Processed: bladder
# Processed: blade
# Processed: blame
# Processed: blameless
# Processed: bland
# Processed: blank
# Processed: blanket
# Processed: blare
# Processed: blase
# Processed: blasphemous
# Processed: blasphemy
# Processed: blast
# Processed: blaster
# Processed: blastoff
# Processed: blatant
# Processed: blather
# Processed: blaze
# Processed: blazer
# Processed: blazing
# Processed: bleach
# Processed: bleak
# Processed: bleed
# Processed: bleeder
# Processed: bleeding
# Processed: bleep
# Processed: blemish
# Processed: blemished
# Processed: blend
# Processed: blender
# Processed: blending
# Processed: bless
# Processed: blessed
# Processed: blessing
# Processed: blessings
# Processed: bleu
# Processed: blight
# Processed: blighted
# Processed: blimp
# Processed: blinded
# Processed: blindfold
# Processed: blindfolded
# Processed: blinding
# Processed: blindly
# Processed: blindness
# Processed: blink
# Processed: blip
# Processed: bliss
# Processed: blissful
# Processed: blister
# Processed: blistering
# Processed: blitz
# Processed: blizzard
# Processed: bloat
# Processed: bloated
# Processed: blob
# Processed: block
# Processed: blockade
# Processed: blockage
# Processed: blockbuster
# Processed: blockhead
# Processed: blog
# Processed: bloke
# Processed: blond
# Processed: blonde
# Processed: blood
# Processed: bloodbath
# Processed: bloodhound
# Processed: bloodless
# Processed: bloodline
# Processed: bloodshed
# Processed: bloodshot
# Processed: bloodstream
# Processed: bloodthirsty
# Processed: bloody
# Processed: bloom
# Processed: bloomers
# Processed: blooming
# Processed: blossom
# Processed: blot
# Processed: blotched
# Processed: blotter
# Processed: blouse
# Processed: blow
# Processed: blower
# Processed: blowfish
# Processed: blowing
# Processed: blowjob
# Processed: blown
# Processed: blowout
# Processed: blowtorch
# Processed: blubber
# Processed: bluddy
# Processed: blue
# Processed: blueberry
# Processed: bluebird
# Processed: bluegrass
# Processed: bluejay
# Processed: blueprint
# Processed: blues
# Processed: bluff
# Processed: bluish
# Processed: blunder
# Processed: blunt
# Processed: blur
# Processed: blurred
# Processed: blurry
# Processed: blurt
# Processed: blush
# Processed: blushing
# Processed: boa
# Processed: boar
# Processed: board
# Processed: boarder
# Processed: boarding
# Processed: boardroom
# Processed: boards
# Processed: boardwalk
# Processed: boast
# Processed: boastful
# Processed: boasting
# Processed: boat
# Processed: boathouse
# Processed: boating
# Processed: boatload
# Processed: boatman
# Processed: bobbin
# Processed: bobcat
# Processed: bobsled
# Processed: bode
# Processed: bodega
# Processed: bodice
# Processed: bodily
# Processed: body
# Processed: bodyguard
# Processed: bog
# Processed: bogey
# Processed: bogeyman
# Processed: bogus
# Processed: bohemian
# Processed: boil
# Processed: boiler
# Processed: boilerplate
# Processed: boiling
# Processed: boisterous
# Processed: bold
# Processed: boldness
# Processed: bollocks
# Processed: bolster
# Processed: bolt
# Processed: bolus
# Processed: bomb
# Processed: bombard
# Processed: bombardier
# Processed: bombardment
# Processed: bombed
# Processed: bomber
# Processed: bombers
# Processed: bombing
# Processed: bombshell
# Processed: bonanza
# Processed: bonbon
# Processed: bond
# Processed: bondage
# Processed: bonding
# Processed: bonds
# Processed: bondsman
# Processed: bone
# Processed: bonehead
# Processed: boner
# Processed: bones
# Processed: bonfire
# Processed: bong
# Processed: bonkers
# Processed: bonne
# Processed: bonnet
# Processed: bonny
# Processed: bonsai
# Processed: bonus
# Processed: bony
# Processed: boo
# Processed: boob
# Processed: booby
# Processed: booger
# Processed: boogeyman
# Processed: boogie
# Processed: book
# Processed: bookcase
# Processed: bookie
# Processed: booking
# Processed: bookish
# Processed: bookkeeper
# Processed: bookkeeping
# Processed: booklet
# Processed: bookmaker
# Processed: bookmark
# Processed: books
# Processed: bookseller
# Processed: bookshop
# Processed: bookstore
# Processed: bookworm
# Processed: boom
# Processed: boomer
# Processed: boomerang
# Processed: booming
# Processed: boon
# Processed: boooo
# Processed: boost
# Processed: booster
# Processed: boot
# Processed: booth
# Processed: bootleg
# Processed: bootlegger
# Processed: boots
# Processed: booty
# Processed: booze
# Processed: bop
# Processed: bopper
# Processed: border
# Processed: bordering
# Processed: borderline
# Processed: bore
# Processed: boreal
# Processed: bored
# Processed: boredom
# Processed: borer
# Processed: boring
# Processed: born
# Processed: boron
# Processed: borough
# Processed: borrow
# Processed: borrower
# Processed: bosom
# Processed: boss
# Processed: bossy
# Processed: boston
# Processed: botanical
# Processed: botanist
# Processed: botany
# Processed: bother
# Processed: bothering
# Processed: bottle
# Processed: bottleneck
# Processed: bottling
# Processed: bottom
# Processed: bottomless
# Processed: botulism
# Processed: boulder
# Processed: bounce
# Processed: bouncer
# Processed: bouncy
# Processed: bound
# Processed: boundary
# Processed: boundless
# Processed: bounds
# Processed: bountiful
# Processed: bounty
# Processed: bouquet
# Processed: bourbon
# Processed: bourgeois
# Processed: bourgeoisie
# Processed: bourse
# Processed: bout
# Processed: boutique
# Processed: bouttime
# Processed: bovine
# Processed: bow
# Processed: bowed
# Processed: bowel
# Processed: bowels
# Processed: bowl
# Processed: bowler
# Processed: bowling
# Processed: bowls
# Processed: box
# Processed: boxcar
# Processed: boxer
# Processed: boxers
# Processed: boxing
# Processed: boycott
# Processed: boyfriend
# Processed: boyhood
# Processed: boyish
# Processed: boysenberry
# Processed: bozo
# Processed: bra
# Processed: brace
# Processed: bracelet
# Processed: braces
# Processed: brachial
# Processed: bracket
# Processed: brackets
# Processed: brackish
# Processed: brad
# Processed: brag
# Processed: braid
# Processed: brain
# Processed: brainless
# Processed: brains
# Processed: brainstorm
# Processed: brainwash
# Processed: brainy
# Processed: brake
# Processed: bran
# Processed: branch
# Processed: branching
# Processed: brand
# Processed: brandy
# Processed: brash
# Processed: brass
# Processed: brassiere
# Processed: brat
# Processed: bratwurst
# Processed: bravado
# Processed: brave
# Processed: bravery
# Processed: brawl
# Processed: brawn
# Processed: brazen
# Processed: breach
# Processed: bread
# Processed: breadth
# Processed: break
# Processed: breakable
# Processed: breakaway
# Processed: breakdown
# Processed: breaker
# Processed: breakers
# Processed: breakfast
# Processed: breakingnews
# Processed: breakneck
# Processed: breakthrough
# Processed: breakup
# Processed: breast
# Processed: breath
# Processed: breathe
# Processed: breather
# Processed: breathless
# Processed: breathtaking
# Processed: breech
# Processed: breeches
# Processed: breed
# Processed: breeder
# Processed: breeding
# Processed: breeze
# Processed: breezy
# Processed: brethren
# Processed: breve
# Processed: brevity
# Processed: brew
# Processed: brewery
# Processed: brewing
# Processed: briar
# Processed: bribe
# Processed: bribery
# Processed: brick
# Processed: bridal
# Processed: bride
# Processed: bridegroom
# Processed: bridesmaid
# Processed: bridge
# Processed: bridle
# Processed: brief
# Processed: briefcase
# Processed: briefing
# Processed: briefly
# Processed: brig
# Processed: brigade
# Processed: bright
# Processed: brighten
# Processed: brightens
# Processed: brighter
# Processed: brightness
# Processed: brilliance
# Processed: brilliant
# Processed: brim
# Processed: brimming
# Processed: brimstone
# Processed: brine
# Processed: bring
# Processed: brink
# Processed: brisk
# Processed: brisket
# Processed: bristle
# Processed: brittle
# Processed: bro
# Processed: broach
# Processed: broad
# Processed: broadcast
# Processed: broadcasting
# Processed: broaden
# Processed: broadside
# Processed: broadsword
# Processed: brocade
# Processed: broccoli
# Processed: brochure
# Processed: broil
# Processed: broke
# Processed: broken
# Processed: brokenheart
# Processed: brokenhearted
# Processed: broker
# Processed: brokerage
# Processed: bromide
# Processed: bronco
# Processed: bronze
# Processed: brooch
# Processed: brood
# Processed: brooding
# Processed: brook
# Processed: broom
# Processed: broomstick
# Processed: broth
# Processed: brothel
# Processed: brother
# Processed: brotherhood
# Processed: brotherly
# Processed: brow
# Processed: brown
# Processed: brownstone
# Processed: browse
# Processed: brrr
# Processed: bruise
# Processed: bruising
# Processed: brunch
# Processed: brunette
# Processed: brunt
# Processed: brush
# Processed: brutal
# Processed: brutality
# Processed: brute
# Processed: brutish
# Processed: bubble
# Processed: bubbling
# Processed: bubbly
# Processed: bubonic
# Processed: buck
# Processed: buckaroo
# Processed: bucket
# Processed: buckle
# Processed: buckled
# Processed: bucko
# Processed: buckshot
# Processed: buckwheat
# Processed: bud
# Processed: buddha
# Processed: buddhism
# Processed: budding
# Processed: buddy
# Processed: budge
# Processed: budget
# Processed: buff
# Processed: buffalo
# Processed: buffer
# Processed: buffering
# Processed: buffet
# Processed: buffoon
# Processed: bug
# Processed: bugaboo
# Processed: bugged
# Processed: bugger
# Processed: buggy
# Processed: bugle
# Processed: bugler
# Processed: build
# Processed: builder
# Processed: building
# Processed: buildings
# Processed: buildup
# Processed: bulb
# Processed: bulbous
# Processed: bulge
# Processed: bulimic
# Processed: bulk
# Processed: bulkhead
# Processed: bulky
# Processed: bull
# Processed: bulldog
# Processed: bulldozer
# Processed: bullet
# Processed: bulletin
# Processed: bulletproof
# Processed: bullfighter
# Processed: bullfrog
# Processed: bullheaded
# Processed: bullhorn
# Processed: bullion
# Processed: bullock
# Processed: bullpen
# Processed: bullshit
# Processed: bully
# Processed: bulwark
# Processed: bum
# Processed: bumblebee
# Processed: bummed
# Processed: bummer
# Processed: bump
# Processed: bumper
# Processed: bumpy
# Processed: bun
# Processed: bunch
# Processed: bundle
# Processed: bungalow
# Processed: bungee
# Processed: bunghole
# Processed: bunion
# Processed: bunk
# Processed: bunker
# Processed: bunkhouse
# Processed: bunny
# Processed: bunt
# Processed: buoy
# Processed: buoyancy
# Processed: buoyant
# Processed: bur
# Processed: burden
# Processed: burdened
# Processed: burdensome
# Processed: bureau
# Processed: bureaucracy
# Processed: bureaucrat
# Processed: bureaucratic
# Processed: burger
# Processed: burglar
# Processed: burglary
# Processed: burial
# Processed: buried
# Processed: burke
# Processed: burlap
# Processed: burlesque
# Processed: burly
# Processed: burn
# Processed: burned
# Processed: burner
# Processed: burning
# Processed: burnished
# Processed: burnout
# Processed: burnt
# Processed: burp
# Processed: burr
# Processed: burrito
# Processed: burro
# Processed: burrow
# Processed: bursary
# Processed: burst
# Processed: bury
# Processed: bus
# Processed: busboy
# Processed: bush
# Processed: bushel
# Processed: bushy
# Processed: business
# Processed: businessman
# Processed: businesswoman
# Processed: busload
# Processed: buss
# Processed: bust
# Processed: busted
# Processed: buster
# Processed: bustle
# Processed: bustling
# Processed: busy
# Processed: busybody
# Processed: butane
# Processed: butcher
# Processed: butler
# Processed: butt
# Processed: butter
# Processed: buttercup
# Processed: butterfly
# Processed: buttermilk
# Processed: butterscotch
# Processed: buttery
# Processed: buttock
# Processed: buttocks
# Processed: button
# Processed: buttress
# Processed: buxom
# Processed: buy
# Processed: buyer
# Processed: buying
# Processed: buzz
# Processed: buzzard
# Processed: buzzed
# Processed: buzzer
# Processed: buzzing
# Processed: bye
# Processed: bygone
# Processed: bylaw
# Processed: byline
# Processed: bypass
# Processed: bystander
# Processed: byte
# Processed: byzantine
# Processed: cab
# Processed: cabal
# Processed: cabana
# Processed: cabaret
# Processed: cabbage
# Processed: cabbie
# Processed: cabernet
# Processed: cabin
# Processed: cabinet
# Processed: cable
# Processed: caboodle
# Processed: caboose
# Processed: cabriolet
# Processed: cache
# Processed: cacophony
# Processed: cactus
# Processed: cad
# Processed: cadaver
# Processed: caddie
# Processed: caddy
# Processed: cadence
# Processed: cadet
# Processed: cafe
# Processed: cafeteria
# Processed: caffeine
# Processed: cage
# Processed: cagey
# Processed: cahoots
# Processed: cairn
# Processed: cake
# Processed: cakewalk
# Processed: calamari
# Processed: calamitous
# Processed: calamity
# Processed: calcareous
# Processed: calcium
# Processed: calculate
# Processed: calculated
# Processed: calculating
# Processed: calculation
# Processed: calculator
# Processed: calculus
# Processed: calendar
# Processed: calender
# Processed: calf
# Processed: caliber
# Processed: calibrate
# Processed: calico
# Processed: calipers
# Processed: calisthenics
# Processed: call
# Processed: callback
# Processed: caller
# Processed: calligraphy
# Processed: calling
# Processed: callous
# Processed: calls
# Processed: calm
# Processed: calming
# Processed: calmness
# Processed: caloric
# Processed: calorie
# Processed: calorimeter
# Processed: cam
# Processed: camaraderie
# Processed: camber
# Processed: camcorder
# Processed: camel
# Processed: cameo
# Processed: camera
# Processed: cameraman
# Processed: camisole
# Processed: camouflage
# Processed: camouflaged
# Processed: camp
# Processed: campaign
# Processed: campaigner
# Processed: campaigning
# Processed: camper
# Processed: campfire
# Processed: camping
# Processed: campsite
# Processed: campus
# Processed: can
# Processed: canal
# Processed: canary
# Processed: cancel
# Processed: canceling
# Processed: cancellation
# Processed: cancer
# Processed: candid
# Processed: candidacy
# Processed: candidate
# Processed: candied
# Processed: candle
# Processed: candlelight
# Processed: candles
# Processed: candlestick
# Processed: candor
# Processed: candy
# Processed: cane
# Processed: canine
# Processed: canister
# Processed: canker
# ...
# Processed: variegated
# Processed: variety
# Processed: various
# Processed: varmint
# Processed: varnish
# Processed: varsity
# Processed: vary
# Processed: varying
# Processed: vascular
# Processed: vase
# Processed: vasectomy
# Processed: vassal
# Processed: vast
# Processed: vat
# Processed: vaudeville
# Processed: vault
# Processed: vaulted
# Processed: vaulting
# Processed: veal
# Processed: vector
# Processed: veer
# Processed: vega
# Processed: vegan
# Processed: vegetable
# Processed: vegetarian
# Processed: vegetarianism
# Processed: vegetation
# Processed: vegetative
# Processed: veggie
# Processed: vehement
# Processed: vehicle
# Processed: veil
# Processed: veiled
# Processed: vein
# Processed: veined
# Processed: vellum
# Processed: velocity
# Processed: velour
# Processed: velvet
# Processed: velvety
# Processed: vena
# Processed: vendetta
# Processed: vending
# Processed: vendor
# Processed: veneer
# Processed: venerable
# Processed: veneration
# Processed: venereal
# Processed: venetian
# Processed: vengeance
# Processed: vengeful
# Processed: venison
# Processed: venom
# Processed: venomous
# Processed: venous
# Processed: vent
# Processed: ventilation
# Processed: ventilator
# Processed: venting
# Processed: ventricle
# Processed: ventricular
# Processed: ventriloquist
# Processed: venture
# Processed: venue
# Processed: veracity
# Processed: veranda
# Processed: verb
# Processed: verbal
# Processed: verbatim
# Processed: verbiage
# Processed: verbose
# Processed: verbosity
# Processed: verdant
# Processed: verdict
# Processed: verge
# Processed: verification
# Processed: verified
# Processed: verify
# Processed: verily
# Processed: veritable
# Processed: vermin
# Processed: vermouth
# Processed: vernacular
# Processed: vernal
# Processed: veronica
# Processed: versatile
# Processed: versatility
# Processed: verse
# Processed: version
# Processed: versus
# Processed: vert
# Processed: vertebra
# Processed: vertebral
# Processed: vertex
# Processed: vertical
# Processed: vertically
# Processed: vertigo
# Processed: verve
# Processed: veryangry
# Processed: vesicle
# Processed: vesicular
# Processed: vessel
# Processed: vest
# Processed: vested
# Processed: vestibule
# Processed: vestige
# Processed: vet
# Processed: veteran
# Processed: veterinarian
# Processed: veterinary
# Processed: veto
# Processed: vexed
# Processed: viability
# Processed: viable
# Processed: viaduct
# Processed: vial
# Processed: vibe
# Processed: vibes
# Processed: vibrant
# Processed: vibrate
# Processed: vibration
# Processed: vibrator
# Processed: vibratory
# Processed: vicar
# Processed: vicarious
# Processed: vice
# Processed: viceroy
# Processed: vicinity
# Processed: vicious
# Processed: victim
# Processed: victimized
# Processed: victor
# Processed: victoria
# Processed: victorious
# Processed: victory
# Processed: video
# Processed: videotape
# Processed: vie
# Processed: view
# Processed: viewer
# Processed: viewing
# Processed: viewpoint
# Processed: vigil
# Processed: vigilance
# Processed: vigilant
# Processed: vigilante
# Processed: vignette
# Processed: vigor
# Processed: vigorous
# Processed: viking
# Processed: vile
# Processed: villa
# Processed: village
# Processed: villager
# Processed: villain
# Processed: villainous
# Processed: vinaigrette
# Processed: vindicate
# Processed: vindicated
# Processed: vindication
# Processed: vindictive
# Processed: vine
# Processed: vinegar
# Processed: vineyard
# Processed: vintage
# Processed: vinyl
# Processed: viola
# Processed: violate
# Processed: violation
# Processed: violence
# Processed: violent
# Processed: violently
# Processed: violet
# Processed: violin
# Processed: violinist
# Processed: viper
# Processed: viral
# Processed: virgin
# Processed: virginal
# Processed: virginity
# Processed: virility
# Processed: virology
# Processed: virtual
# Processed: virtually
# Processed: virtue
# Processed: virtuoso
# Processed: virtuous
# Processed: virulence
# Processed: virus
# Processed: visa
# Processed: visage
# Processed: viscosity
# Processed: viscous
# Processed: vise
# Processed: visibility
# Processed: visible
# Processed: visibly
# Processed: vision
# Processed: visionary
# Processed: visit
# Processed: visitation
# Processed: visiting
# Processed: visitor
# Processed: visor
# Processed: vista
# Processed: visual
# Processed: visualize
# Processed: vital
# Processed: vitality
# Processed: vitals
# Processed: vitamin
# Processed: vitreous
# Processed: viva
# Processed: vivacious
# Processed: vivid
# Processed: vixen
# Processed: vocabulary
# Processed: vocal
# Processed: vocalist
# Processed: vocation
# Processed: vodka
# Processed: vogue
# Processed: voice
# Processed: voiceless
# Processed: voicemail
# Processed: void
# Processed: volatile
# Processed: volatility
# Processed: volcanic
# Processed: volcano
# Processed: volition
# Processed: volley
# Processed: volleyball
# Processed: voltage
# Processed: voltmeter
# Processed: volume
# Processed: volumes
# Processed: voluminous
# Processed: voluntarily
# Processed: voluntary
# Processed: volunteer
# Processed: volunteering
# Processed: volunteers
# Processed: voluptuous
# Processed: vomit
# Processed: vomiting
# Processed: voodoo
# Processed: voracious
# Processed: vortex
# Processed: vote
# Processed: voter
# Processed: voting
# Processed: votive
# Processed: vouch
# Processed: voucher
# Processed: vow
# Processed: vowel
# Processed: voyage
# Processed: voyager
# Processed: voyeur
# Processed: vulgar
# Processed: vulgarity
# Processed: vulnerability
# Processed: vulnerable
# Processed: vulture
# Processed: wacko
# Processed: wacky
# Processed: wad
# Processed: waddle
# Processed: wade
# Processed: wafer
# Processed: waffle
# Processed: wag
# Processed: wage
# Processed: wager
# Processed: wages
# Processed: wagon
# Processed: wail
# Processed: waist
# Processed: waistcoat
# Processed: waistline
# Processed: wait
# Processed: waiter
# Processed: waiting
# Processed: waitinggame
# Processed: waitress
# Processed: waive
# Processed: waiver
# Processed: wake
# Processed: walk
# Processed: walker
# Processed: walking
# Processed: walkout
# Processed: wall
# Processed: wallaby
# Processed: wallet
# Processed: wallflower
# Processed: wallop
# Processed: wallow
# Processed: wallpaper
# Processed: walnut
# Processed: walrus
# Processed: waltz
# Processed: wan
# Processed: wand
# Processed: wander
# Processed: wanderer
# Processed: wandering
# Processed: wane
# Processed: waning
# Processed: wanker
# Processed: wannabe
# Processed: wannasleep
# Processed: want
# Processed: wanting
# Processed: wanton
# Processed: war
# Processed: warbler
# Processed: warcrimes
# Processed: ward
# Processed: warden
# Processed: wardrobe
# Processed: ware
# Processed: warehouse
# Processed: warfare
# Processed: warhead
# Processed: warlike
# Processed: warlock
# Processed: warlord
# Processed: warm
# Processed: warming
# Processed: warms
# Processed: warmth
# Processed: warn
# Processed: warned
# Processed: warning
# Processed: warp
# Processed: warpath
# Processed: warped
# Processed: warrant
# Processed: warranted
# Processed: warrants
# Processed: warranty
# Processed: warren
# Processed: warrior
# Processed: warship
# Processed: wart
# Processed: wartime
# Processed: wary
# Processed: wash
# Processed: washed
# Processed: washer
# Processed: washing
# Processed: washout
# Processed: washroom
# Processed: wasp
# Processed: waste
# Processed: wastebasket
# Processed: wasted
# Processed: wasteful
# Processed: wasteland
# Processed: wasting
# Processed: watch
# Processed: watchdog
# Processed: watcher
# Processed: watchful
# Processed: watchman
# Processed: watchout
# Processed: watchtower
# Processed: water
# Processed: waterbed
# Processed: watercourse
# Processed: watered
# Processed: waterfall
# Processed: waterfront
# Processed: watermelon
# Processed: waterproof
# Processed: waterworks
# Processed: watery
# Processed: wave
# Processed: wavelength
# Processed: waver
# Processed: wavering
# Processed: waves
# Processed: wavy
# Processed: wax
# Processed: waxed
# Processed: waxy
# Processed: way
# Processed: ways
# Processed: wayward
# Processed: weak
# Processed: weaken
# Processed: weakened
# Processed: weakling
# Processed: weakly
# Processed: weakness
# Processed: wealth
# Processed: wealthy
# Processed: weapon
# Processed: weaponry
# Processed: wear
# Processed: wearer
# Processed: wearily
# Processed: weariness
# Processed: wearing
# Processed: weary
# Processed: weasel
# Processed: weather
# Processed: weathered
# Processed: weatherman
# Processed: weatherproof
# Processed: weave
# Processed: web
# Processed: website
# Processed: wed
# Processed: wedded
# Processed: wedding
# Processed: wedge
# Processed: wedlock
# Processed: wee
# Processed: weed
# Processed: weeding
# Processed: weeds
# Processed: weedy
# Processed: weeeee
# Processed: week
# Processed: weekday
# Processed: weekend
# Processed: weekly
# Processed: weenie
# Processed: weep
# Processed: weeping
# Processed: weepy
# Processed: weigh
# Processed: weighing
# Processed: weight
# Processed: weightless
# Processed: weightloss
# Processed: weights
# Processed: weighty
# Processed: weir
# Processed: weird
# Processed: weirdness
# Processed: weirdo
# Processed: welcome
# Processed: welcomed
# Processed: welcoming
# Processed: weld
# Processed: welder
# Processed: welding
# Processed: welfare
# Processed: wellhead
# Processed: wellness
# Processed: welsh
# Processed: welt
# Processed: wen
# Processed: wench
# Processed: werewolf
# Processed: west
# Processed: westbound
# Processed: western
# Processed: wet
# Processed: wetback
# Processed: whack
# Processed: whale
# Processed: whaling
# Processed: wham
# Processed: whammy
# Processed: wharf
# Processed: whatdoido
# Processed: whatif
# Processed: whatmakesmesmile
# Processed: whatnot
# Processed: whatsoever
# Processed: whatsthepoint
# Processed: wheat
# Processed: wheel
# Processed: wheelbarrow
# Processed: wheelchair
# Processed: wheels
# Processed: wheeze
# Processed: whelp
# Processed: whereabouts
# Processed: wherefore
# Processed: wherewith
# Processed: wherewithal
# Processed: whet
# Processed: whiff
# Processed: whilst
# Processed: whim
# Processed: whimper
# Processed: whimsical
# Processed: whimsy
# Processed: whine
# Processed: whiny
# Processed: whip
# Processed: whiplash
# Processed: whipped
# Processed: whirl
# Processed: whirlpool
# Processed: whirlwind
# Processed: whisk
# Processed: whisker
# Processed: whiskers
# Processed: whiskey
# Processed: whisky
# Processed: whisper
# Processed: whispered
# Processed: whistle
# Processed: whit
# Processed: whitefish
# Processed: whiteness
# Processed: whitewash
# Processed: whitish
# Processed: whittle
# Processed: whiz
# Processed: whole
# Processed: wholesale
# Processed: wholesome
# Processed: wholly
# Processed: whoo
# Processed: whoop
# Processed: whopper
# Processed: whopping
# Processed: whore
# Processed: whorehouse
# Processed: wick
# Processed: wicked
# Processed: wickedness
# Processed: wicker
# Processed: wicket
# Processed: wide
# Processed: widely
# Processed: widen
# Processed: widespread
# Processed: widow
# Processed: widowed
# Processed: widower
# Processed: width
# Processed: wield
# Processed: wiener
# Processed: wienie
# Processed: wife
# Processed: wig
# Processed: wiggle
# Processed: wight
# Processed: wiki
# Processed: wild
# Processed: wildcat
# Processed: wildebeest
# Processed: wilderness
# Processed: wildfire
# Processed: wildlife
# Processed: will
# Processed: willful
# Processed: willies
# Processed: willing
# Processed: willingly
# Processed: willingness
# Processed: willow
# Processed: willpower
# Processed: wilt
# Processed: wilted
# Processed: wily
# Processed: wimp
# Processed: wimpy
# Processed: win
# Processed: wince
# Processed: winch
# Processed: wind
# Processed: windbag
# Processed: windfall
# Processed: winding
# Processed: windmill
# Processed: window
# Processed: windowsill
# Processed: windpipe
# Processed: windshield
# Processed: windy
# Processed: wine
# Processed: wing
# Processed: winged
# Processed: winger
# Processed: wingman
# Processed: wink
# Processed: winner
# Processed: winning
# Processed: winnings
# Processed: wino
# Processed: winter
# Processed: winterbreak
# Processed: wintertime
# Processed: wintery
# Processed: wintry
# Processed: wipe
# Processed: wiper
# Processed: wire
# Processed: wired
# Processed: wireless
# Processed: wiretap
# Processed: wiring
# Processed: wis
# Processed: wisdom
# Processed: wise
# Processed: wish
# Processed: wishbone
# Processed: wishful
# Processed: wishing
# Processed: wishmeluck
# Processed: wisp
# Processed: wistful
# Processed: wit
# Processed: witch
# Processed: witchcraft
# Processed: withal
# Processed: withdraw
# Processed: withdrawal
# Processed: withdrawals
# Processed: withdrawn
# Processed: wither
# Processed: withered
# Processed: withering
# Processed: withhold
# Processed: withholding
# Processed: withstand
# Processed: witless
# Processed: witness
# Processed: wits
# Processed: witty
# Processed: wiz
# Processed: wizard
# Processed: wobble
# Processed: wobbly
# Processed: woe
# Processed: woeful
# Processed: woefully
# Processed: wok
# Processed: wokemeup
# Processed: wolf
# Processed: wolverine
# Processed: womanhood
# Processed: womanizer
# Processed: womanly
# Processed: womb
# Processed: wonder
# Processed: wonderful
# Processed: wonderfully
# Processed: wonderment
# Processed: wondrous
# Processed: wont
# Processed: woo
# Processed: wood
# Processed: woodcut
# Processed: wooden
# Processed: woodland
# Processed: woodlands
# Processed: woodpecker
# Processed: woods
# Processed: woodshed
# Processed: woodsman
# Processed: woodwork
# Processed: woody
# Processed: woof
# Processed: woohoo
# Processed: wooing
# Processed: wool
# Processed: woolen
# Processed: woolly
# Processed: woot
# Processed: woozy
# Processed: wop
# Processed: word
# Processed: wording
# Processed: words
# Processed: wordy
# Processed: work
# Processed: workaholic
# Processed: workbook
# Processed: worker
# Processed: working
# Processed: workings
# Processed: workload
# Processed: workman
# Processed: workmanship
# Processed: workout
# Processed: workplace
# Processed: works
# Processed: workshop
# Processed: workup
# Processed: world
# Processed: worldly
# Processed: worldwide
# Processed: worm
# Processed: wormhole
# Processed: wormwood
# Processed: worn
# Processed: worried
# Processed: worries
# Processed: worry
# Processed: worrying
# Processed: worse
# Processed: worsening
# Processed: worship
# Processed: worshipful
# Processed: worstfeeling
# Processed: worth
# Processed: worthless
# Processed: worthwhile
# Processed: worthy
# Processed: wot
# Processed: would
# Processed: wound
# Processed: wounded
# Processed: wounding
# Processed: wounds
# Processed: wracking
# Processed: wrangler
# Processed: wrangling
# Processed: wrap
# Processed: wrapper
# Processed: wrapping
# Processed: wrath
# Processed: wrathful
# Processed: wreak
# Processed: wreath
# Processed: wreck
# Processed: wreckage
# Processed: wrecked
# Processed: wrecker
# Processed: wrench
# Processed: wrenching
# Processed: wrest
# Processed: wrestle
# Processed: wrestler
# Processed: wrestling
# Processed: wretch
# Processed: wretched
# Processed: wriggle
# Processed: wright
# Processed: wring
# Processed: wringer
# Processed: wrinkle
# Processed: wrinkled
# Processed: wrist
# Processed: wristband
# Processed: wristwatch
# Processed: writ
# Processed: write
# Processed: writer
# Processed: writing
# Processed: written
# Processed: wrong
# Processed: wrongdoing
# Processed: wrongful
# Processed: wrongly
# Processed: wrought
# Processed: wry
# Processed: xanax
# Processed: xenophobia
# Processed: xerox
# Processed: xmas
# Processed: xoxo
# Processed: yaaaay
# Processed: yaaay
# Processed: yaay
# Processed: yacht
# Processed: yachting
# Processed: yahoo
# Processed: yak
# Processed: yam
# Processed: yank
# Processed: yap
# Processed: yard
# Processed: yarn
# Processed: yaw
# Processed: yawn
# Processed: yawning
# Processed: yay
# Processed: yayy
# Processed: yayyy
# Processed: yayyyy
# Processed: yea
# Processed: yeahhh
# Processed: yeahhhh
# Processed: year
# Processed: yearbook
# Processed: yearling
# Processed: yearly
# Processed: yearn
# Processed: yearning
# Processed: years
# Processed: yeast
# Processed: yehey
# Processed: yell
# Processed: yeller
# Processed: yelling
# Processed: yellow
# Processed: yellows
# Processed: yelp
# Processed: yen
# Processed: yeoman
# Processed: yesss
# Processed: yessss
# Processed: yesterday
# Processed: yesteryear
# Processed: yew
# Processed: yey
# Processed: yield
# Processed: yielding
# Processed: yo-yo
# Processed: yodel
# Processed: yoga
# Processed: yogi
# Processed: yogurt
# Processed: yoke
# Processed: yolk
# Processed: yon
# Processed: yonder
# Processed: youngster
# Processed: yousuck
# Processed: youth
# Processed: youthful
# Processed: yucky
# Processed: yuletide
# Processed: yummy
# Processed: yuppie
# Processed: zany
# Processed: zap
# Processed: zeal
# Processed: zealot
# Processed: zealous
# Processed: zebra
# Processed: zen
# Processed: zenith
# Processed: zephyr
# Processed: zeppelin
# Processed: zest
# Processed: zesty
# Processed: zeta
# Processed: zigzag
# Processed: zilch
# Processed: zillion
# Processed: zinc
# Processed: zing
# Processed: zip
# Processed: zipper
# Processed: zippy
# Processed: zit
# Processed: zodiac
# Processed: zombie
# Processed: zone
# Processed: zoning
# Processed: zoo
# Processed: zoological
# Processed: zoology
# Processed: zoom
# Processed: zucchini
# Processing completed!

# %% [markdown]
# # 아마존 데이터 감정 분석

# %%
import torch
from transformers import BertTokenizer, BertModel
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from typing import List, Tuple, Dict

class SimplifiedSentimentMapper:
    def __init__(self, model_name: str = 'bert-base-uncased', lexicon_embeddings_path: str = 'lexicon_embeddings.csv'):
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.tokenizer = BertTokenizer.from_pretrained(model_name)
        self.model = BertModel.from_pretrained(model_name).to(self.device)
        self.model.eval()
        
        # 렉시콘 임베딩 로드
        self.lexicon_data = pd.read_csv(lexicon_embeddings_path)
        self.lexicon_embeddings = np.array([np.array(eval(emb)) for emb in self.lexicon_data['embedding']])
    
    def get_cls_embedding(self, text: str) -> np.ndarray:
        # 전처리 및 토큰화
        inputs = self.tokenizer(
            text.lower(),
            return_tensors='pt',
            padding=True,
            truncation=True,
            max_length=512
        ).to(self.device)
        
        with torch.no_grad():
            outputs = self.model(**inputs)
            cls_embedding = outputs.last_hidden_state[:, 0, :].cpu().numpy()[0]
        
        return cls_embedding
    
    def find_most_similar_word(self, cls_embedding: np.ndarray) -> Dict:
        """CLS 임베딩과 가장 유사한 단어 하나를 찾음"""
        similarities = cosine_similarity([cls_embedding], self.lexicon_embeddings)[0]
        top_idx = np.argmax(similarities)
        
        return {
            'word': self.lexicon_data.iloc[top_idx]['word'],
            'valence': self.lexicon_data.iloc[top_idx]['valence'],
            'arousal': self.lexicon_data.iloc[top_idx]['arousal'],
            'similarity': similarities[top_idx]
        }
    
    def get_sentiment_coordinates(self, text: str) -> Tuple[float, float, Dict]:
        """문장의 CLS 임베딩을 기반으로 VA 좌표와 가장 유사한 단어 반환"""
        cls_embedding = self.get_cls_embedding(text)
        most_similar = self.find_most_similar_word(cls_embedding)
        
        return most_similar['valence'], most_similar['arousal'], most_similar
    
    def process_reviews(self, reviews: List[str], output_file: str = 'review_va_coordinates.csv'):
        """여러 리뷰 텍스트를 처리하여 VA 좌표 저장"""
        results = []
        for i, review in enumerate(reviews):
            print(f"Processing review {i+1}/{len(reviews)}")
            valence, arousal, similar_word = self.get_sentiment_coordinates(review)
            results.append({
                'text': review,
                'valence': valence,
                'arousal': arousal,
                'most_similar_word': similar_word['word'],
                'similarity_score': similar_word['similarity']
            })
        
        df = pd.DataFrame(results)
        df.to_csv(output_file, index=False)
        print(f"Results saved to {output_file}")
        return df

def main():
    # ContextAwareSentimentMapper 초기화
    mapper = SimplifiedSentimentMapper(lexicon_embeddings_path=r"C:\Users\Administrator\Desktop\lexicon_embeddings.csv")
    
    print("텍스트 분석 방식을 선택하세요:")
    print("1. CSV 파일 분석")
    print("2. 테스트 텍스트 분석")
    choice = input("선택 (1 또는 2): ")
    
    if choice == '1':
        # CSV 파일 경로 입력
        file_path_choose = input("원하는 csv 파일을 선택하세요:")
        print("1. Amazon Reviews")
        print("2. Audible Reviews")
        print("3. Hotel Reviews")
        print("4. Coursera Reviews")
        if file_path_choose == '1':
            file_path = r"C:\Users\Administrator\Desktop\PADA_LAB\calculated\final\amazon_reviews_with_topics_and_depth_breadth.csv"
        elif file_path_choose == '2':
            file_path = r"C:\Users\Administrator\Desktop\PADA_LAB\calculated\final\audible_reviews_with_topics_and_depth_breadth.csv"
        elif file_path_choose == '3':
            file_path = r"C:\Users\Administrator\Desktop\PADA_LAB\calculated\final\hotel_reviews_with_topics_and_depth_breadth.csv"
        elif file_path_choose == '4':
            file_path = r"C:\Users\Administrator\Desktop\PADA_LAB\calculated\final\coursera_reviews_with_topics_and_depth_breadth.csv"  
        column_name = "Review_Text"
        
        try:
            # 데이터프레임 로드
            df = pd.read_csv(file_path)
            reviews = df[column_name].tolist()
            
            # VA 좌표 계산 및 결과 저장
            print(f"\nTotal reviews to process: {len(reviews)}")
            results = mapper.process_reviews(reviews)
            print("\nProcessing completed!")
            
            # 원본 데이터프레임에 VA 좌표 추가
            df['valence'] = results['valence']
            df['arousal'] = results['arousal']
            
            # 결과 저장
            output_path = file_path.replace('.csv', '_with_va_score.csv')
            df.to_csv(output_path, index=False)
            print(f"Results saved to {output_path}")
            
        except Exception as e:
            print(f"오류 발생: {str(e)}")
    
    elif choice == '2':
        # 테스트용 텍스트 목록
        test_texts = [
                "The course is well paced and they get you comfortable with the topics even though we do not have any sort of prior exposure in this field. It is very good for the beginners who are new to this field",
                "Information was well organized, easy to learn, and study. with frequent note writing, and some breaks . You can learn a good brief summary of what's to come, and what to research more in the future.",
                "A lot of explanations not provided! Too many peer-graded assignments, really disappointed!",
                "I enjoyed both The Martian and Artemis so I preordered this one and started it immediately It did not disappoint Andy Weir is one of my favorite authors and Ray Porter is one of my favorite narrators so this combination is a winwin The narration is superb and the writing is great I recommend this book Dont over think it This is worth the price of admissionDisclaimer My enjoyment of the narrator is based on my listening speed I only leave 5 stars for books Ive listened to or will listen to multiple times",
                "Great story but a little winded Interesting story and great concept, but it dragged a little too much in the middle I love a long book but it wasnt really adding much value"
        ]
        
        # VA 좌표 계산
        print(f"\nTotal texts to process: {len(test_texts)}")
        results = mapper.process_reviews(test_texts)
    
        print("\nAnalysis Results:")
        for i, row in results.iterrows():
            print(f"\nText {i+1}: {row['text'][:100]}...")
            print(f"Most similar word: {row['most_similar_word']} (similarity: {row['similarity_score']:.4f})")
            print(f"Valence: {row['valence']:.3f}")
            print(f"Arousal: {row['arousal']:.3f}")

if __name__ == "__main__":
    main()
# Out:
# 텍스트 분석 방식을 선택하세요:
# 1. CSV 파일 분석
# 2. 테스트 텍스트 분석
#
# Total texts to process: 5
# Processing review 1/5
# Processing review 2/5
# Processing review 3/5
# Processing review 4/5
# Processing review 5/5
# Results saved to review_va_coordinates.csv
#
# Analysis Results:
#
# Text 1: The course is well paced and they get you comfortable with the topics even though we do not have any...
# Most similar word: motivational (similarity: 0.7716)
# Valence: 0.812
# Arousal: 0.292
#
# Text 2: Information was well organized, easy to learn, and study. with frequent note writing, and some break...
# Most similar word: particulars (similarity: 0.7718)
# Valence: 0.208
# Arousal: -0.304
#
# Text 3: A lot of explanations not provided! Too many peer-graded assignments, really disappointed!...
# Most similar word: overworked (similarity: 0.8551)
# Valence: -0.734
# Arousal: 0.340
#
# Text 4: I enjoyed both The Martian and Artemis so I preordered this one and started it immediately It did no...
# Most similar word: goodtimes (similarity: 0.8404)
# Valence: 0.820
# Arousal: 0.052
#
# Text 5: Great story but a little winded Interesting story and great concept, but it dragged a little too muc...
# Most similar word: alreadyyyyy (similarity: 0.7646)
# Valence: 0.184
# Arousal: 0.434
