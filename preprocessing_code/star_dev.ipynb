# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/hyunwoo/Desktop/PADA_hotel_data/data_updated_1216/Hotel_merged.csv')
df.head()
# Out:
#     Hotel_Name                                        Review_Text Posted_Date  \
# 0  studios2let  Perfect location with good connections and sho...  2024-05-01
# 1  studios2let  The room had everything you needed. Near to am...  2024-12-02
# 2  studios2let  Conveniently nearby St. Pancras, very small bu...  2024-12-01
# 3  studios2let         Reception staffed 24 hours a day.All good.  2024-12-01
# 4  studios2let  Very convenient to King’s Cross and the cityA ...  2024-11-30
#
#    Rating  Average_Rating  Num_of_Ratings  Helpfulness  is_photo  \
# 0    10.0             7.6           11670            0         0
# 1     8.0             7.6           11670            0         0
# 2     8.0             7.6           11670            0         0
# 3     9.0             7.6           11670            0         0
# 4     8.0             7.6           11670            0         0
#
#                                         review_title  hotel_grade  \
# ...

# %%
df['Deviation of star ratings'] = abs(df['Rating'] - df['Average_Rating'])
df
# Out:
#           Hotel_Name                                        Review_Text  \
# 0        studios2let  Perfect location with good connections and sho...
# 1        studios2let  The room had everything you needed. Near to am...
# 2        studios2let  Conveniently nearby St. Pancras, very small bu...
# 3        studios2let         Reception staffed 24 hours a day.All good.
# 4        studios2let  Very convenient to King’s Cross and the cityA ...
# ...              ...                                                ...
# 135375  montanahotel                                                NaN
# 135376  montanahotel                                                NaN
# 135377  montanahotel                                                NaN
# 135378  montanahotel                                                NaN
# 135379  montanahotel                                                NaN
#
#        Posted_Date  Rating  Average_Rating  Num_of_Ratings  Helpfulness  \
# ...

# %%
# file_path = '/Users/hyunwoo/Desktop/PADA_hotel_data/data_updated_1216/Hotel_merged.csv'
# df.to_csv(file_path,index = False)  --> 수정하면 됩니다..
