# %%
# 필요한 라이브러리 임포트
from contextualized_topic_models.models.ctm import CombinedTopicModel
from contextualized_topic_models.utils.preprocessing import WhiteSpacePreprocessing
from contextualized_topic_models.utils.data_preparation import TopicModelDataPreparation
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
from scipy.stats import entropy

# 데이터프레임(df)에 'Review_Text' 열이 존재해야 합니다.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[38], line 2
#       1 # 필요한 라이브러리 임포트
# ----> 2 from contextualized_topic_models.models.ctm import CombinedTopicModel
#       3 from contextualized_topic_models.utils.preprocessing import WhiteSpacePreprocessing
#       4 from contextualized_topic_models.utils.data_preparation import TopicModelDataPreparation
#
# ModuleNotFoundError: No module named 'contextualized_topic_models'

# %%
pip install contextualized_topic_models
# Out:
# Collecting contextualized_topic_models
#   Using cached contextualized_topic_models-2.5.0-py2.py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: numpy>=1.19.1 in /opt/anaconda3/lib/python3.12/site-packages (from contextualized_topic_models) (1.26.4)
# Requirement already satisfied: torchvision>=0.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from contextualized_topic_models) (0.20.1)
# Requirement already satisfied: torch>=1.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from contextualized_topic_models) (2.5.1)
# Collecting gensim==4.2.0 (from contextualized_topic_models)
#   Using cached gensim-4.2.0.tar.gz (23.2 MB)
#   Preparing metadata (setup.py) ... done
# Collecting sentence-transformers>=2.1.1 (from contextualized_topic_models)
#   Using cached sentence_transformers-3.3.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: wordcloud>=1.8.1 in /opt/anaconda3/lib/python3.12/site-packages (from contextualized_topic_models) (1.9.4)
# Requirement already satisfied: matplotlib>=3.1.3 in /opt/anaconda3/lib/python3.12/site-packages (from contextualized_topic_models) (3.7.5)
# Requirement already satisfied: tqdm>=4.56.0 in /opt/anaconda3/lib/python3.12/site-packages (from contextualized_topic_models) (4.66.5)
# Requirement already satisfied: scipy>=1.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from contextualized_topic_models) (1.11.4)
# Collecting ipywidgets==7.5.1 (from contextualized_topic_models)
#   Using cached ipywidgets-7.5.1-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting ipython==8.10.0 (from contextualized_topic_models)
#   Using cached ipython-8.10.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: smart_open>=1.8.1 in /opt/anaconda3/lib/python3.12/site-packages (from gensim==4.2.0->contextualized_topic_models) (5.2.1)
# Collecting backcall (from ipython==8.10.0->contextualized_topic_models)
#   Using cached backcall-0.2.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.12/site-packages (from ipython==8.10.0->contextualized_topic_models) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.12/site-packages (from ipython==8.10.0->contextualized_topic_models) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/lib/python3.12/site-packages (from ipython==8.10.0->contextualized_topic_models) (0.1.6)
# Requirement already satisfied: pickleshare in /opt/anaconda3/lib/python3.12/site-packages (from ipython==8.10.0->contextualized_topic_models) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /opt/anaconda3/lib/python3.12/site-packages (from ipython==8.10.0->contextualized_topic_models) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from ipython==8.10.0->contextualized_topic_models) (2.15.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.12/site-packages (from ipython==8.10.0->contextualized_topic_models) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /opt/anaconda3/lib/python3.12/site-packages (from ipython==8.10.0->contextualized_topic_models) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.12/site-packages (from ipython==8.10.0->contextualized_topic_models) (4.8.0)
# Requirement already satisfied: appnope in /opt/anaconda3/lib/python3.12/site-packages (from ipython==8.10.0->contextualized_topic_models) (0.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/anaconda3/lib/python3.12/site-packages (from ipywidgets==7.5.1->contextualized_topic_models) (6.28.0)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from ipywidgets==7.5.1->contextualized_topic_models) (5.10.4)
# Collecting widgetsnbextension~=3.5.0 (from ipywidgets==7.5.1->contextualized_topic_models)
#   Using cached widgetsnbextension-3.5.2-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.1.3->contextualized_topic_models) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.1.3->contextualized_topic_models) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.1.3->contextualized_topic_models) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.1.3->contextualized_topic_models) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.1.3->contextualized_topic_models) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.1.3->contextualized_topic_models) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.1.3->contextualized_topic_models) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.1.3->contextualized_topic_models) (2.9.0.post0)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence-transformers>=2.1.1->contextualized_topic_models)
#   Using cached transformers-4.47.1-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers>=2.1.1->contextualized_topic_models) (1.4.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers>=2.1.1->contextualized_topic_models) (0.26.3)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.6.0->contextualized_topic_models) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.6.0->contextualized_topic_models) (4.11.0)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.6.0->contextualized_topic_models) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.6.0->contextualized_topic_models) (3.1.4)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.6.0->contextualized_topic_models) (2024.6.1)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.6.0->contextualized_topic_models) (75.6.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.6.0->contextualized_topic_models) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.6.0->contextualized_topic_models) (1.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=2.1.1->contextualized_topic_models) (6.0.1)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=2.1.1->contextualized_topic_models) (2.32.3)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.5.1->contextualized_topic_models) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.5.1->contextualized_topic_models) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.5.1->contextualized_topic_models) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.5.1->contextualized_topic_models) (5.7.2)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.5.1->contextualized_topic_models) (1.6.0)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.5.1->contextualized_topic_models) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.5.1->contextualized_topic_models) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.5.1->contextualized_topic_models) (6.4.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from jedi>=0.16->ipython==8.10.0->contextualized_topic_models) (0.8.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/lib/python3.12/site-packages (from nbformat>=4.2.0->ipywidgets==7.5.1->contextualized_topic_models) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /opt/anaconda3/lib/python3.12/site-packages (from nbformat>=4.2.0->ipywidgets==7.5.1->contextualized_topic_models) (4.23.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.12/site-packages (from pexpect>4.3->ipython==8.10.0->contextualized_topic_models) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython==8.10.0->contextualized_topic_models) (0.2.5)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->contextualized_topic_models) (1.16.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.1.1->contextualized_topic_models) (2024.9.11)
# Collecting tokenizers<0.22,>=0.21 (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.1.1->contextualized_topic_models)
#   Using cached tokenizers-0.21.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.1 (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.1.1->contextualized_topic_models)
#   Using cached safetensors-0.4.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Requirement already satisfied: notebook>=4.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (7.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch>=1.6.0->contextualized_topic_models) (2.1.3)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn->sentence-transformers>=2.1.1->contextualized_topic_models) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn->sentence-transformers>=2.1.1->contextualized_topic_models) (3.5.0)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython==8.10.0->contextualized_topic_models) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython==8.10.0->contextualized_topic_models) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython==8.10.0->contextualized_topic_models) (0.2.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.5.1->contextualized_topic_models) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.5.1->contextualized_topic_models) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.5.1->contextualized_topic_models) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.5.1->contextualized_topic_models) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.5.1->contextualized_topic_models) (3.10.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/anaconda3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /opt/anaconda3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (0.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=2.1.1->contextualized_topic_models) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=2.1.1->contextualized_topic_models) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=2.1.1->contextualized_topic_models) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=2.1.1->contextualized_topic_models) (2024.8.30)
# Requirement already satisfied: anyio>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (7.16.4)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (0.14.1)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (2.2.0)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (0.9.6)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in /opt/anaconda3/lib/python3.12/site-packages (from babel>=2.10->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (2024.1)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (0.14.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (4.1.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (1.5.0)
# Requirement already satisfied: tinycss2 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (1.2.1)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (0.5.1)
# Requirement already satisfied: fqdn in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (2.1)
# Requirement already satisfied: uri-template in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (2.5)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.5.1->contextualized_topic_models) (1.2.3)
# Using cached contextualized_topic_models-2.5.0-py2.py3-none-any.whl (36 kB)
# Using cached ipython-8.10.0-py3-none-any.whl (784 kB)
# Using cached ipywidgets-7.5.1-py2.py3-none-any.whl (121 kB)
# Using cached sentence_transformers-3.3.1-py3-none-any.whl (268 kB)
# Using cached transformers-4.47.1-py3-none-any.whl (10.1 MB)
# Using cached widgetsnbextension-3.5.2-py2.py3-none-any.whl (1.6 MB)
# Using cached backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Using cached safetensors-0.4.5-cp312-cp312-macosx_11_0_arm64.whl (381 kB)
# Using cached tokenizers-0.21.0-cp39-abi3-macosx_11_0_arm64.whl (2.6 MB)
# Building wheels for collected packages: gensim
#   Building wheel for gensim (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [866 lines of output]
#       /opt/anaconda3/lib/python3.12/site-packages/setuptools/__init__.py:94: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#       !!
#
#               ********************************************************************************
#               Requirements should be satisfied by a PEP 517 installer.
#               If you are using pip, you can try `pip install --use-pep517`.
#               ********************************************************************************
#
#       !!
#         dist.fetch_build_eggs(dist.setup_requires)
#       /opt/anaconda3/lib/python3.12/site-packages/setuptools/_distutils/dist.py:261: UserWarning: Unknown distribution option: 'test_suite'
#         warnings.warn(msg)
#       /opt/anaconda3/lib/python3.12/site-packages/setuptools/_distutils/dist.py:261: UserWarning: Unknown distribution option: 'tests_require'
#         warnings.warn(msg)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim
#       copying gensim/interfaces.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim
#       copying gensim/downloader.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim
#       copying gensim/matutils.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim
#       copying gensim/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim
#       copying gensim/utils.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim
#       copying gensim/nosy.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/similarities
#       copying gensim/similarities/docsim.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/similarities
#       copying gensim/similarities/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/similarities
#       copying gensim/similarities/nmslib.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/similarities
#       copying gensim/similarities/levenshtein.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/similarities
#       copying gensim/similarities/termsim.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/similarities
#       copying gensim/similarities/annoy.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/similarities
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_text_analysis.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_glove2word2vec.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_parsing.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_tmdiff.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_utils.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_matutils.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_word2vec.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_segmentation.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_lsimodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_coherencemodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_miislita.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_phrases.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_dtm.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_tfidfmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_poincare.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_rpmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_corpora_hashdictionary.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_ensemblelda.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/simspeed2.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_aggregation.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_lee.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_big.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_translation_matrix.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/basetmtests.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_ldaseqmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_datatype.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_similarity_metrics.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_ldamodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_nmf.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_lda_callback.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/utils.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_keyedvectors.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_corpora_dictionary.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/svd_error.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_logentropy_model.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_doc2vec.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_similarities.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_direct_confirmation.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_api.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_atmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_corpora.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_indirect_confirmation.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_probability_estimation.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_fasttext.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_scripts.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_normmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_hdpmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/test_sharded_corpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       copying gensim/test/simspeed.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/test
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/poincare.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/basemodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/phrases.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/ensemblelda.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/_fasttext_bin.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/word2vec.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/normmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/translation_matrix.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/lsimodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/rpmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/logentropy_model.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/keyedvectors.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/lda_worker.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/fasttext.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/tfidfmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/doc2vec.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/callbacks.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/hdpmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/ldamulticore.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/ldaseqmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/lsi_dispatcher.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/lda_dispatcher.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/ldamodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/nmf.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/atmodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/lsi_worker.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       copying gensim/models/coherencemodel.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/models
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/make_wikicorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/word2vec2tensor.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/package_info.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/benchmark.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/segment_wiki.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/make_wiki_online.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/make_wiki.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/make_wiki_online_nodebug.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/glove2word2vec.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       copying gensim/scripts/word2vec_standalone.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/scripts
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/parsing
#       copying gensim/parsing/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/parsing
#       copying gensim/parsing/preprocessing.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/parsing
#       copying gensim/parsing/porter.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/parsing
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/topic_coherence
#       copying gensim/topic_coherence/direct_confirmation_measure.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/topic_coherence
#       copying gensim/topic_coherence/aggregation.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/topic_coherence
#       copying gensim/topic_coherence/text_analysis.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/topic_coherence
#       copying gensim/topic_coherence/probability_estimation.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/topic_coherence
#       copying gensim/topic_coherence/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/topic_coherence
#       copying gensim/topic_coherence/indirect_confirmation_measure.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/topic_coherence
#       copying gensim/topic_coherence/segmentation.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/topic_coherence
#       creating build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/sharded_corpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/textcorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/wikicorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/csvcorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/opinosiscorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/malletcorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/mmcorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/ucicorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/indexedcorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/lowcorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/bleicorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/dictionary.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/svmlightcorpus.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       copying gensim/corpora/hashdictionary.py -> build/lib.macosx-11.1-arm64-cpython-312/gensim/corpora
#       running egg_info
#       writing gensim.egg-info/PKG-INFO
#       writing dependency_links to gensim.egg-info/dependency_links.txt
#       writing requirements to gensim.egg-info/requires.txt
#       writing top-level names to gensim.egg-info/top_level.txt
#       reading manifest file 'gensim.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no files found matching 'COPYING.LESSER'
#       warning: no files found matching 'ez_setup.py'
#       warning: no files found matching 'gensim/models/doc2vec_inner.c'
#       adding license file 'COPYING'
#       writing manifest file 'gensim.egg-info/SOURCES.txt'
#       /opt/anaconda3/lib/python3.12/site-packages/setuptools/command/build_py.py:212: _Warning: Package 'gensim.test.test_data' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.test.test_data' to be distributed and are
#               already explicitly excluding 'gensim.test.test_data' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /opt/anaconda3/lib/python3.12/site-packages/setuptools/command/build_py.py:212: _Warning: Package 'gensim.test.test_data.DTM' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data.DTM' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data.DTM' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.test.test_data.DTM' to be distributed and are
#               already explicitly excluding 'gensim.test.test_data.DTM' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /opt/anaconda3/lib/python3.12/site-packages/setuptools/command/build_py.py:212: _Warning: Package 'gensim.test.test_data.PathLineSentences' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data.PathLineSentences' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data.PathLineSentences' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.test.test_data.PathLineSentences' to be distributed and are
#               already explicitly excluding 'gensim.test.test_data.PathLineSentences' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /opt/anaconda3/lib/python3.12/site-packages/setuptools/command/build_py.py:212: _Warning: Package 'gensim.test.test_data.old_d2v_models' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data.old_d2v_models' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data.old_d2v_models' is explicitly added
#               to the `packages` configuration field.
#
# ...
#         ^
#       gensim/models/word2vec_inner.c:1652:43: note: expanded from macro '__Pyx_GetModuleGlobalName'
#           (var) = (likely(__pyx_dict_version == __PYX_GET_DICT_VERSION(__pyx_d))) ?\
#                                                 ^
#       gensim/models/word2vec_inner.c:1624:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#       #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#                                                                       ^
#       /opt/anaconda3/include/python3.12/cpython/dictobject.h:22:5: note: 'ma_version_tag' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.12) uint64_t ma_version_tag;
#           ^
#       /opt/anaconda3/include/python3.12/pyport.h:317:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       gensim/models/word2vec_inner.c:10856:3: warning: 'ma_version_tag' is deprecated [-Wdeprecated-declarations]
#         __Pyx_GetModuleGlobalName(__pyx_t_1, __pyx_n_s_fblas); if (unlikely(!__pyx_t_1)) __PYX_ERR(0, 36, __pyx_L1_error)
#         ^
#       gensim/models/word2vec_inner.c:1652:43: note: expanded from macro '__Pyx_GetModuleGlobalName'
#           (var) = (likely(__pyx_dict_version == __PYX_GET_DICT_VERSION(__pyx_d))) ?\
#                                                 ^
#       gensim/models/word2vec_inner.c:1624:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#       #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#                                                                       ^
#       /opt/anaconda3/include/python3.12/cpython/dictobject.h:22:5: note: 'ma_version_tag' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.12) uint64_t ma_version_tag;
#           ^
#       /opt/anaconda3/include/python3.12/pyport.h:317:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       gensim/models/word2vec_inner.c:10874:3: warning: 'ma_version_tag' is deprecated [-Wdeprecated-declarations]
#         __Pyx_GetModuleGlobalName(__pyx_t_1, __pyx_n_s_fblas); if (unlikely(!__pyx_t_1)) __PYX_ERR(0, 37, __pyx_L1_error)
#         ^
#       gensim/models/word2vec_inner.c:1652:43: note: expanded from macro '__Pyx_GetModuleGlobalName'
#           (var) = (likely(__pyx_dict_version == __PYX_GET_DICT_VERSION(__pyx_d))) ?\
#                                                 ^
#       gensim/models/word2vec_inner.c:1624:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#       #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#                                                                       ^
#       /opt/anaconda3/include/python3.12/cpython/dictobject.h:22:5: note: 'ma_version_tag' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.12) uint64_t ma_version_tag;
#           ^
#       /opt/anaconda3/include/python3.12/pyport.h:317:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       gensim/models/word2vec_inner.c:10892:3: warning: 'ma_version_tag' is deprecated [-Wdeprecated-declarations]
#         __Pyx_GetModuleGlobalName(__pyx_t_1, __pyx_n_s_fblas); if (unlikely(!__pyx_t_1)) __PYX_ERR(0, 38, __pyx_L1_error)
#         ^
#       gensim/models/word2vec_inner.c:1652:43: note: expanded from macro '__Pyx_GetModuleGlobalName'
#           (var) = (likely(__pyx_dict_version == __PYX_GET_DICT_VERSION(__pyx_d))) ?\
#                                                 ^
#       gensim/models/word2vec_inner.c:1624:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#       #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#                                                                       ^
#       /opt/anaconda3/include/python3.12/cpython/dictobject.h:22:5: note: 'ma_version_tag' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.12) uint64_t ma_version_tag;
#           ^
#       /opt/anaconda3/include/python3.12/pyport.h:317:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       gensim/models/word2vec_inner.c:10987:3: warning: 'ma_version_tag' is deprecated [-Wdeprecated-declarations]
#         __Pyx_GetModuleGlobalName(__pyx_t_1, __pyx_n_s_init); if (unlikely(!__pyx_t_1)) __PYX_ERR(0, 964, __pyx_L1_error)
#         ^
#       gensim/models/word2vec_inner.c:1652:43: note: expanded from macro '__Pyx_GetModuleGlobalName'
#           (var) = (likely(__pyx_dict_version == __PYX_GET_DICT_VERSION(__pyx_d))) ?\
#                                                 ^
#       gensim/models/word2vec_inner.c:1624:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#       #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#                                                                       ^
#       /opt/anaconda3/include/python3.12/cpython/dictobject.h:22:5: note: 'ma_version_tag' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.12) uint64_t ma_version_tag;
#           ^
#       /opt/anaconda3/include/python3.12/pyport.h:317:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       gensim/models/word2vec_inner.c:11111:53: error: no member named 'ob_digit' in 'struct _longobject'
#               const digit* digits = ((PyLongObject*)op1)->ob_digit;
#                                     ~~~~~~~~~~~~~~~~~~~~  ^
#       gensim/models/word2vec_inner.c:11961:36: error: no member named 'curexc_traceback' in 'struct _ts'
#               PyObject* tmp_tb = tstate->curexc_traceback;
#                                  ~~~~~~  ^
#       gensim/models/word2vec_inner.c:11964:21: error: no member named 'curexc_traceback' in 'struct _ts'
#                   tstate->curexc_traceback = tb;
#                   ~~~~~~  ^
#       gensim/models/word2vec_inner.c:12119:27: warning: 'ma_version_tag' is deprecated [-Wdeprecated-declarations]
#           return likely(dict) ? __PYX_GET_DICT_VERSION(dict) : 0;
#                                 ^
#       gensim/models/word2vec_inner.c:1624:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#       #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#                                                                       ^
#       /opt/anaconda3/include/python3.12/cpython/dictobject.h:22:5: note: 'ma_version_tag' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.12) uint64_t ma_version_tag;
#           ^
#       /opt/anaconda3/include/python3.12/pyport.h:317:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       gensim/models/word2vec_inner.c:12131:36: warning: 'ma_version_tag' is deprecated [-Wdeprecated-declarations]
#           return (dictptr && *dictptr) ? __PYX_GET_DICT_VERSION(*dictptr) : 0;
#                                          ^
#       gensim/models/word2vec_inner.c:1624:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#       #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#                                                                       ^
#       /opt/anaconda3/include/python3.12/cpython/dictobject.h:22:5: note: 'ma_version_tag' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.12) uint64_t ma_version_tag;
#           ^
#       /opt/anaconda3/include/python3.12/pyport.h:317:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       gensim/models/word2vec_inner.c:12135:56: warning: 'ma_version_tag' is deprecated [-Wdeprecated-declarations]
#           if (unlikely(!dict) || unlikely(tp_dict_version != __PYX_GET_DICT_VERSION(dict)))
#                                                              ^
#       gensim/models/word2vec_inner.c:1624:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#       #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#                                                                       ^
#       /opt/anaconda3/include/python3.12/cpython/dictobject.h:22:5: note: 'ma_version_tag' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.12) uint64_t ma_version_tag;
#           ^
#       /opt/anaconda3/include/python3.12/pyport.h:317:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       gensim/models/word2vec_inner.c:12152:5: warning: 'ma_version_tag' is deprecated [-Wdeprecated-declarations]
#           __PYX_UPDATE_DICT_CACHE(__pyx_d, result, *dict_cached_value, *dict_version)
#           ^
#       gensim/models/word2vec_inner.c:1626:21: note: expanded from macro '__PYX_UPDATE_DICT_CACHE'
#           (version_var) = __PYX_GET_DICT_VERSION(dict);\
#                           ^
#       gensim/models/word2vec_inner.c:1624:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#       #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#                                                                       ^
#       /opt/anaconda3/include/python3.12/cpython/dictobject.h:22:5: note: 'ma_version_tag' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.12) uint64_t ma_version_tag;
#           ^
#       /opt/anaconda3/include/python3.12/pyport.h:317:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       gensim/models/word2vec_inner.c:12233:9: warning: 'ma_version_tag' is deprecated [-Wdeprecated-declarations]
#               __PYX_PY_DICT_LOOKUP_IF_MODIFIED(
#               ^
#       gensim/models/word2vec_inner.c:1631:16: note: expanded from macro '__PYX_PY_DICT_LOOKUP_IF_MODIFIED'
#           if (likely(__PYX_GET_DICT_VERSION(DICT) == __pyx_dict_version)) {\
#                      ^
#       gensim/models/word2vec_inner.c:1624:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#       #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#                                                                       ^
#       /opt/anaconda3/include/python3.12/cpython/dictobject.h:22:5: note: 'ma_version_tag' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.12) uint64_t ma_version_tag;
#           ^
#       /opt/anaconda3/include/python3.12/pyport.h:317:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       gensim/models/word2vec_inner.c:12233:9: warning: 'ma_version_tag' is deprecated [-Wdeprecated-declarations]
#               __PYX_PY_DICT_LOOKUP_IF_MODIFIED(
#               ^
#       gensim/models/word2vec_inner.c:1635:30: note: expanded from macro '__PYX_PY_DICT_LOOKUP_IF_MODIFIED'
#               __pyx_dict_version = __PYX_GET_DICT_VERSION(DICT);\
#                                    ^
#       gensim/models/word2vec_inner.c:1624:65: note: expanded from macro '__PYX_GET_DICT_VERSION'
#       #define __PYX_GET_DICT_VERSION(dict)  (((PyDictObject*)(dict))->ma_version_tag)
#                                                                       ^
#       /opt/anaconda3/include/python3.12/cpython/dictobject.h:22:5: note: 'ma_version_tag' has been explicitly marked deprecated here
#           Py_DEPRECATED(3.12) uint64_t ma_version_tag;
#           ^
#       /opt/anaconda3/include/python3.12/pyport.h:317:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       gensim/models/word2vec_inner.c:12424:5: error: incomplete definition of type 'struct _frame'
#           __Pyx_PyFrame_SetLineNumber(py_frame, py_line);
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       gensim/models/word2vec_inner.c:457:62: note: expanded from macro '__Pyx_PyFrame_SetLineNumber'
#         #define __Pyx_PyFrame_SetLineNumber(frame, lineno)  (frame)->f_lineno = (lineno)
#                                                             ~~~~~~~^
#       /opt/anaconda3/include/python3.12/pytypedefs.h:22:16: note: forward declaration of 'struct _frame'
#       typedef struct _frame PyFrameObject;
#                      ^
#       gensim/models/word2vec_inner.c:12853:55: error: no member named 'ob_digit' in 'struct _longobject'
#                   const digit* digits = ((PyLongObject*)x)->ob_digit;
#                                         ~~~~~~~~~~~~~~~~~~  ^
#       gensim/models/word2vec_inner.c:12908:55: error: no member named 'ob_digit' in 'struct _longobject'
#                   const digit* digits = ((PyLongObject*)x)->ob_digit;
#                                         ~~~~~~~~~~~~~~~~~~  ^
#       gensim/models/word2vec_inner.c:13087:55: error: no member named 'ob_digit' in 'struct _longobject'
#                   const digit* digits = ((PyLongObject*)x)->ob_digit;
#                                         ~~~~~~~~~~~~~~~~~~  ^
#       gensim/models/word2vec_inner.c:13142:55: error: no member named 'ob_digit' in 'struct _longobject'
#                   const digit* digits = ((PyLongObject*)x)->ob_digit;
#                                         ~~~~~~~~~~~~~~~~~~  ^
#       gensim/models/word2vec_inner.c:13283:55: error: no member named 'ob_digit' in 'struct _longobject'
#                   const digit* digits = ((PyLongObject*)x)->ob_digit;
#                                         ~~~~~~~~~~~~~~~~~~  ^
#       gensim/models/word2vec_inner.c:13338:55: error: no member named 'ob_digit' in 'struct _longobject'
#                   const digit* digits = ((PyLongObject*)x)->ob_digit;
#                                         ~~~~~~~~~~~~~~~~~~  ^
#       gensim/models/word2vec_inner.c:13479:55: error: no member named 'ob_digit' in 'struct _longobject'
#                   const digit* digits = ((PyLongObject*)x)->ob_digit;
#                                         ~~~~~~~~~~~~~~~~~~  ^
#       gensim/models/word2vec_inner.c:13534:55: error: no member named 'ob_digit' in 'struct _longobject'
#                   const digit* digits = ((PyLongObject*)x)->ob_digit;
#                                         ~~~~~~~~~~~~~~~~~~  ^
#       gensim/models/word2vec_inner.c:13675:55: error: no member named 'ob_digit' in 'struct _longobject'
#                   const digit* digits = ((PyLongObject*)x)->ob_digit;
#                                         ~~~~~~~~~~~~~~~~~~  ^
#       gensim/models/word2vec_inner.c:13730:55: error: no member named 'ob_digit' in 'struct _longobject'
#                   const digit* digits = ((PyLongObject*)x)->ob_digit;
#                                         ~~~~~~~~~~~~~~~~~~  ^
#       gensim/models/word2vec_inner.c:14227:47: error: no member named 'ob_digit' in 'struct _longobject'
#           const digit* digits = ((PyLongObject*)b)->ob_digit;
#                                 ~~~~~~~~~~~~~~~~~~  ^
#       15 warnings and 15 errors generated.
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for gensim
#   Running setup.py clean for gensim
# Failed to build gensim
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (gensim)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Step 1: 리뷰 데이터를 전처리하고 CTM 모델에 맞는 데이터를 준비

# 리뷰 텍스트를 전처리하기 위해 WhiteSpacePreprocessing 사용
# 필요에 따라 stopword 목록을 추가할 수 있습니다.
preprocessor = WhiteSpacePreprocessing(
    df['Review_Text'].tolist(), 
    stopwords_list=None  # 커스텀 stopword 목록을 지정하려면 여기에 추가
)
data_cleaned = preprocessor.preprocess()

# BoW(단어 빈도 벡터) 생성
vectorizer = CountVectorizer(max_features=1000)  # 최대 1000개의 단어를 BoW로 사용
data_bow = vectorizer.fit_transform(data_cleaned)
data_vocab = vectorizer.get_feature_names_out()

# CTM 모델 데이터를 준비
data_ctm = TopicModelDataPreparation("paraphrase-MiniLM-L6-v2")
data_train = data_ctm.fit(data_cleaned, bow_matrix=data_bow)

# 준비된 데이터 확인 (필요시 출력)
print("전처리된 데이터 예시:", data_cleaned[:3])
print("BoW 단어 집합 크기:", len(data_vocab))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 # Step 1: 리뷰 데이터를 전처리하고 CTM 모델에 맞는 데이터를 준비
#       2
#       3 # 리뷰 텍스트를 전처리하기 위해 WhiteSpacePreprocessing 사용
#       4 # 필요에 따라 stopword 목록을 추가할 수 있습니다.
# ----> 5 preprocessor = WhiteSpacePreprocessing(
#       6     df['Review_Text'].tolist(),
#       7     stopwords_list=None  # 커스텀 stopword 목록을 지정하려면 여기에 추가
#       8 )
#       9 data_cleaned = preprocessor.preprocess()
#      11 # BoW(단어 빈도 벡터) 생성
#
# NameError: name 'WhiteSpacePreprocessing' is not defined

# %%
# Step 2: CTM 모델 학습

# CTM 모델 초기화
ctm_model = CombinedTopicModel(
    bow_size=len(data_vocab),  # BoW 크기
    contextual_size=768,  # MiniLM 임베딩 크기
    n_components=10,  # 토픽 수 (10개의 토픽)
    num_epochs=20,  # 학습 반복 횟수
)

# 모델 학습
ctm_model.fit(data_train)

# 학습 완료 메시지
print("CTM 모델 학습 완료!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 # Step 2: CTM 모델 학습
#       2
#       3 # CTM 모델 초기화
# ----> 4 ctm_model = CombinedTopicModel(
#       5     bow_size=len(data_vocab),  # BoW 크기
#       6     contextual_size=768,  # MiniLM 임베딩 크기
#       7     n_components=10,  # 토픽 수 (10개의 토픽)
#       8     num_epochs=20,  # 학습 반복 횟수
#       9 )
#      11 # 모델 학습
#      12 ctm_model.fit(data_train)
#
# NameError: name 'CombinedTopicModel' is not defined

# %%
# Step 3: 문장 단위의 토픽 비율 계산 함수

def get_sentence_topic_proportions(text, model, data_ctm):
    """
    주어진 텍스트를 BoW와 임베딩으로 변환하고, 문장에 대한 토픽 비율을 계산
    """
    sentence_embeddings, sentence_bow = data_ctm.transform([text])
    topic_proportions = model.get_doc_topic_distribution(sentence_bow)
    return topic_proportions[0]  # 문장에 대한 토픽 비율 반환

# %%
# Step 4: 리뷰 단위의 토픽 비율 계산 함수

def aggregate_to_review_level(review_text, model, data_ctm):
    """
    리뷰를 문장 단위로 나누고, 각 문장에 대한 토픽 비율을 평균내어 리뷰 단위의 토픽 비율 계산
    """
    sentences = review_text.split('.')  # 기본적인 문장 분리
    sentence_proportions = []

    for sentence in sentences:
        if sentence.strip():  # 빈 문장은 건너뛰기
            sentence_prop = get_sentence_topic_proportions(sentence.strip(), model, data_ctm)
            sentence_proportions.append(sentence_prop)

    # 리뷰 전체에 대한 평균 토픽 비율 계산
    avg_topic_proportions = np.mean(sentence_proportions, axis=0)
    return avg_topic_proportions

# %%
# Step 5: Shannon 엔트로피 계산 함수

def calculate_entropy(topic_proportions):
    """
    주어진 토픽 비율에 대한 Shannon 엔트로피 계산
    """
    return entropy(topic_proportions, base=2)  # base=2는 정보 이론에서 일반적인 로그 기준

# %%
# Step 6: ContentDepth 계산 함수

def compute_content_depth(review_text, model, data_ctm):
    """
    리뷰에 대한 ContentDepth를 계산 (엔트로피를 문장 수로 정규화한 후 부호 반전)
    """
    # 리뷰 단위의 토픽 비율 계산
    avg_topic_proportions = aggregate_to_review_level(review_text, model, data_ctm)

    # 엔트로피 계산
    entropy_value = calculate_entropy(avg_topic_proportions)

    # 문장 수로 정규화
    num_sentences = len([s for s in review_text.split('.') if s.strip()])

    # ContentDepth 계산
    content_depth = -entropy_value / num_sentences if num_sentences > 0 else 0
    return content_depth

# %%
# Step 7: ContentDepth를 데이터프레임에 추가

df['ContentDepth'] = df['Review_Text'].apply(lambda x: compute_content_depth(x, ctm_model, data_ctm))

# 결과 확인
print(df[['Review_Text', 'ContentDepth']].head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 # Step 7: ContentDepth를 데이터프레임에 추가
# ----> 3 df['ContentDepth'] = df['Review_Text'].apply(lambda x: compute_content_depth(x, ctm_model, data_ctm))
#       5 # 결과 확인
#       6 print(df[['Review_Text', 'ContentDepth']].head())
#
# NameError: name 'df' is not defined
